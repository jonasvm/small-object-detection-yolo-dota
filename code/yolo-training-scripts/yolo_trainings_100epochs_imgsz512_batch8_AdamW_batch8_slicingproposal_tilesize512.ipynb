# %% [markdown]
# Downloading the first part of the training images zip

# %%
# Instala gdown
# !pip install -U gdown

# Baixa o arquivo usando o ID
import gdown

file_id = "1BlaGYNNEKGmT6OjZjsJ8HoUYrTTmFcO2"
output = "imagens.zip"

gdown.download(f"https://drive.google.com/uc?id={file_id}", output, quiet=False)
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.7.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1BlaGYNNEKGmT6OjZjsJ8HoUYrTTmFcO2
# From (redirected): https://drive.google.com/uc?id=1BlaGYNNEKGmT6OjZjsJ8HoUYrTTmFcO2&confirm=t&uuid=b1eca319-f366-44a6-b2ad-e4fcfd125d29
# To: /content/imagens.zip
# 100%|██████████| 2.13G/2.13G [00:17<00:00, 120MB/s]
# 'imagens.zip'

# %% [markdown]
# Unzipping the images and placing them into the YOLO dataset folder structure

# %%
# Cria a subpasta desejada e descompacta
import os
import zipfile

destino = "yolo-dataset/images/train"
os.makedirs(destino, exist_ok=True)

with zipfile.ZipFile("imagens.zip", 'r') as zip_ref:
    zip_ref.extractall(destino)

# Mostra os primeiros arquivos extraídos
# !ls -lh "yolo-dataset/images/train" | head
# Out:
# total 20K
# drwxr-xr-x 2 root root 20K Aug  7 03:20 images

# %% [markdown]
# The images ended up in the wrong structure, so moving them to the correct order

# %%
import os
import shutil

# Caminhos
pasta_errada = "yolo-dataset/images/train/images"
pasta_correta = "yolo-dataset/images/train"

# Verifica se a pasta errada existe
if os.path.exists(pasta_errada):
    # Move todos os arquivos da pasta_errada para pasta_correta
    for nome_arquivo in os.listdir(pasta_errada):
        origem = os.path.join(pasta_errada, nome_arquivo)
        destino = os.path.join(pasta_correta, nome_arquivo)
        shutil.move(origem, destino)

    # Remove a pasta_errada após mover os arquivos
    shutil.rmtree(pasta_errada)
    print("Arquivos movidos e pasta 'images' removida com sucesso.")
else:
    print("Pasta 'yolo-dataset/images/train/images' não encontrada.")
# Out:
# Arquivos movidos e pasta 'images' removida com sucesso.

# %% [markdown]
# Doing the same thing for part 2 of the training image

# %%
# ID do arquivo no Google Drive
file_id = "1JBWCHdyZOd9ULX0ng5C9haAt3FMPXa3v"
zip_path = "imagens2.zip"

# Baixa o .zip
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# Caminhos de destino
destino_final = "yolo-dataset/images/train"
tmp_extract = "temp_extracao"

# Cria as pastas
os.makedirs(tmp_extract, exist_ok=True)
os.makedirs(destino_final, exist_ok=True)

# Descompacta na pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(tmp_extract)

# Move arquivos da subpasta "images" para "train"
src_images_dir = os.path.join(tmp_extract, "images")
if os.path.exists(src_images_dir):
    for nome_arquivo in os.listdir(src_images_dir):
        origem = os.path.join(src_images_dir, nome_arquivo)
        destino = os.path.join(destino_final, nome_arquivo)
        shutil.move(origem, destino)
else:
    print(f"A pasta '{src_images_dir}' não foi encontrada.")

# Remove a pasta temporária
shutil.rmtree(tmp_extract)

# Verifica resultado
# !ls -lh "yolo-dataset/images/train" | head
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JBWCHdyZOd9ULX0ng5C9haAt3FMPXa3v
# From (redirected): https://drive.google.com/uc?id=1JBWCHdyZOd9ULX0ng5C9haAt3FMPXa3v&confirm=t&uuid=63d52508-0634-4c31-b2bb-7dcc6b1f3bf3
# To: /content/imagens2.zip
# 100%|██████████| 4.76G/4.76G [01:06<00:00, 71.3MB/s]
# total 6.8G
# -rw-r--r-- 1 root root   23M Aug  7 03:20 P0000.png
# -rw-r--r-- 1 root root   12M Aug  7 03:20 P0001.png
# -rw-r--r-- 1 root root  7.8M Aug  7 03:20 P0002.png
# -rw-r--r-- 1 root root  1.4M Aug  7 03:20 P0005.png
# -rw-r--r-- 1 root root  2.1M Aug  7 03:20 P0008.png
# -rw-r--r-- 1 root root  6.0M Aug  7 03:20 P0010.png
# -rw-r--r-- 1 root root  3.6M Aug  7 03:20 P0011.png
# -rw-r--r-- 1 root root  9.2M Aug  7 03:20 P0012.png
# -rw-r--r-- 1 root root  3.9M Aug  7 03:20 P0013.png

# %% [markdown]
# Now the third and final part of the training images zip

# %%
# ID do terceiro arquivo
file_id = "1pEmwJtugIWhiwgBqOtplNUtTG2T454zn"
zip_path = "imagens3.zip"

# Baixa o arquivo .zip do Google Drive
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# Diretórios
tmp_extract = "temp_extracao"
destino_final = "yolo-dataset/images/train"

# Cria diretórios se não existirem
os.makedirs(tmp_extract, exist_ok=True)
os.makedirs(destino_final, exist_ok=True)

# Extrai o conteúdo na pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(tmp_extract)

# Move arquivos de temp_extracao/images para train/
src_images_dir = os.path.join(tmp_extract, "images")
if os.path.exists(src_images_dir):
    for nome_arquivo in os.listdir(src_images_dir):
        origem = os.path.join(src_images_dir, nome_arquivo)
        destino = os.path.join(destino_final, nome_arquivo)
        shutil.move(origem, destino)
else:
    print(f"Pasta '{src_images_dir}' não encontrada.")

# Limpa a pasta temporária
shutil.rmtree(tmp_extract)

# Verifica os primeiros arquivos movidos
# !ls -lh "yolo-dataset/images/train" | head
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1pEmwJtugIWhiwgBqOtplNUtTG2T454zn
# From (redirected): https://drive.google.com/uc?id=1pEmwJtugIWhiwgBqOtplNUtTG2T454zn&confirm=t&uuid=6c34fed3-cd77-48b9-afdc-868ff53cbead
# To: /content/imagens3.zip
# 100%|██████████| 3.32G/3.32G [01:17<00:00, 42.7MB/s]
# total 10G
# -rw-r--r-- 1 root root   23M Aug  7 03:20 P0000.png
# -rw-r--r-- 1 root root   12M Aug  7 03:20 P0001.png
# -rw-r--r-- 1 root root  7.8M Aug  7 03:20 P0002.png
# -rw-r--r-- 1 root root  1.4M Aug  7 03:20 P0005.png
# -rw-r--r-- 1 root root  2.1M Aug  7 03:20 P0008.png
# -rw-r--r-- 1 root root  6.0M Aug  7 03:20 P0010.png
# -rw-r--r-- 1 root root  3.6M Aug  7 03:20 P0011.png
# -rw-r--r-- 1 root root  9.2M Aug  7 03:20 P0012.png
# -rw-r--r-- 1 root root  3.9M Aug  7 03:20 P0013.png

# %% [markdown]
# Checking the images

# %%
# Caminho da pasta com as imagens
caminho = "yolo-dataset/images/train"

# Extensões consideradas como imagem
extensoes_imagem = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp')

# Conta arquivos com as extensões de imagem
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensoes_imagem)
)

print(f"Total de imagens em '{caminho}': {quantidade}")
# Out:
# Total de imagens em 'yolo-dataset/images/train': 1411

# %% [markdown]
# Now setting up the validation images

# %%
# ID do arquivo .zip no Google Drive
file_id = "1uCCCFhFQOJLfjBpcL5MC0DHJ9lgOaXWP"
zip_path = "imagens_test.zip"

# Baixar o arquivo .zip
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# Caminhos
tmp_extract = "temp_extracao"
destino_final = "yolo-dataset/images/val"

# Cria pastas se necessário
os.makedirs(tmp_extract, exist_ok=True)
os.makedirs(destino_final, exist_ok=True)

# Descompacta na pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(tmp_extract)

# Move arquivos de temp_extracao/images para test/
src_images_dir = os.path.join(tmp_extract, "images")
if os.path.exists(src_images_dir):
    for nome_arquivo in os.listdir(src_images_dir):
        origem = os.path.join(src_images_dir, nome_arquivo)
        destino = os.path.join(destino_final, nome_arquivo)
        shutil.move(origem, destino)
else:
    print(f"Pasta '{src_images_dir}' não encontrada.")

# Remove pasta temporária
shutil.rmtree(tmp_extract)

# Verifica os primeiros arquivos
# !ls -lh "yolo-dataset/images/test" | head
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1uCCCFhFQOJLfjBpcL5MC0DHJ9lgOaXWP
# From (redirected): https://drive.google.com/uc?id=1uCCCFhFQOJLfjBpcL5MC0DHJ9lgOaXWP&confirm=t&uuid=052a38f4-5d89-4152-a6cf-0943e7116079
# To: /content/imagens_test.zip
# 100%|██████████| 3.34G/3.34G [00:46<00:00, 71.3MB/s]
# ls: cannot access 'yolo-dataset/images/test': No such file or directory

# %% [markdown]
# Checking the validation images

# %%
# Caminho da pasta com as imagens
caminho = "yolo-dataset/images/val"

# Extensões consideradas como imagem
extensoes_imagem = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp')

# Conta arquivos com as extensões de imagem
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensoes_imagem)
)

print(f"Total de imagens em '{caminho}': {quantidade}")
# Out:
# Total de imagens em 'yolo-dataset/images/val': 458

# %% [markdown]
# Checking the training images

# %%
# Caminho da pasta com as imagens
caminho = "yolo-dataset/images/train"

# Extensões consideradas como imagem
extensoes_imagem = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp')

# Conta arquivos com as extensões de imagem
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensoes_imagem)
)

print(f"Total de imagens em '{caminho}': {quantidade}")
# Out:
# Total de imagens em 'yolo-dataset/images/train': 1411

# %% [markdown]
# Uploading and organizing the training labels (manual upload)

# %%
# Caminhos
zip_path = "/content/train.zip"
dest_folder = "/content/yolo-dataset/labels/train"
temp_extract_folder = "/content/temp_labels"

# Cria a pasta de destino se não existir
os.makedirs(dest_folder, exist_ok=True)

# Extrai o zip para uma pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(temp_extract_folder)

# Move os arquivos extraídos para a pasta de destino
for root, _, files in os.walk(temp_extract_folder):
    for file in files:
        src = os.path.join(root, file)
        dst = os.path.join(dest_folder, file)
        shutil.move(src, dst)

# Remove a pasta temporária
shutil.rmtree(temp_extract_folder)

print(f"Arquivos extraídos para {dest_folder}")
# Out:
# Arquivos extraídos para /content/yolo-dataset/labels/train

# %% [markdown]
# Uploading and organizing the validation labels (manual upload)

# %%
# Caminhos
zip_path = "/content/val.zip"
dest_folder = "/content/yolo-dataset/labels/val"
temp_extract_folder = "/content/temp_labels"

# Cria a pasta de destino se não existir
os.makedirs(dest_folder, exist_ok=True)

# Extrai o zip para uma pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(temp_extract_folder)

# Move os arquivos extraídos para a pasta de destino
for root, _, files in os.walk(temp_extract_folder):
    for file in files:
        src = os.path.join(root, file)
        dst = os.path.join(dest_folder, file)
        shutil.move(src, dst)

# Remove a pasta temporária
shutil.rmtree(temp_extract_folder)

print(f"Arquivos extraídos para {dest_folder}")
# Out:
# Arquivos extraídos para /content/yolo-dataset/labels/val

# %% [markdown]
# Checking the labels

# %%
# Caminho da pasta com os labels
caminho = "yolo-dataset/labels/train"

# Extensão considerada como label YOLO
extensao_label = ".txt"

# Conta arquivos com a extensão .txt
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensao_label)
)

print(f"Total de labels em '{caminho}': {quantidade}")
# Out:
# Total de labels em 'yolo-dataset/labels/train': 1410

# %%
# Caminho da pasta com os labels
caminho = "yolo-dataset/labels/val"

# Extensão considerada como label YOLO
extensao_label = ".txt"

# Conta arquivos com a extensão .txt
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensao_label)
)

print(f"Total de labels em '{caminho}': {quantidade}")
# Out:
# Total de labels em 'yolo-dataset/labels/val': 458

# %% [markdown]
# Creating the dataset description

# %%
data_yaml = """
train: yolo-dataset/images/train
val: yolo-dataset/images/val

nc: 15

names: [
  'plane',
  'ship',
  'storage-tank',
  'baseball-diamond',
  'tennis-court',
  'basketball-court',
  'ground-track-field',
  'harbor',
  'bridge',
  'large-vehicle',
  'small-vehicle',
  'helicopter',
  'roundabout',
  'soccer-ball-field',
  'swimming-pool'
]
"""

with open("data.yaml", "w") as f:
    f.write(data_yaml)

# %% [markdown]
# Installing the ultralytics

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.175-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.175-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 131.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 107.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 45.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 114.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.175 ultralytics-thop-2.0.15

# %% [markdown]
# Checking the GPU availability

# %%
# !nvidia-smi
# Out:
# Thu Aug  7 03:28:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# NOW PROCESSING THE IMAGES FOR TESTING WITH TRAINING AND VALIDATION SLICIN

# %%
import os
import cv2
import math
import shutil

# Configurações
BASE_DIR = "/content/yolo-dataset"
IMG_DIR = os.path.join(BASE_DIR, "images")
LABEL_DIR = os.path.join(BASE_DIR, "labels")

OUTPUT_DIR = "/content/yolo-dataset-sliced"
TILE_SIZE = 512

SUBSETS = ["train", "val"]  # Apenas train e val

def read_labels(label_path):
    labels = []
    if not os.path.exists(label_path):
        return labels
    with open(label_path, "r") as f:
        for line in f.readlines():
            parts = line.strip().split()
            cls = int(parts[0])
            x_center = float(parts[1])
            y_center = float(parts[2])
            w = float(parts[3])
            h = float(parts[4])
            labels.append([cls, x_center, y_center, w, h])
    return labels

def save_labels(label_path, labels):
    with open(label_path, "w") as f:
        for label in labels:
            f.write(" ".join(map(str, label)) + "\n")

def yolo_to_box(xc, yc, w, h, img_w, img_h):
    xmin = (xc - w / 2) * img_w
    xmax = (xc + w / 2) * img_w
    ymin = (yc - h / 2) * img_h
    ymax = (yc + h / 2) * img_h
    return xmin, ymin, xmax, ymax

def box_to_yolo(xmin, ymin, xmax, ymax, img_w, img_h):
    xc = (xmin + xmax) / 2 / img_w
    yc = (ymin + ymax) / 2 / img_h
    w = (xmax - xmin) / img_w
    h = (ymax - ymin) / img_h
    return [xc, yc, w, h]

def process_subset(subset):
    img_subset_dir = os.path.join(IMG_DIR, subset)
    label_subset_dir = os.path.join(LABEL_DIR, subset)
    out_img_dir = os.path.join(OUTPUT_DIR, "images", subset)
    out_label_dir = os.path.join(OUTPUT_DIR, "labels", subset)

    os.makedirs(out_img_dir, exist_ok=True)
    os.makedirs(out_label_dir, exist_ok=True)

    img_files = [f for f in os.listdir(img_subset_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

    for img_file in img_files:
        img_path = os.path.join(img_subset_dir, img_file)
        label_path = os.path.join(label_subset_dir, img_file.rsplit('.',1)[0] + ".txt")

        img = cv2.imread(img_path)
        if img is None:
            print(f"Erro ao ler imagem {img_path}")
            continue
        h_img, w_img = img.shape[:2]

        labels = read_labels(label_path)

        # Se a imagem for menor ou igual a TILE_SIZE em largura ou altura, copia direto
        if w_img <= TILE_SIZE or h_img <= TILE_SIZE:
            out_img_path = os.path.join(out_img_dir, img_file)
            out_label_path = os.path.join(out_label_dir, img_file.rsplit('.',1)[0] + ".txt")
            shutil.copy2(img_path, out_img_path)
            save_labels(out_label_path, labels)
            print(f"Copiado {img_file} sem fatiamento")
            continue

        # Quantidade de tiles horizontal e vertical
        tiles_x = math.ceil(w_img / TILE_SIZE)
        tiles_y = math.ceil(h_img / TILE_SIZE)

        for ty in range(tiles_y):
            for tx in range(tiles_x):
                x_start = tx * TILE_SIZE
                y_start = ty * TILE_SIZE
                x_end = min(x_start + TILE_SIZE, w_img)
                y_end = min(y_start + TILE_SIZE, h_img)

                tile_w = x_end - x_start
                tile_h = y_end - y_start

                tile_img = img[y_start:y_end, x_start:x_end]

                tile_labels = []
                for label in labels:
                    cls, xc, yc, bw, bh = label
                    xmin, ymin, xmax, ymax = yolo_to_box(xc, yc, bw, bh, w_img, h_img)

                    inter_xmin = max(xmin, x_start)
                    inter_ymin = max(ymin, y_start)
                    inter_xmax = min(xmax, x_end)
                    inter_ymax = min(ymax, y_end)

                    inter_w = inter_xmax - inter_xmin
                    inter_h = inter_ymax - inter_ymin

                    if inter_w <= 0 or inter_h <= 0:
                        continue

                    new_xmin = inter_xmin - x_start
                    new_ymin = inter_ymin - y_start
                    new_xmax = inter_xmax - x_start
                    new_ymax = inter_ymax - y_start

                    if new_xmax - new_xmin < 2 or new_ymax - new_ymin < 2:
                        continue

                    new_xc, new_yc, new_w, new_h = box_to_yolo(new_xmin, new_ymin, new_xmax, new_ymax, tile_w, tile_h)

                    tile_labels.append([cls, new_xc, new_yc, new_w, new_h])

                if len(tile_labels) > 0:
                    tile_img_name = f"{img_file.rsplit('.',1)[0]}_{ty}_{tx}.png"
                    tile_label_name = f"{img_file.rsplit('.',1)[0]}_{ty}_{tx}.txt"

                    cv2.imwrite(os.path.join(out_img_dir, tile_img_name), tile_img)
                    save_labels(os.path.join(out_label_dir, tile_label_name), tile_labels)

        print(f"Processado {img_file} - {tiles_y}x{tiles_x} tiles")

def main():
    for subset in SUBSETS:
        print(f"Processando {subset}...")
        process_subset(subset)
    print("Corte concluído!")

if __name__ == "__main__":
    main()
# Out:
# Processando train...
# Processado P2354.png - 4x4 tiles
# Processado P0581.png - 4x4 tiles
# Processado P0225.png - 2x3 tiles
# Processado P1616.png - 8x8 tiles
# Processado P1688.png - 8x8 tiles
# Processado P1976.png - 2x2 tiles
# Processado P1739.png - 8x8 tiles
# Processado P2106.png - 2x2 tiles
# Processado P0648.png - 2x2 tiles
# Processado P0013.png - 4x3 tiles
# Processado P2066.png - 3x3 tiles
# Processado P1918.png - 2x2 tiles
# Processado P0404.png - 3x3 tiles
# Processado P2668.png - 6x4 tiles
# Processado P2692.png - 5x6 tiles
# Processado P0873.png - 7x4 tiles
# Processado P2501.png - 5x4 tiles
# Processado P0441.png - 3x3 tiles
# Processado P0251.png - 4x4 tiles
# Processado P2730.png - 3x3 tiles
# Processado P0349.png - 7x7 tiles
# Processado P0224.png - 3x4 tiles
# Processado P1239.png - 8x8 tiles
# Processado P0061.png - 4x4 tiles
# Processado P1366.png - 8x11 tiles
# Processado P0052.png - 5x4 tiles
# Processado P1535.png - 10x8 tiles
# Processado P1591.png - 8x9 tiles
# Processado P1896.png - 2x2 tiles
# Processado P1046.png - 3x6 tiles
# Processado P2013.png - 2x4 tiles
# Processado P1894.png - 2x3 tiles
# Processado P2657.png - 5x4 tiles
# Processado P1155.png - 6x6 tiles
# Processado P1702.png - 8x9 tiles
# Processado P0299.png - 2x3 tiles
# Processado P0516.png - 3x3 tiles
# Processado P0843.png - 2x2 tiles
# Processado P0728.png - 3x5 tiles
# Processado P1574.png - 8x8 tiles
# Processado P2712.png - 3x4 tiles
# Processado P2019.png - 3x3 tiles
# Processado P1185.png - 3x3 tiles
# Processado P2533.png - 5x5 tiles
# Processado P2680.png - 4x4 tiles
# Processado P0308.png - 3x3 tiles
# Processado P2313.png - 2x2 tiles
# Processado P2468.png - 4x4 tiles
# Processado P1057.png - 8x9 tiles
# Processado P2531.png - 5x5 tiles
# Processado P1661.png - 8x8 tiles
# Processado P2006.png - 6x4 tiles
# Processado P0817.png - 3x3 tiles
# Processado P0386.png - 3x2 tiles
# Processado P1499.png - 6x6 tiles
# Processado P0431.png - 3x3 tiles
# Processado P0438.png - 3x4 tiles
# Processado P1580.png - 8x8 tiles
# Processado P2182.png - 4x3 tiles
# Processado P1805.png - 4x3 tiles
# Processado P0900.png - 5x5 tiles
# Processado P2792.png - 4x5 tiles
# Processado P2479.png - 5x4 tiles
# Processado P0461.png - 2x3 tiles
# Processado P1997.png - 2x2 tiles
# Processado P0950.png - 3x10 tiles
# Processado P1399.png - 12x13 tiles
# Processado P0602.png - 3x3 tiles
# Processado P2433.png - 4x4 tiles
# Processado P0255.png - 4x3 tiles
# Processado P0933.png - 3x5 tiles
# Processado P0987.png - 4x3 tiles
# Processado P1741.png - 8x9 tiles
# Processado P2054.png - 2x2 tiles
# Processado P0301.png - 2x2 tiles
# Processado P0064.png - 5x6 tiles
# Processado P1352.png - 8x8 tiles
# Processado P2734.png - 6x9 tiles
# Processado P0495.png - 3x2 tiles
# Processado P1063.png - 4x5 tiles
# Processado P0167.png - 7x8 tiles
# Processado P0074.png - 2x2 tiles
# Processado P2770.png - 5x7 tiles
# Processado P2435.png - 5x4 tiles
# Processado P2426.png - 5x4 tiles
# Processado P1340.png - 8x8 tiles
# Processado P1495.png - 11x10 tiles
# Processado P1055.png - 9x10 tiles
# Processado P2397.png - 4x4 tiles
# Processado P0446.png - 2x4 tiles
# Processado P2528.png - 4x5 tiles
# Processado P0868.png - 5x7 tiles
# Processado P2560.png - 7x8 tiles
# Processado P2793.png - 4x4 tiles
# Processado P1939.png - 3x3 tiles
# Processado P1685.png - 6x9 tiles
# Processado P0183.png - 4x13 tiles
# Processado P0000.png - 11x8 tiles
# Processado P0365.png - 2x3 tiles
# Processado P2491.png - 6x6 tiles
# Processado P0730.png - 3x4 tiles
# Processado P1972.png - 6x13 tiles
# Processado P2116.png - 3x3 tiles
# Processado P2621.png - 3x4 tiles
# Processado P2731.png - 10x10 tiles
# Processado P2309.png - 2x2 tiles
# Copiado P2321.png sem fatiamento
# Processado P0856.png - 3x4 tiles
# Processado P2470.png - 4x3 tiles
# Processado P1753.png - 8x8 tiles
# Processado P0753.png - 2x2 tiles
# Processado P0067.png - 3x3 tiles
# Processado P2506.png - 4x4 tiles
# Processado P2700.png - 6x7 tiles
# Processado P1467.png - 8x8 tiles
# Processado P2606.png - 6x4 tiles
# Processado P1981.png - 4x4 tiles
# Processado P2453.png - 5x4 tiles
# Processado P2732.png - 6x7 tiles
# Processado P0938.png - 3x4 tiles
# Processado P0460.png - 3x2 tiles
# Processado P2553.png - 7x7 tiles
# Processado P0285.png - 2x2 tiles
# Processado P2060.png - 2x2 tiles
# Processado P0921.png - 6x8 tiles
# Processado P2110.png - 4x2 tiles
# Processado P1161.png - 13x13 tiles
# Processado P2100.png - 3x4 tiles
# Processado P1930.png - 5x3 tiles
# Processado P1984.png - 2x2 tiles
# Processado P0452.png - 2x3 tiles
# Processado P1631.png - 8x8 tiles
# Processado P2156.png - 2x2 tiles
# Processado P2529.png - 4x4 tiles
# Processado P1632.png - 8x8 tiles
# Processado P2235.png - 4x2 tiles
# Processado P0376.png - 2x2 tiles
# Copiado P2270.png sem fatiamento
# Processado P1965.png - 2x2 tiles
# Processado P2352.png - 5x5 tiles
# Processado P0200.png - 2x3 tiles
# Processado P2001.png - 2x2 tiles
# Processado P1113.png - 2x6 tiles
# Processado P1966.png - 3x2 tiles
# Processado P1403.png - 7x9 tiles
# Processado P1150.png - 7x6 tiles
# Processado P2585.png - 4x4 tiles
# Processado P0809.png - 3x3 tiles
# Processado P0805.png - 3x3 tiles
# Processado P0478.png - 3x2 tiles
# Processado P1788.png - 3x4 tiles
# Processado P2421.png - 5x5 tiles
# Processado P0160.png - 6x7 tiles
# Processado P1181.png - 9x8 tiles
# Processado P2127.png - 2x2 tiles
# Processado P2475.png - 5x4 tiles
# Processado P1193.png - 2x3 tiles
# Processado P1545.png - 8x8 tiles
# Processado P1746.png - 8x8 tiles
# Processado P2403.png - 4x5 tiles
# Copiado P2016.png sem fatiamento
# Processado P0099.png - 3x3 tiles
# Processado P2543.png - 5x5 tiles
# Processado P2788.png - 2x3 tiles
# Processado P0750.png - 2x4 tiles
# Processado P2476.png - 5x4 tiles
# Processado P2483.png - 4x4 tiles
# Processado P1633.png - 8x8 tiles
# Processado P1427.png - 11x16 tiles
# Processado P1027.png - 3x5 tiles
# Processado P1808.png - 3x2 tiles
# Processado P0586.png - 2x3 tiles
# Processado P0687.png - 4x4 tiles
# Processado P1458.png - 10x8 tiles
# Processado P2189.png - 3x2 tiles
# Processado P0831.png - 2x3 tiles
# Processado P1228.png - 8x8 tiles
# Processado P0434.png - 2x3 tiles
# Processado P2686.png - 8x13 tiles
# Processado P2063.png - 2x2 tiles
# Processado P0222.png - 3x4 tiles
# Processado P2605.png - 5x5 tiles
# Processado P2609.png - 10x8 tiles
# Processado P2641.png - 11x15 tiles
# Processado P2099.png - 3x3 tiles
# Processado P1443.png - 7x11 tiles
# Processado P1247.png - 8x8 tiles
# Processado P1306.png - 8x8 tiles
# Processado P1130.png - 6x5 tiles
# Processado P0587.png - 2x3 tiles
# Processado P1329.png - 8x8 tiles
# Processado P2442.png - 4x3 tiles
# Processado P2646.png - 6x3 tiles
# Processado P1676.png - 8x9 tiles
# Processado P1839.png - 4x3 tiles
# Processado P2032.png - 2x2 tiles
# Processado P2179.png - 3x3 tiles
# Processado P1109.png - 5x4 tiles
# Processado P2411.png - 4x4 tiles
# Processado P2716.png - 5x8 tiles
# Processado P0783.png - 3x5 tiles
# Processado P1879.png - 2x2 tiles
# Processado P1168.png - 15x6 tiles
# Processado P1594.png - 8x8 tiles
# Processado P2672.png - 6x8 tiles
# Processado P2346.png - 4x4 tiles
# Processado P2517.png - 4x5 tiles
# Copiado P2057.png sem fatiamento
# Copiado P2103.png sem fatiamento
# Processado P1585.png - 8x8 tiles
# Processado P2409.png - 5x4 tiles
# Processado P0521.png - 4x3 tiles
# Processado P1522.png - 6x8 tiles
# Processado P0627.png - 3x7 tiles
# Processado P1780.png - 10x8 tiles
# Processado P1200.png - 8x11 tiles
# Processado P2061.png - 2x2 tiles
# Processado P1649.png - 8x8 tiles
# Processado P2226.png - 3x9 tiles
# Processado P0707.png - 3x3 tiles
# Processado P0652.png - 2x2 tiles
# Processado P0555.png - 4x2 tiles
# Processado P0967.png - 3x8 tiles
# Processado P1141.png - 9x11 tiles
# Processado P0465.png - 3x3 tiles
# Processado P2247.png - 3x6 tiles
# Processado P1636.png - 8x8 tiles
# Processado P0845.png - 3x2 tiles
# Processado P1730.png - 8x8 tiles
# Processado P0203.png - 2x4 tiles
# Processado P2249.png - 13x5 tiles
# Processado P1186.png - 2x2 tiles
# Processado P0286.png - 2x2 tiles
# Processado P0453.png - 2x3 tiles
# Processado P2519.png - 5x4 tiles
# Processado P1182.png - 7x6 tiles
# Processado P2561.png - 3x3 tiles
# Processado P2279.png - 6x7 tiles
# Processado P1131.png - 12x9 tiles
# Processado P2728.png - 5x6 tiles
# Processado P0790.png - 4x5 tiles
# Processado P2243.png - 4x4 tiles
# Processado P1224.png - 8x8 tiles
# Processado P0256.png - 2x3 tiles
# Processado P0688.png - 3x3 tiles
# Processado P2163.png - 3x3 tiles
# Processado P1077.png - 3x2 tiles
# Processado P0786.png - 4x7 tiles
# Processado P2681.png - 3x3 tiles
# Processado P1358.png - 8x8 tiles
# Processado P1260.png - 8x8 tiles
# Processado P2777.png - 5x9 tiles
# Processado P0233.png - 3x3 tiles
# Processado P1459.png - 9x11 tiles
# Processado P0070.png - 3x3 tiles
# Processado P1790.png - 4x3 tiles
# Processado P2141.png - 3x3 tiles
# Processado P1394.png - 8x14 tiles
# Processado P0330.png - 2x3 tiles
# Processado P0339.png - 3x7 tiles
# Processado P0288.png - 3x3 tiles
# Processado P2690.png - 5x6 tiles
# Processado P2638.png - 4x2 tiles
# Processado P1745.png - 8x8 tiles
# Processado P1277.png - 8x8 tiles
# Processado P0400.png - 2x3 tiles
# Processado P2674.png - 6x6 tiles
# Processado P1562.png - 8x8 tiles
# Processado P2492.png - 5x4 tiles
# Processado P1076.png - 6x3 tiles
# Processado P1804.png - 3x3 tiles
# Processado P0782.png - 3x2 tiles
# Processado P0884.png - 3x3 tiles
# Processado P2548.png - 5x5 tiles
# Copiado P2175.png sem fatiamento
# Processado P1201.png - 8x8 tiles
# Processado P1887.png - 2x2 tiles
# Processado P1891.png - 3x4 tiles
# Processado P1439.png - 9x5 tiles
# Processado P0032.png - 4x5 tiles
# Processado P2028.png - 2x3 tiles
# Processado P1053.png - 3x3 tiles
# Processado P2077.png - 2x2 tiles
# Processado P2144.png - 2x2 tiles
# Processado P1341.png - 8x8 tiles
# Processado P0624.png - 3x2 tiles
# Processado P2464.png - 5x4 tiles
# Processado P2052.png - 2x2 tiles
# Processado P0417.png - 3x2 tiles
# Processado P2423.png - 4x4 tiles
# Processado P0174.png - 3x4 tiles
# Processado P2509.png - 5x5 tiles
# Processado P2735.png - 6x7 tiles
# Processado P0091.png - 3x2 tiles
# Processado P2750.png - 8x7 tiles
# Processado P0488.png - 2x2 tiles
# Processado P0395.png - 2x3 tiles
# Processado P0861.png - 6x5 tiles
# Processado P2047.png - 3x3 tiles
# Processado P2591.png - 4x4 tiles
# Processado P1757.png - 8x8 tiles
# Processado P1462.png - 10x12 tiles
# Processado P0737.png - 3x5 tiles
# Processado P2457.png - 5x4 tiles
# Processado P1799.png - 2x2 tiles
# Processado P0846.png - 2x4 tiles
# Processado P0800.png - 4x4 tiles
# Processado P0981.png - 3x4 tiles
# Processado P2282.png - 7x7 tiles
# Processado P2748.png - 6x7 tiles
# Copiado P1118.png sem fatiamento
# Processado P2018.png - 3x3 tiles
# Processado P0578.png - 3x5 tiles
# Processado P0041.png - 5x7 tiles
# Processado P2746.png - 5x6 tiles
# Copiado P2070.png sem fatiamento
# Processado P2201.png - 2x3 tiles
# Processado P1069.png - 7x9 tiles
# Processado P0273.png - 2x3 tiles
# Processado P0364.png - 2x2 tiles
# Processado P2158.png - 4x3 tiles
# Processado P0810.png - 2x2 tiles
# Processado P2036.png - 4x2 tiles
# Processado P1067.png - 7x5 tiles
# Processado P0039.png - 8x8 tiles
# Processado P2629.png - 4x3 tiles
# Processado P1455.png - 11x12 tiles
# Processado P1874.png - 7x7 tiles
# Processado P0567.png - 2x2 tiles
# Processado P2014.png - 6x6 tiles
# Processado P1822.png - 2x2 tiles
# Processado P1620.png - 8x8 tiles
# Processado P2123.png - 2x2 tiles
# Processado P0629.png - 3x5 tiles
# Processado P2401.png - 5x4 tiles
# Processado P2224.png - 3x10 tiles
# Processado P1395.png - 7x10 tiles
# Processado P2122.png - 2x2 tiles
# Processado P1413.png - 8x11 tiles
# Processado P0658.png - 3x2 tiles
# Processado P2091.png - 2x2 tiles
# Processado P2579.png - 4x4 tiles
# Processado P1433.png - 2x2 tiles
# Processado P2670.png - 6x5 tiles
# Processado P0129.png - 4x3 tiles
# Processado P0554.png - 2x3 tiles
# Processado P0439.png - 2x2 tiles
# Processado P2196.png - 3x3 tiles
# Processado P2262.png - 2x5 tiles
# Processado P2604.png - 4x3 tiles
# Processado P1789.png - 3x4 tiles
# Processado P2554.png - 6x6 tiles
# Processado P2460.png - 4x4 tiles
# Processado P1061.png - 3x4 tiles
# Processado P1119.png - 2x7 tiles
# Processado P1537.png - 10x8 tiles
# Processado P1660.png - 8x8 tiles
# Processado P0966.png - 3x7 tiles
# Processado P0082.png - 10x11 tiles
# Processado P1756.png - 8x8 tiles
# Processado P0872.png - 3x5 tiles
# Processado P1281.png - 8x8 tiles
# Copiado P1054.png sem fatiamento
# Processado P2615.png - 2x3 tiles
# Processado P0611.png - 4x2 tiles
# Processado P0609.png - 4x2 tiles
# Processado P0038.png - 9x5 tiles
# Processado P0335.png - 4x5 tiles
# Processado P1565.png - 8x9 tiles
# Copiado P2184.png sem fatiamento
# Processado P0345.png - 7x3 tiles
# Processado P2572.png - 5x3 tiles
# Copiado P2319.png sem fatiamento
# Processado P2217.png - 4x2 tiles
# Processado P2628.png - 4x3 tiles
# Processado P0878.png - 5x10 tiles
# Processado P0631.png - 4x3 tiles
# Processado P1597.png - 10x8 tiles
# Processado P1841.png - 4x4 tiles
# Processado P1638.png - 8x9 tiles
# Processado P0322.png - 4x4 tiles
# Processado P1231.png - 8x8 tiles
# Processado P1934.png - 2x2 tiles
# Processado P0169.png - 8x14 tiles
# Processado P1696.png - 8x8 tiles
# Processado P1502.png - 9x9 tiles
# Processado P1222.png - 8x8 tiles
# Processado P1216.png - 8x8 tiles
# Processado P0544.png - 3x4 tiles
# Processado P0124.png - 5x4 tiles
# Processado P1167.png - 9x6 tiles
# Processado P0448.png - 3x2 tiles
# Processado P2656.png - 4x4 tiles
# Processado P1426.png - 11x16 tiles
# Processado P0087.png - 11x9 tiles
# Processado P2584.png - 6x5 tiles
# Processado P2225.png - 4x3 tiles
# Processado P1959.png - 3x2 tiles
# Processado P1107.png - 2x2 tiles
# Processado P0430.png - 4x3 tiles
# Processado P2800.png - 7x7 tiles
# Processado P0907.png - 4x4 tiles
# Processado P0283.png - 2x3 tiles
# Processado P2359.png - 5x4 tiles
# Processado P0021.png - 7x6 tiles
# Processado P2130.png - 3x3 tiles
# Processado P2380.png - 4x5 tiles
# Processado P0219.png - 3x6 tiles
# Processado P0085.png - 5x6 tiles
# Processado P0819.png - 3x2 tiles
# Processado P0634.png - 2x2 tiles
# Processado P1251.png - 8x11 tiles
# Processado P2204.png - 4x2 tiles
# Processado P0734.png - 4x5 tiles
# Processado P1927.png - 6x3 tiles
# Processado P2627.png - 3x3 tiles
# Processado P1279.png - 8x8 tiles
# Processado P2039.png - 2x2 tiles
# Processado P0549.png - 2x2 tiles
# Processado P2755.png - 10x4 tiles
# Processado P2213.png - 3x4 tiles
# Processado P0908.png - 5x5 tiles
# Processado P1317.png - 8x8 tiles
# Processado P1006.png - 2x11 tiles
# Processado P2206.png - 4x3 tiles
# Processado P2304.png - 2x2 tiles
# Processado P2157.png - 4x3 tiles
# Processado P2751.png - 7x8 tiles
# Processado P1073.png - 3x3 tiles
# Processado P0232.png - 4x3 tiles
# Processado P0563.png - 3x3 tiles
# Processado P1795.png - 3x2 tiles
# Processado P1292.png - 8x8 tiles
# Processado P2387.png - 4x4 tiles
# Processado P1962.png - 3x2 tiles
# Processado P2438.png - 5x3 tiles
# Processado P1554.png - 8x8 tiles
# Processado P1211.png - 8x8 tiles
# Processado P0620.png - 4x2 tiles
# Copiado P2089.png sem fatiamento
# Processado P1697.png - 8x8 tiles
# Processado P1375.png - 7x8 tiles
# Processado P2704.png - 4x8 tiles
# Processado P1158.png - 11x13 tiles
# Processado P0828.png - 5x3 tiles
# Processado P2334.png - 4x5 tiles
# Processado P1214.png - 8x8 tiles
# Processado P2007.png - 9x5 tiles
# Processado P1451.png - 8x5 tiles
# Processado P1221.png - 8x8 tiles
# Processado P0593.png - 2x3 tiles
# Processado P0785.png - 7x5 tiles
# Processado P1132.png - 10x11 tiles
# Processado P1174.png - 12x12 tiles
# Processado P0947.png - 4x11 tiles
# Processado P1108.png - 6x7 tiles
# Processado P1515.png - 8x8 tiles
# Processado P2244.png - 3x3 tiles
# Processado P1816.png - 4x3 tiles
# Processado P2234.png - 4x3 tiles
# Processado P2419.png - 5x4 tiles
# Processado P2578.png - 3x3 tiles
# Processado P2753.png - 5x7 tiles
# Processado P1071.png - 7x5 tiles
# Processado P0389.png - 3x2 tiles
# Processado P0023.png - 10x5 tiles
# Processado P2264.png - 2x5 tiles
# Processado P1209.png - 8x8 tiles
# Processado P0095.png - 3x2 tiles
# Processado P1913.png - 4x3 tiles
# Processado P2311.png - 2x2 tiles
# Processado P1717.png - 8x8 tiles
# Processado P2227.png - 2x2 tiles
# Processado P0714.png - 2x2 tiles
# Processado P1709.png - 8x8 tiles
# Processado P2177.png - 3x2 tiles
# Processado P0896.png - 5x4 tiles
# Processado P2306.png - 2x2 tiles
# Processado P2436.png - 4x3 tiles
# Processado P2221.png - 2x2 tiles
# Processado P1117.png - 3x4 tiles
# Processado P2145.png - 3x2 tiles
# Processado P1683.png - 8x8 tiles
# Processado P0445.png - 3x2 tiles
# Processado P1653.png - 8x8 tiles
# Processado P0879.png - 6x7 tiles
# Processado P2377.png - 4x5 tiles
# Processado P2467.png - 4x5 tiles
# Processado P0610.png - 4x3 tiles
# Processado P1020.png - 2x5 tiles
# Processado P2154.png - 2x2 tiles
# Processado P0743.png - 2x4 tiles
# Processado P1791.png - 10x10 tiles
# Processado P0248.png - 3x2 tiles
# Processado P0612.png - 2x3 tiles
# Processado P0358.png - 2x3 tiles
# Processado P2729.png - 6x7 tiles
# Processado P0482.png - 2x2 tiles
# Processado P0392.png - 2x3 tiles
# Processado P0857.png - 4x3 tiles
# Processado P2747.png - 5x6 tiles
# Processado P0282.png - 2x3 tiles
# Processado P0860.png - 6x8 tiles
# Processado P0960.png - 4x4 tiles
# Processado P0617.png - 4x4 tiles
# Processado P1207.png - 8x11 tiles
# Processado P2228.png - 5x4 tiles
# Processado P0855.png - 2x3 tiles
# Processado P0294.png - 3x3 tiles
# Processado P2706.png - 3x4 tiles
# Processado P0762.png - 2x4 tiles
# Processado P2344.png - 4x5 tiles
# Processado P1935.png - 2x3 tiles
# Processado P1784.png - 4x3 tiles
# Processado P2258.png - 2x5 tiles
# Processado P0263.png - 2x2 tiles
# Processado P0424.png - 3x3 tiles
# Processado P0840.png - 4x7 tiles
# Processado P0881.png - 2x2 tiles
# Processado P0978.png - 4x4 tiles
# Processado P2199.png - 3x3 tiles
# Processado P0366.png - 3x2 tiles
# Processado P0851.png - 2x2 tiles
# Processado P0113.png - 9x8 tiles
# Processado P1308.png - 8x11 tiles
# Processado P0360.png - 2x2 tiles
# Processado P1783.png - 7x7 tiles
# Processado P1457.png - 10x11 tiles
# Processado P2685.png - 5x3 tiles
# Processado P1861.png - 8x4 tiles
# Processado P1444.png - 8x5 tiles
# Processado P0321.png - 4x4 tiles
# Processado P0979.png - 2x6 tiles
# Processado P1060.png - 4x5 tiles
# Processado P0697.png - 3x3 tiles
# Processado P0732.png - 3x4 tiles
# Processado P2428.png - 6x6 tiles
# Processado P1928.png - 2x2 tiles
# Processado P2240.png - 4x2 tiles
# Processado P0346.png - 6x9 tiles
# Processado P1724.png - 10x8 tiles
# Processado P1250.png - 8x8 tiles
# Processado P2327.png - 2x2 tiles
# Processado P2552.png - 8x6 tiles
# Processado P1659.png - 8x8 tiles
# Processado P2062.png - 2x2 tiles
# Processado P1851.png - 5x4 tiles
# Processado P1933.png - 3x4 tiles
# Processado P2343.png - 4x5 tiles
# Processado P0597.png - 5x2 tiles
# Processado P2289.png - 2x2 tiles
# Processado P0151.png - 2x2 tiles
# Processado P1938.png - 3x4 tiles
# Processado P2759.png - 10x18 tiles
# Processado P0407.png - 2x4 tiles
# Processado P0310.png - 4x6 tiles
# Processado P2613.png - 2x2 tiles
# Processado P1259.png - 8x8 tiles
# Processado P2655.png - 6x10 tiles
# Processado P1265.png - 8x11 tiles
# Processado P2458.png - 5x4 tiles
# Processado P0258.png - 3x2 tiles
# Processado P1641.png - 10x8 tiles
# Processado P0207.png - 3x2 tiles
# Processado P0401.png - 2x2 tiles
# Processado P0025.png - 9x9 tiles
# Processado P0270.png - 3x3 tiles
# Processado P1863.png - 7x6 tiles
# Processado P1875.png - 6x12 tiles
# Processado P1305.png - 8x11 tiles
# Processado P1337.png - 8x11 tiles
# Processado P0011.png - 3x3 tiles
# Processado P0582.png - 3x3 tiles
# Processado P2775.png - 6x9 tiles
# Processado P1618.png - 8x9 tiles
# Processado P2058.png - 3x2 tiles
# Copiado P1899.png sem fatiamento
# Processado P1059.png - 6x7 tiles
# Processado P0565.png - 3x3 tiles
# Processado P0036.png - 11x7 tiles
# Processado P2642.png - 11x14 tiles
# Processado P2390.png - 4x6 tiles
# Processado P0915.png - 4x3 tiles
# Processado P0327.png - 4x4 tiles
# Processado P0050.png - 7x5 tiles
# Processado P1094.png - 9x3 tiles
# Processado P1556.png - 8x9 tiles
# Processado P1321.png - 8x8 tiles
# Processado P0187.png - 3x5 tiles
# Processado P0630.png - 2x7 tiles
# Copiado P0641.png sem fatiamento
# Processado P0746.png - 2x4 tiles
# Processado P1482.png - 5x5 tiles
# Processado P2739.png - 6x8 tiles
# Processado P0001.png - 12x3 tiles
# Processado P1339.png - 8x8 tiles
# Processado P2005.png - 9x10 tiles
# Processado P0892.png - 5x5 tiles
# Processado P0416.png - 3x2 tiles
# Processado P0355.png - 2x2 tiles
# Processado P0094.png - 3x3 tiles
# Processado P1493.png - 10x9 tiles
# Processado P0436.png - 2x4 tiles
# Processado P0241.png - 3x3 tiles
# Processado P1670.png - 8x8 tiles
# Processado P0002.png - 5x5 tiles
# Processado P0381.png - 2x3 tiles
# Processado P0469.png - 2x2 tiles
# Processado P1087.png - 6x5 tiles
# Processado P0792.png - 3x3 tiles
# Processado P1793.png - 7x7 tiles
# Processado P0164.png - 3x3 tiles
# Processado P2639.png - 2x3 tiles
# Processado P1353.png - 8x8 tiles
# Copiado P2305.png sem fatiamento
# Processado P0076.png - 2x2 tiles
# Processado P0632.png - 3x6 tiles
# Processado P1703.png - 8x8 tiles
# Processado P1416.png - 5x6 tiles
# Processado P0018.png - 4x4 tiles
# Processado P0388.png - 3x2 tiles
# Processado P0313.png - 3x3 tiles
# Processado P1445.png - 7x11 tiles
# Processado P0238.png - 3x3 tiles
# Processado P0210.png - 3x5 tiles
# Processado P1859.png - 4x3 tiles
# Processado P2115.png - 3x2 tiles
# Processado P0693.png - 2x3 tiles
# Processado P1673.png - 10x8 tiles
# Processado P0252.png - 3x4 tiles
# Processado P2076.png - 3x4 tiles
# Processado P0562.png - 3x2 tiles
# Processado P0505.png - 4x2 tiles
# Processado P0692.png - 3x2 tiles
# Processado P0952.png - 4x12 tiles
# Processado P1893.png - 2x2 tiles
# Processado P2288.png - 10x6 tiles
# Processado P2558.png - 10x11 tiles
# Processado P0541.png - 3x3 tiles
# Processado P0596.png - 4x2 tiles
# Copiado P1987.png sem fatiamento
# Processado P1915.png - 4x2 tiles
# Processado P0520.png - 4x3 tiles
# Processado P0911.png - 4x3 tiles
# Processado P1092.png - 5x4 tiles
# Processado P2148.png - 3x2 tiles
# Processado P2725.png - 6x9 tiles
# Processado P2033.png - 4x4 tiles
# Processado P0315.png - 3x3 tiles
# Processado P1823.png - 6x4 tiles
# Processado P1509.png - 7x10 tiles
# Processado P0008.png - 3x3 tiles
# Processado P2485.png - 5x4 tiles
# Processado P2095.png - 3x3 tiles
# Processado P0324.png - 4x6 tiles
# Processado P0626.png - 4x2 tiles
# Processado P1868.png - 8x21 tiles
# Processado P1047.png - 2x2 tiles
# Processado P2512.png - 5x4 tiles
# Processado P0493.png - 2x2 tiles
# Processado P0111.png - 4x4 tiles
# Processado P0494.png - 4x6 tiles
# Copiado P0676.png sem fatiamento
# Processado P0139.png - 2x2 tiles
# Processado P0769.png - 4x3 tiles
# Processado P0226.png - 2x2 tiles
# Processado P2708.png - 6x6 tiles
# Processado P1775.png - 4x3 tiles
# Processado P0303.png - 2x2 tiles
# Processado P0317.png - 2x4 tiles
# Processado P2038.png - 2x2 tiles
# Processado P0343.png - 3x6 tiles
# Processado P2211.png - 6x9 tiles
# Processado P1016.png - 3x6 tiles
# Processado P1947.png - 2x2 tiles
# Processado P0503.png - 3x3 tiles
# Processado P1986.png - 3x2 tiles
# Processado P0367.png - 3x4 tiles
# Processado P1465.png - 5x5 tiles
# Processado P0029.png - 5x6 tiles
# Processado P1344.png - 8x11 tiles
# Processado P0236.png - 3x3 tiles
# Processado P1876.png - 4x3 tiles
# Processado P0142.png - 2x2 tiles
# Processado P2232.png - 4x3 tiles
# Processado P2507.png - 5x5 tiles
# Processado P1479.png - 5x5 tiles
# Processado P1274.png - 8x8 tiles
# Processado P2302.png - 2x2 tiles
# Processado P0727.png - 3x4 tiles
# Processado P0280.png - 2x2 tiles
# Processado P0362.png - 2x2 tiles
# Processado P1223.png - 8x11 tiles
# Processado P0638.png - 2x2 tiles
# Copiado P2326.png sem fatiamento
# Processado P0393.png - 2x2 tiles
# Processado P1765.png - 10x8 tiles
# Processado P1727.png - 8x8 tiles
# Processado P0757.png - 3x4 tiles
# Processado P1387.png - 9x14 tiles
# Processado P0922.png - 4x4 tiles
# Processado P0384.png - 2x2 tiles
# Processado P0458.png - 3x3 tiles
# Processado P0176.png - 2x2 tiles
# Processado P0042.png - 5x4 tiles
# Copiado P2080.png sem fatiamento
# Processado P2669.png - 3x4 tiles
# Processado P0825.png - 2x2 tiles
# Processado P2659.png - 4x6 tiles
# Processado P1374.png - 13x13 tiles
# Processado P0250.png - 4x3 tiles
# Processado P0103.png - 2x2 tiles
# Processado P1166.png - 10x7 tiles
# Processado P2523.png - 6x4 tiles
# Processado P2164.png - 6x10 tiles
# Processado P0925.png - 4x3 tiles
# Processado P2056.png - 2x2 tiles
# Processado P2616.png - 3x4 tiles
# Processado P0380.png - 2x2 tiles
# Processado P0895.png - 4x3 tiles
# Processado P0455.png - 2x3 tiles
# Processado P1419.png - 10x7 tiles
# Processado P0993.png - 3x5 tiles
# Processado P2067.png - 3x4 tiles
# Processado P1725.png - 8x8 tiles
# Processado P2490.png - 6x6 tiles
# Processado P2691.png - 13x12 tiles
# Processado P1105.png - 2x2 tiles
# Processado P2396.png - 4x5 tiles
# Processado P0572.png - 2x4 tiles
# Processado P2804.png - 5x8 tiles
# Processado P1388.png - 11x9 tiles
# Processado P1307.png - 8x8 tiles
# Copiado P2191.png sem fatiamento
# Processado P0724.png - 3x4 tiles
# Processado P0642.png - 3x2 tiles
# Processado P2471.png - 5x4 tiles
# Processado P0778.png - 3x4 tiles
# Processado P1414.png - 10x12 tiles
# Processado P1328.png - 8x8 tiles
# Processado P1726.png - 8x8 tiles
# Processado P0538.png - 3x5 tiles
# Processado P0605.png - 3x2 tiles
# Processado P1116.png - 4x13 tiles
# Processado P0829.png - 4x4 tiles
# Processado P0702.png - 2x3 tiles
# Processado P0533.png - 3x3 tiles
# Processado P0995.png - 4x2 tiles
# Processado P2662.png - 6x5 tiles
# Processado P0141.png - 4x9 tiles
# Copiado P1012.png sem fatiamento
# Processado P1505.png - 5x6 tiles
# Processado P1164.png - 9x6 tiles
# Processado P1540.png - 8x8 tiles
# Processado P0209.png - 4x8 tiles
# Copiado P1998.png sem fatiamento
# Processado P1740.png - 8x8 tiles
# Processado P2107.png - 2x2 tiles
# Processado P2576.png - 5x2 tiles
# Processado P1606.png - 8x9 tiles
# Processado P1526.png - 8x8 tiles
# Processado P1148.png - 11x10 tiles
# Processado P0350.png - 3x2 tiles
# Processado P1311.png - 8x8 tiles
# Processado P1245.png - 8x8 tiles
# Processado P2079.png - 2x2 tiles
# Processado P2626.png - 2x3 tiles
# Processado P1187.png - 2x2 tiles
# Processado P2173.png - 5x11 tiles
# Processado P0738.png - 4x2 tiles
# Processado P0159.png - 2x2 tiles
# Processado P2538.png - 5x4 tiles
# Processado P1674.png - 8x8 tiles
# Processado P0140.png - 3x3 tiles
# Processado P0928.png - 3x2 tiles
# Processado P1369.png - 8x11 tiles
# Processado P0700.png - 4x4 tiles
# Processado P0489.png - 2x2 tiles
# Processado P2049.png - 3x4 tiles
# Processado P0542.png - 2x2 tiles
# Processado P2454.png - 4x4 tiles
# Copiado P2259.png sem fatiamento
# Processado P0664.png - 3x3 tiles
# Processado P2631.png - 5x3 tiles
# Processado P0383.png - 2x3 tiles
# Processado P0760.png - 2x3 tiles
# Processado P1707.png - 8x8 tiles
# Processado P0275.png - 3x3 tiles
# Processado P0522.png - 4x2 tiles
# Processado P0716.png - 4x2 tiles
# Processado P0361.png - 2x2 tiles
# Processado P1842.png - 2x2 tiles
# Processado P1531.png - 8x9 tiles
# Processado P2379.png - 5x5 tiles
# Processado P2222.png - 3x2 tiles
# Processado P0731.png - 3x4 tiles
# Processado P1926.png - 4x2 tiles
# Processado P0848.png - 2x2 tiles
# Processado P2055.png - 3x3 tiles
# Processado P2522.png - 4x5 tiles
# Processado P1360.png - 8x8 tiles
# Processado P0890.png - 7x4 tiles
# Processado P0066.png - 7x7 tiles
# Processado P0768.png - 2x5 tiles
# Processado P0406.png - 3x2 tiles
# Processado P1892.png - 2x2 tiles
# Processado P0373.png - 2x2 tiles
# Processado P0818.png - 2x2 tiles
# Processado P2142.png - 3x3 tiles
# Processado P0980.png - 2x2 tiles
# Processado P0363.png - 3x2 tiles
# Processado P0149.png - 2x2 tiles
# Processado P2381.png - 5x5 tiles
# Processado P2355.png - 4x5 tiles
# Processado P1571.png - 10x8 tiles
# Processado P1309.png - 8x8 tiles
# Processado P2743.png - 9x9 tiles
# Processado P1909.png - 2x2 tiles
# Processado P2245.png - 3x3 tiles
# Processado P2801.png - 8x6 tiles
# Processado P0479.png - 2x2 tiles
# Processado P1856.png - 5x6 tiles
# Processado P0471.png - 2x2 tiles
# Processado P1602.png - 8x9 tiles
# Processado P2497.png - 5x5 tiles
# Processado P2237.png - 3x2 tiles
# Processado P0553.png - 2x4 tiles
# Processado P0464.png - 3x3 tiles
# Processado P0100.png - 2x2 tiles
# Processado P2644.png - 7x9 tiles
# Processado P0973.png - 3x7 tiles
# Processado P1704.png - 8x9 tiles
# Processado P1991.png - 2x4 tiles
# Processado P2565.png - 5x4 tiles
# Processado P0264.png - 2x2 tiles
# Processado P0619.png - 3x3 tiles
# Processado P2362.png - 4x5 tiles
# Processado P2324.png - 2x2 tiles
# Processado P0695.png - 3x3 tiles
# Processado P0595.png - 4x3 tiles
# Processado P0172.png - 4x6 tiles
# Processado P0371.png - 3x2 tiles
# Processado P0835.png - 3x6 tiles
# Processado P2250.png - 4x6 tiles
# Processado P0190.png - 3x6 tiles
# Processado P2651.png - 4x4 tiles
# Processado P0218.png - 6x7 tiles
# Processado P1003.png - 2x16 tiles
# Processado P2469.png - 4x4 tiles
# Processado P1258.png - 8x11 tiles
# Processado P0422.png - 2x2 tiles
# Processado P2053.png - 3x3 tiles
# Processado P0535.png - 3x2 tiles
# Processado P0569.png - 2x2 tiles
# Processado P1923.png - 3x3 tiles
# Processado P2632.png - 3x3 tiles
# Processado P0719.png - 3x4 tiles
# Processado P0821.png - 2x2 tiles
# Processado P1144.png - 5x3 tiles
# Processado P0913.png - 5x7 tiles
# Processado P1361.png - 8x8 tiles
# Processado P2030.png - 10x15 tiles
# Processado P1833.png - 2x3 tiles
# Processado P0379.png - 2x2 tiles
# Processado P0147.png - 3x4 tiles
# Processado P0948.png - 3x6 tiles
# Processado P1480.png - 6x5 tiles
# Processado P2676.png - 8x5 tiles
# Processado P1062.png - 4x7 tiles
# Processado P0122.png - 3x4 tiles
# Processado P1298.png - 8x8 tiles
# Processado P0215.png - 3x7 tiles
# Processado P2551.png - 9x9 tiles
# Processado P0221.png - 5x3 tiles
# Processado P2045.png - 2x2 tiles
# Processado P0289.png - 3x3 tiles
# Processado P2278.png - 3x4 tiles
# Processado P2162.png - 3x3 tiles
# Processado P1846.png - 3x3 tiles
# Processado P1680.png - 10x8 tiles
# Processado P2597.png - 4x3 tiles
# Processado P2618.png - 3x2 tiles
# Processado P1486.png - 3x3 tiles
# Processado P0689.png - 2x3 tiles
# Processado P1768.png - 8x8 tiles
# Processado P1418.png - 7x5 tiles
# Copiado P0078.png sem fatiamento
# Processado P0972.png - 3x5 tiles
# Processado P0646.png - 3x2 tiles
# Processado P1078.png - 5x4 tiles
# Processado P2260.png - 2x3 tiles
# Processado P1634.png - 8x9 tiles
# Processado P1689.png - 10x8 tiles
# Processado P1336.png - 8x11 tiles
# Processado P2516.png - 5x5 tiles
# Processado P1469.png - 4x5 tiles
# Processado P2805.png - 7x6 tiles
# Processado P1705.png - 8x8 tiles
# Processado P2118.png - 2x2 tiles
# Processado P1431.png - 6x8 tiles
# Processado P2219.png - 2x3 tiles
# Processado P1096.png - 3x9 tiles
# Processado P2637.png - 5x4 tiles
# Processado P1845.png - 7x8 tiles
# Processado P1895.png - 2x2 tiles
# Processado P2682.png - 9x6 tiles
# Processado P1208.png - 8x8 tiles
# Processado P0591.png - 3x3 tiles
# Processado P1121.png - 3x5 tiles
# Processado P1646.png - 8x9 tiles
# Processado P2764.png - 8x9 tiles
# Processado P0475.png - 2x3 tiles
# Processado P0477.png - 3x2 tiles
# Processado P1555.png - 8x8 tiles
# Processado P0419.png - 2x3 tiles
# Copiado P1198.png sem fatiamento
# Processado P1539.png - 8x8 tiles
# Processado P1607.png - 8x8 tiles
# Processado P2532.png - 6x6 tiles
# Processado P2650.png - 4x6 tiles
# Processado P0775.png - 4x4 tiles
# Processado P0158.png - 6x7 tiles
# Processado P1171.png - 11x14 tiles
# Processado P1785.png - 3x3 tiles
# Processado P1428.png - 6x7 tiles
# Processado P0804.png - 2x3 tiles
# Processado P1827.png - 3x4 tiles
# Processado P2022.png - 4x2 tiles
# Processado P2192.png - 4x6 tiles
# Processado P1794.png - 9x7 tiles
# Processado P0065.png - 7x5 tiles
# Processado P1368.png - 8x8 tiles
# Processado P2720.png - 5x9 tiles
# Processado P1645.png - 8x8 tiles
# Processado P0527.png - 2x3 tiles
# Processado P1514.png - 8x8 tiles
# Processado P2109.png - 2x2 tiles
# Processado P1582.png - 10x8 tiles
# Processado P0426.png - 2x2 tiles
# Processado P2210.png - 3x9 tiles
# Processado P0083.png - 9x11 tiles
# Processado P0058.png - 3x3 tiles
# Processado P2251.png - 3x3 tiles
# Processado P1686.png - 8x9 tiles
# Processado P0571.png - 5x3 tiles
# Processado P0260.png - 3x4 tiles
# Processado P2761.png - 9x10 tiles
# Processado P0548.png - 3x2 tiles
# Processado P0357.png - 3x3 tiles
# Processado P2566.png - 3x3 tiles
# Processado P1587.png - 8x8 tiles
# Processado P0766.png - 2x2 tiles
# Processado P1994.png - 2x2 tiles
# Processado P2790.png - 7x10 tiles
# Processado P1779.png - 2x2 tiles
# Processado P0869.png - 3x2 tiles
# Processado P2430.png - 5x4 tiles
# Processado P2741.png - 6x6 tiles
# Processado P2388.png - 4x5 tiles
# Processado P2494.png - 5x4 tiles
# Processado P1907.png - 2x2 tiles
# Processado P0926.png - 5x5 tiles
# Processado P0133.png - 3x3 tiles
# Processado P0005.png - 2x2 tiles
# Processado P0885.png - 5x2 tiles
# Processado P0713.png - 4x5 tiles
# Processado P2783.png - 3x3 tiles
# Processado P0071.png - 2x2 tiles
# Processado P1563.png - 8x8 tiles
# Processado P1658.png - 10x9 tiles
# Processado P1450.png - 8x6 tiles
# Processado P2269.png - 3x3 tiles
# Processado P0425.png - 3x2 tiles
# Processado P0914.png - 4x4 tiles
# Processado P2503.png - 5x4 tiles
# Processado P1682.png - 8x8 tiles
# Processado P1517.png - 8x9 tiles
# Processado P1291.png - 8x8 tiles
# Processado P1173.png - 8x7 tiles
# Processado P2693.png - 5x5 tiles
# Processado P2727.png - 3x4 tiles
# Processado P0568.png - 5x2 tiles
# Processado P1640.png - 10x8 tiles
# Processado P2705.png - 5x3 tiles
# Processado P1552.png - 8x8 tiles
# Processado P0918.png - 2x2 tiles
# Processado P2370.png - 4x4 tiles
# Processado P1267.png - 8x8 tiles
# Processado P0484.png - 2x2 tiles
# Processado P0726.png - 3x4 tiles
# Processado P2496.png - 4x4 tiles
# Processado P1955.png - 4x5 tiles
# Processado P2482.png - 5x5 tiles
# Processado P2071.png - 2x2 tiles
# Processado P1299.png - 8x8 tiles
# Processado P0656.png - 2x3 tiles
# Processado P0405.png - 3x2 tiles
# Processado P0276.png - 3x3 tiles
# Processado P0874.png - 5x3 tiles
# Processado P1255.png - 8x8 tiles
# Processado P1669.png - 8x9 tiles
# Processado P0049.png - 4x4 tiles
# Processado P2622.png - 3x5 tiles
# Processado P0387.png - 2x4 tiles
# Processado P1719.png - 8x9 tiles
# Processado P1843.png - 2x2 tiles
# Processado P2074.png - 4x3 tiles
# Processado P0666.png - 2x2 tiles
# Processado P1140.png - 10x12 tiles
# Processado P1908.png - 3x2 tiles
# Processado P1964.png - 4x3 tiles
# Processado P1521.png - 8x8 tiles
# Processado P1287.png - 8x11 tiles
# Processado P1519.png - 8x8 tiles
# Processado P2010.png - 2x2 tiles
# Processado P0957.png - 3x7 tiles
# Processado P0827.png - 4x3 tiles
# Processado P2087.png - 2x3 tiles
# Processado P2545.png - 5x6 tiles
# Processado P2395.png - 5x6 tiles
# Processado P0601.png - 2x2 tiles
# Processado P1114.png - 4x10 tiles
# Processado P2536.png - 5x5 tiles
# Processado P1043.png - 3x3 tiles
# Processado P1996.png - 3x4 tiles
# Processado P2138.png - 5x5 tiles
# Processado P1343.png - 8x8 tiles
# Processado P0220.png - 3x4 tiles
# Processado P0905.png - 3x2 tiles
# Processado P2432.png - 4x6 tiles
# Processado P0603.png - 4x2 tiles
# Processado P0759.png - 3x3 tiles
# Processado P1871.png - 10x24 tiles
# Processado P2131.png - 3x3 tiles
# Processado P0281.png - 3x2 tiles
# Processado P0826.png - 3x2 tiles
# Processado P0537.png - 5x3 tiles
# Copiado P2029.png sem fatiamento
# Processado P1558.png - 8x8 tiles
# Processado P0780.png - 4x3 tiles
# Processado P1614.png - 8x8 tiles
# Processado P1990.png - 3x3 tiles
# Processado P2710.png - 5x4 tiles
# Processado P1351.png - 8x11 tiles
# Processado P1392.png - 8x9 tiles
# Processado P2472.png - 5x4 tiles
# Processado P1872.png - 10x8 tiles
# Processado P2415.png - 5x4 tiles
# Processado P0951.png - 2x13 tiles
# Processado P1049.png - 11x4 tiles
# Processado P1165.png - 9x6 tiles
# Processado P1288.png - 8x8 tiles
# Processado P0044.png - 4x4 tiles
# Processado P0415.png - 2x3 tiles
# Processado P0754.png - 3x2 tiles
# Processado P0098.png - 3x2 tiles
# Processado P0803.png - 2x3 tiles
# Processado P0934.png - 3x6 tiles
# Processado P2550.png - 9x10 tiles
# Processado P1951.png - 3x4 tiles
# Processado P1364.png - 8x8 tiles
# Processado P2611.png - 4x7 tiles
# Processado P1534.png - 8x9 tiles
# Processado P0421.png - 3x3 tiles
# Processado P1070.png - 8x9 tiles
# Processado P0893.png - 10x4 tiles
# Processado P2534.png - 6x6 tiles
# Processado P0334.png - 4x6 tiles
# Processado P2159.png - 3x4 tiles
# Processado P0296.png - 3x3 tiles
# Processado P2495.png - 6x4 tiles
# Processado P2663.png - 5x5 tiles
# Processado P1498.png - 7x5 tiles
# Processado P1675.png - 8x8 tiles
# Processado P0314.png - 3x3 tiles
# Processado P0703.png - 4x3 tiles
# Processado P2452.png - 5x4 tiles
# Processado P1142.png - 10x8 tiles
# Processado P2253.png - 3x7 tiles
# Processado P0068.png - 2x2 tiles
# Processado P1758.png - 8x9 tiles
# Processado P1801.png - 4x4 tiles
# Processado P2769.png - 8x6 tiles
# Processado P0975.png - 4x5 tiles
# Processado P1325.png - 8x8 tiles
# Processado P0894.png - 4x7 tiles
# Processado P1449.png - 7x5 tiles
# Processado P0442.png - 2x3 tiles
# Processado P2673.png - 6x5 tiles
# Processado P1297.png - 8x8 tiles
# Processado P1319.png - 8x11 tiles
# Processado P0293.png - 3x3 tiles
# Processado P1037.png - 7x4 tiles
# Processado P1098.png - 5x5 tiles
# Processado P1015.png - 2x8 tiles
# Processado P2687.png - 11x6 tiles
# Processado P0755.png - 3x4 tiles
# Processado P1421.png - 2x2 tiles
# Processado P2207.png - 7x7 tiles
# Processado P2160.png - 4x3 tiles
# Processado P1600.png - 8x8 tiles
# Processado P0010.png - 4x4 tiles
# Copiado P2185.png sem fatiamento
# Processado P2034.png - 3x3 tiles
# Processado P1748.png - 8x8 tiles
# Processado P1615.png - 8x8 tiles
# Processado P0022.png - 13x8 tiles
# Processado P1662.png - 8x8 tiles
# Processado P2371.png - 5x4 tiles
# Processado P0109.png - 3x3 tiles
# Processado P1550.png - 8x8 tiles
# Processado P0063.png - 6x6 tiles
# Processado P0093.png - 3x2 tiles
# Copiado P2134.png sem fatiamento
# Processado P1639.png - 10x8 tiles
# Processado P1079.png - 4x3 tiles
# Processado P1910.png - 2x2 tiles
# Processado P0723.png - 3x3 tiles
# Processado P1446.png - 8x4 tiles
# Processado P2073.png - 3x2 tiles
# Processado P2456.png - 6x4 tiles
# Processado P1929.png - 5x3 tiles
# Processado P1617.png - 8x8 tiles
# Processado P0733.png - 2x7 tiles
# Processado P0292.png - 2x3 tiles
# Processado P1300.png - 8x11 tiles
# Processado P1365.png - 8x8 tiles
# Processado P1551.png - 8x8 tiles
# Processado P0946.png - 5x7 tiles
# Processado P1052.png - 2x3 tiles
# Processado P2368.png - 5x6 tiles
# Processado P0546.png - 3x2 tiles
# Processado P2048.png - 4x4 tiles
# Processado P0428.png - 3x2 tiles
# Processado P2590.png - 3x3 tiles
# Processado P0340.png - 3x6 tiles
# Processado P1354.png - 8x8 tiles
# Processado P2427.png - 6x6 tiles
# Processado P1743.png - 10x9 tiles
# Processado P0850.png - 2x3 tiles
# Processado P1466.png - 12x13 tiles
# Processado P2328.png - 2x2 tiles
# Processado P0136.png - 6x6 tiles
# Processado P1977.png - 4x4 tiles
# Processado P1501.png - 8x4 tiles
# Processado P1487.png - 3x4 tiles
# Processado P0963.png - 2x5 tiles
# Processado P1438.png - 9x6 tiles
# Processado P1295.png - 8x11 tiles
# Processado P0144.png - 2x2 tiles
# Processado P0832.png - 3x2 tiles
# Processado P1807.png - 3x3 tiles
# Processado P1850.png - 4x3 tiles
# Processado P0744.png - 3x3 tiles
# Processado P2417.png - 5x3 tiles
# Processado P0459.png - 2x2 tiles
# Processado P1484.png - 5x4 tiles
# Processado P0888.png - 3x13 tiles
# Processado P0096.png - 3x2 tiles
# Processado P0614.png - 3x2 tiles
# Processado P2664.png - 5x4 tiles
# Processado P0898.png - 8x6 tiles
# Processado P1507.png - 4x3 tiles
# Processado P0370.png - 2x2 tiles
# Processado P2392.png - 4x4 tiles
# Processado P1249.png - 8x8 tiles
# Processado P1812.png - 4x3 tiles
# Processado P1989.png - 3x2 tiles
# Processado P0487.png - 3x3 tiles
# Processado P1900.png - 2x2 tiles
# Processado P1948.png - 2x3 tiles
# Processado P1481.png - 7x6 tiles
# Processado P0722.png - 3x2 tiles
# Processado P1152.png - 8x5 tiles
# Processado P1159.png - 9x7 tiles
# Processado P1869.png - 10x15 tiles
# Processado P0986.png - 5x3 tiles
# Processado P1698.png - 8x8 tiles
# Processado P0332.png - 4x5 tiles
# Processado P0483.png - 2x3 tiles
# Processado P1599.png - 10x9 tiles
# Processado P0413.png - 3x2 tiles
# Processado P2373.png - 5x5 tiles
# Processado P0378.png - 3x3 tiles
# Copiado P2133.png sem fatiamento
# Processado P1217.png - 8x8 tiles
# Processado P1019.png - 7x9 tiles
# Processado P1691.png - 8x8 tiles
# Processado P2020.png - 2x2 tiles
# Processado P1778.png - 6x7 tiles
# Processado P1954.png - 3x2 tiles
# Processado P2422.png - 6x5 tiles
# Processado P2257.png - 3x2 tiles
# Processado P2090.png - 3x2 tiles
# Processado P1084.png - 3x3 tiles
# Processado P0849.png - 3x4 tiles
# Processado P2287.png - 5x5 tiles
# Processado P1322.png - 8x11 tiles
# Processado P2557.png - 8x10 tiles
# Processado P0202.png - 3x3 tiles
# Processado P0941.png - 2x6 tiles
# Processado P1708.png - 8x8 tiles
# Processado P2653.png - 6x5 tiles
# Processado P0437.png - 2x3 tiles
# Processado P0229.png - 3x3 tiles
# Processado P0468.png - 3x2 tiles
# Processado P1408.png - 11x15 tiles
# Processado P0504.png - 3x4 tiles
# Processado P1902.png - 2x2 tiles
# Processado P2349.png - 4x4 tiles
# Processado P2634.png - 3x4 tiles
# Processado P0223.png - 3x4 tiles
# Processado P0054.png - 5x5 tiles
# Processado P0152.png - 2x2 tiles
# Processado P1470.png - 12x11 tiles
# Processado P2026.png - 6x2 tiles
# Processado P1475.png - 2x2 tiles
# Processado P2418.png - 5x4 tiles
# Processado P0637.png - 2x2 tiles
# Processado P2444.png - 4x4 tiles
# Processado P1524.png - 8x8 tiles
# Processado P0178.png - 4x4 tiles
# Processado P2520.png - 5x5 tiles
# Processado P2702.png - 5x4 tiles
# Processado P0699.png - 2x2 tiles
# Processado P0580.png - 2x2 tiles
# Processado P2671.png - 6x6 tiles
# Processado P0391.png - 2x3 tiles
# Processado P0899.png - 4x5 tiles
# Processado P2518.png - 5x4 tiles
# Processado P2248.png - 2x2 tiles
# Processado P2594.png - 6x4 tiles
# Processado P1437.png - 14x6 tiles
# Processado P0244.png - 2x3 tiles
# Processado P0440.png - 3x4 tiles
# Processado P1744.png - 8x8 tiles
# Processado P0116.png - 2x2 tiles
# Copiado P0126.png sem fatiamento
# Processado P2514.png - 6x4 tiles
# Processado P0871.png - 6x5 tiles
# Processado P0201.png - 3x3 tiles
# Processado P0435.png - 3x2 tiles
# Processado P0668.png - 2x2 tiles
# Processado P0806.png - 3x3 tiles
# Processado P1945.png - 4x4 tiles
# Processado P0212.png - 2x2 tiles
# Processado P0227.png - 3x5 tiles
# Processado P2280.png - 11x9 tiles
# Processado P0794.png - 3x4 tiles
# Processado P1652.png - 8x8 tiles
# Processado P2332.png - 5x6 tiles
# Processado P2787.png - 8x4 tiles
# Processado P1241.png - 8x8 tiles
# Processado P2756.png - 9x10 tiles
# Processado P1589.png - 8x8 tiles
# Processado P1736.png - 10x9 tiles
# Processado P1497.png - 9x7 tiles
# Processado P1866.png - 7x6 tiles
# Processado P1401.png - 7x9 tiles
# Processado P1969.png - 4x3 tiles
# Processado P2612.png - 9x14 tiles
# Processado P1609.png - 8x9 tiles
# Processado P1010.png - 3x5 tiles
# Processado P1832.png - 5x3 tiles
# Processado P2513.png - 5x4 tiles
# Processado P1333.png - 8x8 tiles
# Processado P2335.png - 5x5 tiles
# Processado P0171.png - 3x6 tiles
# Processado P0235.png - 2x5 tiles
# Copiado P2151.png sem fatiamento
# Processado P1942.png - 3x3 tiles
# Processado P2569.png - 4x2 tiles
# Processado P1089.png - 2x5 tiles
# Processado P0012.png - 4x6 tiles
# Processado P0823.png - 5x4 tiles
# Copiado P1110.png sem fatiamento
# Processado P2797.png - 4x2 tiles
# Processado P0607.png - 4x2 tiles
# Processado P0517.png - 3x3 tiles
# Processado P1080.png - 7x4 tiles
# Processado P1747.png - 8x8 tiles
# Processado P0867.png - 5x6 tiles
# Processado P0531.png - 3x5 tiles
# Processado P0344.png - 4x4 tiles
# Processado P1420.png - 3x4 tiles
# Processado P1608.png - 8x8 tiles
# Processado P2281.png - 8x8 tiles
# Processado P2416.png - 5x4 tiles
# Processado P1205.png - 8x8 tiles
# Processado P0030.png - 5x6 tiles
# Processado P2266.png - 3x2 tiles
# Processado P1338.png - 8x8 tiles
# Processado P0119.png - 6x6 tiles
# Processado P1489.png - 10x10 tiles
# Processado P0020.png - 9x10 tiles
# Copiado P1932.png sem fatiamento
# Processado P1026.png - 4x4 tiles
# Processado P2437.png - 4x4 tiles
# Processado P2665.png - 5x6 tiles
# Processado P0909.png - 6x5 tiles
# Processado P0999.png - 2x5 tiles
# Processado P1533.png - 8x8 tiles
# Processado P1391.png - 8x13 tiles
# Processado P2505.png - 5x5 tiles
# Processado P2017.png - 2x3 tiles
# Processado P0272.png - 2x2 tiles
# Processado P0779.png - 2x2 tiles
# Processado P0188.png - 5x4 tiles
# Processado P1359.png - 8x8 tiles
# Processado P0991.png - 4x5 tiles
# Processado P1656.png - 10x8 tiles
# Processado P0337.png - 3x7 tiles
# Processado P0618.png - 3x3 tiles
# Processado P0204.png - 3x2 tiles
# Processado P0870.png - 3x2 tiles
# Processado P0450.png - 2x2 tiles
# Processado P0512.png - 2x2 tiles
# Processado P1460.png - 4x4 tiles
# Processado P0573.png - 3x3 tiles
# Processado P1714.png - 8x9 tiles
# Processado P2205.png - 5x3 tiles
# Processado P1382.png - 15x10 tiles
# Processado P1867.png - 5x14 tiles
# Processado P1170.png - 16x9 tiles
# Processado P1243.png - 8x8 tiles
# Processado P0677.png - 2x2 tiles
# Processado P1931.png - 4x3 tiles
# Processado P1849.png - 6x6 tiles
# Processado P1906.png - 2x2 tiles
# Processado P2149.png - 2x2 tiles
# Processado P2696.png - 5x6 tiles
# Processado P0944.png - 2x7 tiles
# Processado P1464.png - 10x8 tiles
# Processado P2339.png - 5x5 tiles
# Processado P1818.png - 3x5 tiles
# Processado P0653.png - 3x3 tiles
# Processado P2382.png - 4x5 tiles
# Processado P0711.png - 2x2 tiles
# Processado P2301.png - 2x2 tiles
# Processado P1393.png - 13x12 tiles
# Processado P1881.png - 2x2 tiles
# Processado P1139.png - 13x18 tiles
# Processado P1357.png - 8x8 tiles
# Processado P2527.png - 6x5 tiles
# Processado P0556.png - 4x2 tiles
# Processado P2719.png - 5x9 tiles
# Processado P1389.png - 11x12 tiles
# Processado P2065.png - 3x2 tiles
# Processado P1980.png - 4x3 tiles
# Processado P1412.png - 6x13 tiles
# Processado P0781.png - 3x2 tiles
# Processado P2002.png - 4x3 tiles
# Processado P0883.png - 3x3 tiles
# Processado P1350.png - 8x8 tiles
# Processado P0625.png - 2x3 tiles
# Processado P0162.png - 3x3 tiles
# Processado P0940.png - 3x3 tiles
# Processado P1199.png - 2x2 tiles
# Processado P2466.png - 4x4 tiles
# Processado P2190.png - 3x2 tiles
# Processado P1232.png - 8x8 tiles
# Processado P0745.png - 2x4 tiles
# Processado P0510.png - 2x3 tiles
# Processado P2614.png - 3x4 tiles
# Processado P2114.png - 2x2 tiles
# Processado P0875.png - 4x6 tiles
# Processado P2465.png - 5x4 tiles
# Processado P2132.png - 2x2 tiles
# Processado P2143.png - 2x2 tiles
# Processado P0338.png - 3x6 tiles
# Processado P0418.png - 2x3 tiles
# Processado P1773.png - 3x2 tiles
# Processado P0906.png - 4x4 tiles
# Processado P1238.png - 8x8 tiles
# Processado P1453.png - 4x5 tiles
# Processado P2356.png - 4x5 tiles
# Copiado P1917.png sem fatiamento
# Processado P2275.png - 5x7 tiles
# Processado P2364.png - 5x5 tiles
# Processado P0691.png - 2x2 tiles
# Processado P0443.png - 3x3 tiles
# Processado P2283.png - 5x5 tiles
# Processado P0254.png - 4x5 tiles
# Processado P1864.png - 3x4 tiles
# Processado P1776.png - 3x3 tiles
# Processado P1848.png - 5x4 tiles
# Processado P0777.png - 3x4 tiles
# Processado P0685.png - 4x4 tiles
# Processado P2389.png - 4x5 tiles
# Processado P1272.png - 8x11 tiles
# Processado P1837.png - 4x3 tiles
# Processado P1912.png - 3x2 tiles
# Processado P0920.png - 4x3 tiles
# Processado P2600.png - 5x4 tiles
# Processado P2203.png - 4x3 tiles
# Copiado P2180.png sem fatiamento
# Copiado P2125.png sem fatiamento
# Processado P0163.png - 2x2 tiles
# Processado P1276.png - 8x8 tiles
# Processado P0481.png - 2x2 tiles
# Processado P0853.png - 3x3 tiles
# Processado P1256.png - 8x8 tiles
# Processado P2348.png - 3x3 tiles
# Processado P2740.png - 5x8 tiles
# Processado P1191.png - 2x2 tiles
# Processado P2742.png - 5x5 tiles
# Processado P2601.png - 7x6 tiles
# Copiado P2303.png sem fatiamento
# Processado P0649.png - 2x2 tiles
# Processado P2004.png - 4x3 tiles
# Processado P2086.png - 3x3 tiles
# Processando val...
# Processado P2547.png - 5x8 tiles
# Processado P0336.png - 3x6 tiles
# Processado P1512.png - 4x4 tiles
# Processado P1213.png - 8x11 tiles
# Processado P2481.png - 5x5 tiles
# Processado P0936.png - 3x7 tiles
# Processado P1246.png - 8x8 tiles
# Processado P0949.png - 2x6 tiles
# Processado P1513.png - 9x6 tiles
# Processado P1905.png - 2x2 tiles
# Processado P2271.png - 7x13 tiles
# Processado P0189.png - 2x2 tiles
# Processado P0577.png - 3x2 tiles
# Processado P1149.png - 9x7 tiles
# Processado P0168.png - 4x5 tiles
# Processado P0964.png - 3x7 tiles
# Processado P2595.png - 4x2 tiles
# Processado P2429.png - 6x5 tiles
# Processado P0179.png - 9x10 tiles
# Processado P2385.png - 4x5 tiles
# Processado P1732.png - 8x9 tiles
# Processado P2088.png - 3x2 tiles
# Processado P1492.png - 6x4 tiles
# Processado P2577.png - 3x3 tiles
# Processado P1478.png - 4x4 tiles
# Processado P1432.png - 9x7 tiles
# Processado P0715.png - 4x3 tiles
# Processado P2093.png - 4x3 tiles
# Processado P0249.png - 4x2 tiles
# Processado P1720.png - 8x8 tiles
# Processado P2570.png - 3x4 tiles
# Processado P1377.png - 8x8 tiles
# Processado P1651.png - 8x8 tiles
# Processado P0353.png - 3x3 tiles
# Processado P0262.png - 5x5 tiles
# Processado P1240.png - 8x8 tiles
# Processado P0257.png - 4x3 tiles
# Processado P0123.png - 3x2 tiles
# Processado P0004.png - 3x2 tiles
# Processado P2778.png - 7x6 tiles
# Processado P1342.png - 8x8 tiles
# Processado P0932.png - 3x3 tiles
# Processado P0795.png - 5x4 tiles
# Processado P2791.png - 12x10 tiles
# Processado P1275.png - 8x8 tiles
# Processado P2215.png - 2x2 tiles
# Processado P2337.png - 5x5 tiles
# Processado P2124.png - 3x3 tiles
# Processado P1647.png - 8x8 tiles
# Processado P0329.png - 2x2 tiles
# Processado P0712.png - 3x2 tiles
# Copiado P0075.png sem fatiamento
# Processado P2003.png - 4x3 tiles
# Processado P0228.png - 2x3 tiles
# Processado P1429.png - 6x7 tiles
# Processado P1529.png - 8x8 tiles
# Processado P0374.png - 3x3 tiles
# Processado P1672.png - 10x8 tiles
# Processado P0432.png - 2x2 tiles
# Processado P0104.png - 3x2 tiles
# Processado P2098.png - 2x2 tiles
# Processado P1473.png - 2x3 tiles
# Processado P0822.png - 2x3 tiles
# Processado P0882.png - 5x2 tiles
# Processado P2239.png - 2x2 tiles
# Processado P1610.png - 8x8 tiles
# Processado P1178.png - 9x9 tiles
# Processado P1212.png - 8x8 tiles
# Processado P0961.png - 3x12 tiles
# Processado P0300.png - 2x3 tiles
# Processado P0660.png - 2x3 tiles
# Processado P1021.png - 2x4 tiles
# Processado P0706.png - 3x3 tiles
# Processado P0613.png - 2x3 tiles
# Processado P1541.png - 8x8 tiles
# Processado P0486.png - 2x3 tiles
# Processado P1904.png - 2x2 tiles
# Processado P2236.png - 2x3 tiles
# Processado P2375.png - 5x4 tiles
# Processado P0499.png - 3x3 tiles
# Processado P0175.png - 3x2 tiles
# Processado P1888.png - 2x2 tiles
# Processado P2011.png - 3x2 tiles
# Processado P0990.png - 5x5 tiles
# Processado P1242.png - 8x8 tiles
# Processado P1095.png - 5x11 tiles
# Processado P1371.png - 8x8 tiles
# Processado P1960.png - 4x3 tiles
# Processado P1373.png - 8x8 tiles
# Processado P2462.png - 5x4 tiles
# Processado P1787.png - 3x2 tiles
# Processado P1751.png - 8x8 tiles
# Processado P1950.png - 2x2 tiles
# Processado P0864.png - 4x6 tiles
# Processado P1273.png - 8x11 tiles
# Processado P2714.png - 5x9 tiles
# Processado P1623.png - 10x8 tiles
# Processado P1103.png - 4x3 tiles
# Processado P2455.png - 5x4 tiles
# Processado P2255.png - 2x2 tiles
# Processado P2477.png - 5x4 tiles
# Processado P1518.png - 8x8 tiles
# Processado P0910.png - 4x5 tiles
# Processado P2220.png - 2x3 tiles
# Processado P1506.png - 6x7 tiles
# Processado P0650.png - 2x2 tiles
# Processado P1911.png - 2x2 tiles
# Processado P1860.png - 4x4 tiles
# Processado P0799.png - 4x3 tiles
# Processado P2593.png - 4x3 tiles
# Processado P2322.png - 2x2 tiles
# Processado P0457.png - 2x3 tiles
# Processado P0246.png - 2x2 tiles
# Processado P1122.png - 6x14 tiles
# Processado P1995.png - 3x5 tiles
# Processado P0801.png - 4x7 tiles
# Processado P0161.png - 6x6 tiles
# Processado P2155.png - 2x2 tiles
# Processado P1086.png - 3x2 tiles
# Processado P2378.png - 5x6 tiles
# Processado P0081.png - 2x2 tiles
# Processado P1957.png - 4x4 tiles
# Processado P2342.png - 5x4 tiles
# Processado P0583.png - 2x5 tiles
# Processado P0242.png - 3x2 tiles
# Processado P0969.png - 2x2 tiles
# Processado P0305.png - 2x2 tiles
# Processado P1596.png - 10x8 tiles
# Copiado P2198.png sem fatiamento
# Processado P0833.png - 3x4 tiles
# Processado P2630.png - 3x4 tiles
# Processado P2126.png - 3x2 tiles
# Processado P1065.png - 5x9 tiles
# Processado P0131.png - 3x3 tiles
# Processado P1601.png - 8x8 tiles
# Processado P1088.png - 4x4 tiles
# Processado P1009.png - 3x8 tiles
# Processado P1700.png - 8x8 tiles
# Processado P2608.png - 5x5 tiles
# Processado P1584.png - 10x9 tiles
# Processado P2413.png - 4x5 tiles
# Processado P1189.png - 2x2 tiles
# Processado P2617.png - 2x3 tiles
# Processado P2111.png - 2x2 tiles
# Processado P1566.png - 8x8 tiles
# Processado P2129.png - 3x2 tiles
# Processado P0047.png - 5x3 tiles
# Processado P2781.png - 5x7 tiles
# Processado P2488.png - 5x5 tiles
# Processado P1133.png - 3x3 tiles
# Processado P0683.png - 5x4 tiles
# Processado P0887.png - 6x5 tiles
# Processado P1029.png - 4x6 tiles
# Processado P1821.png - 3x2 tiles
# Processado P1268.png - 8x8 tiles
# Processado P2582.png - 4x4 tiles
# Processado P1090.png - 3x5 tiles
# Processado P0466.png - 3x3 tiles
# Processado P0331.png - 5x5 tiles
# Processado P2478.png - 4x4 tiles
# Processado P2169.png - 2x2 tiles
# Processado P0261.png - 3x3 tiles
# Processado P0550.png - 2x3 tiles
# Processado P2450.png - 4x4 tiles
# Processado P1452.png - 2x2 tiles
# Processado P1380.png - 10x9 tiles
# Copiado P1825.png sem fatiamento
# Processado P0359.png - 2x2 tiles
# Processado P2580.png - 4x2 tiles
# Processado P2420.png - 5x4 tiles
# Processado P2771.png - 4x5 tiles
# Processado P2695.png - 5x8 tiles
# Processado P0559.png - 2x2 tiles
# Processado P0815.png - 2x3 tiles
# Processado P0837.png - 6x4 tiles
# Processado P0729.png - 3x2 tiles
# Processado P0589.png - 5x2 tiles
# Processado P0117.png - 3x3 tiles
# Processado P0647.png - 2x2 tiles
# Processado P1099.png - 3x2 tiles
# Processado P0659.png - 3x2 tiles
# Processado P0003.png - 2x3 tiles
# Processado P0604.png - 2x3 tiles
# Processado P1752.png - 8x8 tiles
# Processado P0557.png - 3x5 tiles
# Processado P1650.png - 8x9 tiles
# Processado P1314.png - 8x8 tiles
# Processado P1023.png - 3x8 tiles
# Processado P0796.png - 5x2 tiles
# Processado P0998.png - 3x12 tiles
# Processado P1476.png - 4x5 tiles
# Processado P2404.png - 9x11 tiles
# Processado P1878.png - 3x2 tiles
# Processado P2285.png - 8x8 tiles
# Processado P1278.png - 8x11 tiles
# Processado P1754.png - 10x8 tiles
# Processado P0791.png - 3x3 tiles
# Processado P0749.png - 2x3 tiles
# Processado P1376.png - 11x10 tiles
# Processado P2758.png - 9x15 tiles
# Processado P0651.png - 3x2 tiles
# Processado P0150.png - 2x2 tiles
# Processado P2745.png - 5x8 tiles
# Processado P0342.png - 2x2 tiles
# Processado P1234.png - 8x8 tiles
# Processado P0838.png - 4x3 tiles
# Processado P0974.png - 3x5 tiles
# Processado P2709.png - 5x6 tiles
# Processado P1581.png - 8x9 tiles
# Processado P1738.png - 8x8 tiles
# Processado P0525.png - 3x2 tiles
# Processado P0385.png - 2x2 tiles
# Processado P0526.png - 4x5 tiles
# Processado P0396.png - 3x3 tiles
# Processado P2645.png - 7x9 tiles
# Processado P0789.png - 3x4 tiles
# Processado P1561.png - 8x9 tiles
# Processado P0970.png - 3x9 tiles
# Processado P1770.png - 10x8 tiles
# Processado P0770.png - 3x4 tiles
# Processado P0056.png - 2x2 tiles
# Processado P2286.png - 5x6 tiles
# Processado P1643.png - 8x8 tiles
# Processado P1666.png - 8x8 tiles
# Processado P1370.png - 8x8 tiles
# Processado P2446.png - 5x4 tiles
# Processado P1091.png - 2x2 tiles
# Processado P2587.png - 5x6 tiles
# Processado P1809.png - 14x15 tiles
# Processado P0841.png - 6x5 tiles
# Processado P0904.png - 2x3 tiles
# Processado P1508.png - 8x4 tiles
# Processado P2721.png - 5x9 tiles
# Processado P1398.png - 13x8 tiles
# Processado P2150.png - 3x2 tiles
# Processado P2167.png - 3x3 tiles
# Processado P2754.png - 8x7 tiles
# Processado P1051.png - 2x3 tiles
# Processado P2768.png - 5x3 tiles
# Processado P0654.png - 3x3 tiles
# Processado P0186.png - 2x3 tiles
# Processado P2701.png - 6x8 tiles
# Processado P1397.png - 7x17 tiles
# Processado P1699.png - 10x9 tiles
# Processado P1547.png - 8x8 tiles
# Processado P2504.png - 5x4 tiles
# Processado P1356.png - 8x8 tiles
# Processado P1919.png - 2x2 tiles
# Processado P1838.png - 3x2 tiles
# Processado P2393.png - 4x5 tiles
# Processado P2241.png - 3x2 tiles
# Processado P1386.png - 7x10 tiles
# Processado P0347.png - 7x4 tiles
# Processado P1014.png - 4x5 tiles
# Processado P1570.png - 10x8 tiles
# Processado P2363.png - 4x5 tiles
# Processado P1434.png - 4x4 tiles
# Processado P0622.png - 4x3 tiles
# Processado P1257.png - 8x8 tiles
# Processado P2214.png - 2x3 tiles
# Processado P1829.png - 3x4 tiles
# Processado P1269.png - 8x8 tiles
# Processado P0170.png - 3x4 tiles
# Processado P2050.png - 2x2 tiles
# Processado P1456.png - 5x7 tiles
# Processado P2625.png - 5x9 tiles
# Processado P0198.png - 3x3 tiles
# Processado P0929.png - 13x2 tiles
# Processado P0615.png - 3x3 tiles
# Processado P1474.png - 13x6 tiles
# Processado P2563.png - 3x4 tiles
# Processado P2365.png - 5x6 tiles
# Processado P1973.png - 4x4 tiles
# Processado P1138.png - 3x5 tiles
# Processado P2571.png - 3x3 tiles
# Processado P0558.png - 4x2 tiles
# Processado P1742.png - 8x9 tiles
# Copiado P2012.png sem fatiamento
# Copiado P2044.png sem fatiamento
# Processado P2779.png - 3x4 tiles
# Processado P0454.png - 2x3 tiles
# Processado P1230.png - 8x11 tiles
# Processado P1463.png - 6x8 tiles
# Processado P1128.png - 3x4 tiles
# Copiado P1880.png sem fatiamento
# Processado P2166.png - 2x3 tiles
# Processado P2027.png - 5x3 tiles
# Processado P2085.png - 2x3 tiles
# Processado P1137.png - 2x2 tiles
# Processado P0130.png - 2x2 tiles
# Processado P2374.png - 4x4 tiles
# Processado P1147.png - 13x10 tiles
# Processado P0696.png - 5x4 tiles
# Processado P0110.png - 5x6 tiles
# Processado P1750.png - 8x9 tiles
# Processado P0816.png - 2x3 tiles
# Processado P1749.png - 8x8 tiles
# Processado P0348.png - 4x2 tiles
# Processado P0962.png - 2x5 tiles
# Processado P2724.png - 5x9 tiles
# Processado P1030.png - 3x8 tiles
# Processado P0787.png - 3x3 tiles
# Processado P0213.png - 4x4 tiles
# Processado P1903.png - 3x4 tiles
# Copiado P2042.png sem fatiamento
# Processado P0579.png - 3x5 tiles
# Processado P2599.png - 3x3 tiles
# Processado P1557.png - 10x8 tiles
# Copiado P2310.png sem fatiamento
# Processado P1854.png - 9x27 tiles
# Processado P2726.png - 6x6 tiles
# Processado P2408.png - 6x4 tiles
# Processado P0079.png - 2x2 tiles
# Processado P0194.png - 2x2 tiles
# Processado P0206.png - 3x3 tiles
# Processado P2082.png - 3x2 tiles
# Processado P1940.png - 2x3 tiles
# Processado P2168.png - 3x4 tiles
# Processado P0968.png - 2x5 tiles
# Processado P2539.png - 5x4 tiles
# Processado P0989.png - 4x3 tiles
# Processado P0844.png - 3x2 tiles
# Processado P2722.png - 5x8 tiles
# Processado P0814.png - 2x3 tiles
# Processado P1005.png - 3x12 tiles
# Processado P0027.png - 4x5 tiles
# Processado P2194.png - 5x4 tiles
# Processado P0053.png - 3x3 tiles
# Processado P1958.png - 3x2 tiles
# Processado P1154.png - 8x8 tiles
# Processado P0382.png - 3x3 tiles
# Processado P0524.png - 3x3 tiles
# Processado P1101.png - 2x2 tiles
# Processado P0764.png - 3x4 tiles
# Processado P1225.png - 8x8 tiles
# Processado P0623.png - 3x3 tiles
# Processado P0420.png - 3x4 tiles
# Processado P0673.png - 3x3 tiles
# Processado P1332.png - 8x8 tiles
# Processado P1763.png - 8x8 tiles
# Processado P0704.png - 3x5 tiles
# Processado P1266.png - 8x8 tiles
# Processado P2766.png - 11x11 tiles
# Copiado P2135.png sem fatiamento
# Processado P0684.png - 2x2 tiles
# Processado P2331.png - 4x7 tiles
# Processado P1471.png - 10x10 tiles
# Processado P2678.png - 6x9 tiles
# Processado P0414.png - 3x2 tiles
# Processado P2718.png - 5x9 tiles
# Processado P0019.png - 8x13 tiles
# Processado P2097.png - 2x3 tiles
# Processado P1440.png - 4x4 tiles
# Processado P1156.png - 6x7 tiles
# Processado P0411.png - 3x2 tiles
# Processado P0665.png - 4x3 tiles
# Processado P1583.png - 10x8 tiles
# Processado P0725.png - 3x4 tiles
# Processado P1713.png - 8x9 tiles
# Processado P0352.png - 3x3 tiles
# Processado P1679.png - 10x8 tiles
# Processado P0761.png - 3x4 tiles
# Processado P1586.png - 8x8 tiles
# Processado P1786.png - 8x7 tiles
# Processado P0259.png - 5x5 tiles
# Processado P0060.png - 5x7 tiles
# Processado P0402.png - 2x2 tiles
# Processado P1210.png - 8x8 tiles
# Processado P2541.png - 6x6 tiles
# Processado P1924.png - 2x2 tiles
# Processado P1179.png - 13x13 tiles
# Processado P2351.png - 4x4 tiles
# Processado P1598.png - 10x8 tiles
# Processado P1877.png - 3x2 tiles
# Processado P1992.png - 4x3 tiles
# Processado P2449.png - 5x4 tiles
# Processado P2598.png - 5x5 tiles
# Processado P1390.png - 7x13 tiles
# Processado P2592.png - 3x5 tiles
# Processado P0945.png - 3x3 tiles
# Processado P0368.png - 3x2 tiles
# Processado P0518.png - 3x2 tiles
# Processado P1134.png - 5x5 tiles
# Processado P1022.png - 3x6 tiles
# Processado P1323.png - 8x8 tiles
# Processado P1604.png - 8x8 tiles
# Processado P2230.png - 3x5 tiles
# Processado P2502.png - 5x7 tiles
# Processado P1066.png - 7x4 tiles
# Processado P0086.png - 3x3 tiles
# Processado P1619.png - 8x8 tiles
# Processado P1283.png - 8x8 tiles
# Processado P2181.png - 5x6 tiles
# Processado P0375.png - 2x2 tiles
# Processado P1982.png - 4x4 tiles
# Processado P1978.png - 3x3 tiles
# Processado P1573.png - 10x9 tiles
# Processado P1315.png - 8x8 tiles
# Processado P0590.png - 3x3 tiles
# Processado P2542.png - 5x5 tiles
# Processado P2733.png - 6x6 tiles
# Processado P1075.png - 7x5 tiles
# Processado P2789.png - 9x10 tiles
# Processado P1560.png - 8x8 tiles
# Processado P0173.png - 2x2 tiles
# Processado P1483.png - 4x4 tiles
# Processado P0146.png - 4x6 tiles
# Processado P0377.png - 2x2 tiles
# Processado P0128.png - 4x4 tiles
# Processado P1983.png - 3x3 tiles
# Processado P0543.png - 2x3 tiles
# Processado P0217.png - 3x4 tiles
# Processado P1007.png - 3x17 tiles
# Processado P0977.png - 5x5 tiles
# Processado P2330.png - 8x17 tiles
# Processado P0199.png - 4x3 tiles
# Processado P1577.png - 8x9 tiles
# Processado P2218.png - 2x2 tiles
# Processado P2794.png - 9x9 tiles
# Processado P1184.png - 13x6 tiles
# Copiado P2294.png sem fatiamento
# Processado P1759.png - 8x8 tiles
# Processado P2152.png - 2x3 tiles
# Processado P2394.png - 4x4 tiles
# Processado P0143.png - 2x2 tiles
# Processado P2689.png - 7x13 tiles
# Processado P2802.png - 11x12 tiles
# Processado P1542.png - 8x8 tiles
# Processado P0953.png - 3x6 tiles
# Processado P1806.png - 3x2 tiles
# Processado P2610.png - 5x4 tiles
# Processado P0643.png - 2x2 tiles
# Processado P1569.png - 8x9 tiles
# Processado P2068.png - 2x2 tiles
# Processado P0007.png - 5x3 tiles
# Processado P1410.png - 12x11 tiles
# Processado P0763.png - 3x4 tiles
# Processado P2059.png - 5x2 tiles
# Processado P0839.png - 5x2 tiles
# Processado P2242.png - 3x6 tiles
# Processado P1219.png - 8x8 tiles
# Processado P2197.png - 4x5 tiles
# Processado P0547.png - 3x2 tiles
# Processado P0897.png - 10x5 tiles
# Processado P1384.png - 12x12 tiles
# Processado P0551.png - 3x3 tiles
# Processado P0237.png - 2x2 tiles
# Processado P1143.png - 11x12 tiles
# Processado P0491.png - 4x6 tiles
# Processado P0476.png - 3x3 tiles
# Processado P2256.png - 3x9 tiles
# Processado P0858.png - 3x5 tiles
# Processado P1579.png - 8x8 tiles
# Processado P2231.png - 5x4 tiles
# Processado P1693.png - 8x8 tiles
# Processado P0309.png - 4x2 tiles
# Processado P2121.png - 3x2 tiles
# Processado P0564.png - 3x2 tiles
# Corte concluído!

# %% [markdown]
# Creating the sliced dataset description

# %%
data_sliced_yaml = """
train: yolo-dataset-sliced/images/train
val: yolo-dataset-sliced/images/val

nc: 15

names: [
  'plane',
  'ship',
  'storage-tank',
  'baseball-diamond',
  'tennis-court',
  'basketball-court',
  'ground-track-field',
  'harbor',
  'bridge',
  'large-vehicle',
  'small-vehicle',
  'helicopter',
  'roundabout',
  'soccer-ball-field',
  'swimming-pool'
]
"""

with open("data_sliced.yaml", "w") as f:
    f.write(data_sliced_yaml)

# %% [markdown]
# Training the yolov11m with the sliced dataset

# %%
# !yolo train model=yolo11m.pt data=/content/data_sliced.yaml epochs=100 imgsz=512 batch=8 optimizer=AdamW lr0=0.001
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt': 100% 38.8M/38.8M [00:00<00:00, 151MB/s]
# Ultralytics 8.3.175 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data_sliced.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% 755k/755k [00:00<00:00, 66.9MB/s]
# Overriding model.yaml nc=80 with nc=15
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1422589  ultralytics.nn.modules.head.Detect           [15, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,064,573 parameters, 20,064,557 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% 5.35M/5.35M [00:00<00:00, 146MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3633.7±996.9 MB/s, size: 344.3 KB)
# train: Scanning /content/yolo-dataset-sliced/labels/train... 16108 images, 0 backgrounds, 2 corrupt: 100% 16110/16110 [00:37<00:00, 434.20it/s]
# train: /content/yolo-dataset-sliced/images/train/P0867_4_2.png: ignoring corrupt image/label: image size (3, 512) <10 pixels
# train: /content/yolo-dataset-sliced/images/train/P0867_4_3.png: ignoring corrupt image/label: image size (3, 512) <10 pixels
# train: New cache created: /content/yolo-dataset-sliced/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2078.9±1201.8 MB/s, size: 394.4 KB)
# val: Scanning /content/yolo-dataset-sliced/labels/val... 4977 images, 0 backgrounds, 3 corrupt: 100% 4980/4980 [00:11<00:00, 431.82it/s]
# val: /content/yolo-dataset-sliced/images/val/P1983_2_2.png: ignoring corrupt image/label: image size (238, 8) <10 pixels
# val: /content/yolo-dataset-sliced/images/val/P2592_0_4.png: ignoring corrupt image/label: image size (512, 7) <10 pixels
# val: /content/yolo-dataset-sliced/images/val/P2592_1_4.png: ignoring corrupt image/label: image size (512, 7) <10 pixels
# val: New cache created: /content/yolo-dataset-sliced/labels/val.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.12G      1.674      1.966      1.423         54        512: 100% 2014/2014 [06:31<00:00,  5.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:52<00:00,  5.89it/s]
#                    all       4977      35511      0.517      0.293      0.284       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      5.44G      1.603       1.72      1.394         14        512: 100% 2014/2014 [06:16<00:00,  5.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.02it/s]
#                    all       4977      35511      0.423      0.333       0.33      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      5.51G      1.531       1.59      1.355         91        512: 100% 2014/2014 [06:12<00:00,  5.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.07it/s]
#                    all       4977      35511      0.477      0.402      0.389      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      5.55G       1.47      1.476      1.321         26        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.12it/s]
#                    all       4977      35511      0.513      0.441       0.44      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      5.64G      1.416       1.37      1.286         78        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.13it/s]
#                    all       4977      35511      0.613      0.452      0.466      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      5.71G       1.39      1.322      1.275         57        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.12it/s]
#                    all       4977      35511      0.582      0.481      0.483      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      5.77G       1.36      1.276      1.255         25        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.579       0.49      0.498      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      5.81G       1.33      1.224      1.239         60        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.616      0.516       0.52      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100       5.9G      1.309      1.183      1.226         47        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.12it/s]
#                    all       4977      35511      0.636      0.523      0.537      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      5.97G      1.299      1.174      1.224         64        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.13it/s]
#                    all       4977      35511      0.641      0.535      0.553       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      6.04G      1.281      1.144      1.209         43        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.649      0.545       0.56      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      6.08G      1.269      1.124      1.206         48        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.21it/s]
#                    all       4977      35511      0.634      0.554      0.557      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      6.17G      1.258      1.097      1.194         21        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.667      0.549      0.577      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      6.24G      1.237      1.079      1.188         26        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.19it/s]
#                    all       4977      35511      0.671      0.571       0.59      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100       6.3G      1.242      1.076      1.191        111        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.22it/s]
#                    all       4977      35511      0.692      0.558      0.596      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      6.34G      1.224      1.049      1.179         84        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.21it/s]
#                    all       4977      35511      0.683      0.573      0.599      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      6.44G      1.222      1.044       1.18         12        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.08it/s]
#                    all       4977      35511      0.681      0.589      0.607      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100       6.5G      1.203      1.018      1.171          9        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.18it/s]
#                    all       4977      35511      0.698      0.579      0.609      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      6.57G      1.202      1.009      1.165         14        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.18it/s]
#                    all       4977      35511      0.704      0.594       0.62      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      6.61G      1.194      1.007      1.164         64        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.18it/s]
#                    all       4977      35511      0.706      0.587      0.622      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100       6.7G      1.188     0.9831      1.154         18        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.679      0.608      0.624      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      6.77G      1.178     0.9739       1.15         45        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.719      0.597       0.63      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      6.83G      1.171     0.9711      1.149         16        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.703      0.606      0.628      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      6.87G       1.17     0.9576      1.146         81        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.15it/s]
#                    all       4977      35511      0.715      0.609      0.636      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      6.96G      1.164     0.9572      1.146         32        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.718      0.632      0.653      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      7.03G      1.159     0.9426      1.139         66        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.15it/s]
#                    all       4977      35511      0.729      0.623      0.659      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100       7.1G      1.154     0.9346      1.139         44        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.714       0.62      0.653      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      7.14G       1.14      0.921      1.129         12        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.724      0.615      0.656      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      7.23G      1.137     0.9111      1.127         15        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.18it/s]
#                    all       4977      35511      0.746       0.62      0.664      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      7.29G       1.13     0.9138      1.124         78        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.742      0.634       0.67      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      7.36G       1.13     0.9081      1.118         52        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.743      0.629       0.67      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100       7.4G       1.13      0.899      1.122          9        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.10it/s]
#                    all       4977      35511      0.736      0.644      0.673       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100       4.1G      1.118     0.8902      1.114         29        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.738      0.643      0.678      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100       4.1G      1.116     0.8869      1.114         11        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.15it/s]
#                    all       4977      35511      0.728       0.65      0.678      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100       4.1G      1.114     0.8852      1.113         29        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.753      0.643       0.68      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100       4.1G       1.11     0.8771      1.114         29        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.736      0.648      0.681      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100       4.1G      1.109     0.8628      1.108         31        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.12it/s]
#                    all       4977      35511       0.75      0.647      0.681      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      4.11G      1.102     0.8658      1.107         68        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.736      0.655      0.682       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      4.17G      1.094     0.8498      1.102         66        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.19it/s]
#                    all       4977      35511      0.739      0.656      0.687      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      4.66G      1.089     0.8511      1.102         64        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.21it/s]
#                    all       4977      35511      0.737      0.656      0.686      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      4.76G      1.081     0.8342      1.092         40        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.21it/s]
#                    all       4977      35511      0.744      0.651      0.687      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      4.83G      1.082     0.8375      1.097         24        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.19it/s]
#                    all       4977      35511      0.734      0.661       0.69      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      4.89G      1.076     0.8317      1.091         46        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.19it/s]
#                    all       4977      35511      0.742      0.664      0.693      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      4.93G      1.078     0.8266      1.092         54        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.20it/s]
#                    all       4977      35511      0.759      0.653      0.693      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      5.02G      1.067     0.8191      1.087         59        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.23it/s]
#                    all       4977      35511       0.75      0.661      0.694      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      5.09G      1.068     0.8156      1.086         16        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.20it/s]
#                    all       4977      35511      0.758      0.662      0.699      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      5.15G      1.063     0.8114      1.088         35        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.22it/s]
#                    all       4977      35511      0.751      0.667        0.7      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      5.19G      1.056      0.802      1.082          7        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.20it/s]
#                    all       4977      35511      0.746      0.674      0.701      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      5.29G      1.055     0.8002      1.081        112        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:49<00:00,  6.24it/s]
#                    all       4977      35511       0.75      0.669        0.7      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      5.35G      1.052     0.7998      1.082         40        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.11it/s]
#                    all       4977      35511      0.753      0.667      0.702      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      5.42G      1.051     0.7997      1.078         20        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.751       0.67      0.703      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      5.91G      1.049     0.7918      1.078         31        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.756      0.668      0.704      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100         6G      1.043     0.7844      1.073         65        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.759      0.664      0.706      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      6.06G      1.042     0.7791      1.075         37        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.18it/s]
#                    all       4977      35511      0.747      0.671      0.706      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      6.13G      1.035     0.7771      1.071         31        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.20it/s]
#                    all       4977      35511      0.748      0.673      0.707      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      6.17G      1.027     0.7691      1.067         62        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.21it/s]
#                    all       4977      35511      0.748      0.674      0.708      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      6.26G      1.027     0.7665      1.068         39        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.21it/s]
#                    all       4977      35511       0.75      0.675      0.709      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      6.33G      1.023     0.7655      1.064         38        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.24it/s]
#                    all       4977      35511      0.756      0.669      0.709      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100       6.4G      1.023     0.7546      1.064         27        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.15it/s]
#                    all       4977      35511      0.752      0.672      0.709      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      6.44G      1.018     0.7565      1.061         29        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.20it/s]
#                    all       4977      35511      0.753      0.675       0.71      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      6.53G      1.016     0.7493       1.06         48        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511       0.76      0.667      0.711      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      7.04G      1.012     0.7438      1.058         39        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.18it/s]
#                    all       4977      35511       0.76      0.667      0.711      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      7.11G       1.01     0.7386      1.057         49        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.752      0.674      0.711      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      7.15G      1.009     0.7441      1.061         59        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.19it/s]
#                    all       4977      35511      0.754      0.674      0.713      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      7.25G      1.003     0.7378      1.054         19        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.21it/s]
#                    all       4977      35511      0.756      0.677      0.713      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      7.31G     0.9973     0.7306      1.054         36        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.758      0.676      0.714      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      7.38G      1.001     0.7396      1.055         10        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.08it/s]
#                    all       4977      35511       0.76      0.674      0.714      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      4.65G      0.989     0.7153      1.046         31        512: 100% 2014/2014 [06:12<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.10it/s]
#                    all       4977      35511      0.768       0.67      0.715      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.65G     0.9896     0.7203      1.047         12        512: 100% 2014/2014 [06:12<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.773      0.667      0.714      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      4.65G       0.99      0.718      1.049         46        512: 100% 2014/2014 [06:12<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.09it/s]
#                    all       4977      35511      0.768      0.671      0.714      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.65G     0.9819     0.7154      1.046         33        512: 100% 2014/2014 [06:12<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.10it/s]
#                    all       4977      35511      0.768      0.671      0.714      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      4.65G     0.9873     0.7175      1.049         10        512: 100% 2014/2014 [06:12<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.09it/s]
#                    all       4977      35511      0.769       0.67      0.714      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      4.65G      0.977     0.7061      1.041         44        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.13it/s]
#                    all       4977      35511      0.768      0.671      0.715      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      4.65G     0.9768     0.7076      1.041         10        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.11it/s]
#                    all       4977      35511      0.769      0.671      0.715       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      4.68G     0.9741     0.7038      1.043         23        512: 100% 2014/2014 [06:11<00:00,  5.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.13it/s]
#                    all       4977      35511       0.77      0.671      0.716       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      4.72G     0.9685     0.6948      1.037         54        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.15it/s]
#                    all       4977      35511      0.771       0.67      0.716       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      4.81G     0.9667     0.6895      1.036         34        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.19it/s]
#                    all       4977      35511      0.767      0.675      0.716       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      4.88G     0.9601     0.6846      1.035         58        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.20it/s]
#                    all       4977      35511      0.768      0.675      0.717       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      4.94G     0.9594     0.6847      1.033         84        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.768      0.675      0.717       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      4.98G     0.9569      0.685      1.032         12        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.767      0.675      0.717       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      5.08G     0.9526     0.6781      1.032         15        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.765      0.676      0.717      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      5.14G     0.9561     0.6769       1.03         38        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.764      0.676      0.717      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      5.21G     0.9537     0.6808      1.032         27        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.20it/s]
#                    all       4977      35511      0.764      0.677      0.718      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      5.25G     0.9473     0.6755      1.028         28        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.764      0.678      0.719      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      5.34G      0.949     0.6727      1.028         17        512: 100% 2014/2014 [06:11<00:00,  5.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.768      0.676      0.719      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      5.85G     0.9436     0.6629      1.026        105        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.18it/s]
#                    all       4977      35511      0.771      0.675      0.719      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      5.92G     0.9383     0.6666      1.025         17        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.21it/s]
#                    all       4977      35511      0.771      0.675      0.719      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      5.96G     0.9423     0.6698      1.027         34        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.15it/s]
#                    all       4977      35511      0.772      0.675      0.719      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      6.05G     0.9365     0.6606      1.025         35        512: 100% 2014/2014 [06:11<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.18it/s]
#                    all       4977      35511      0.772      0.675       0.72      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      6.12G     0.9396     0.6698      1.027         14        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.22it/s]
#                    all       4977      35511      0.771      0.675       0.72      0.482
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      6.18G     0.9275     0.6224      1.034          8        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.767      0.678       0.72      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      6.23G     0.9171      0.603      1.028         12        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.13it/s]
#                    all       4977      35511      0.768      0.678       0.72      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      6.32G     0.9166     0.6037      1.028         61        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.12it/s]
#                    all       4977      35511      0.767      0.678       0.72      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      6.38G     0.9123     0.6049      1.026         35        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.14it/s]
#                    all       4977      35511      0.769      0.678       0.72      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      6.45G     0.9027     0.5913       1.02          6        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.13it/s]
#                    all       4977      35511      0.771      0.676       0.72      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      6.49G     0.9042     0.5933      1.025          5        512: 100% 2014/2014 [06:09<00:00,  5.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.09it/s]
#                    all       4977      35511      0.773      0.676      0.721      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      6.58G     0.8989     0.5856      1.021         15        512: 100% 2014/2014 [06:10<00:00,  5.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.16it/s]
#                    all       4977      35511      0.773      0.675      0.721      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100       7.1G     0.8986     0.5864      1.021          9        512: 100% 2014/2014 [06:08<00:00,  5.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:50<00:00,  6.17it/s]
#                    all       4977      35511      0.775      0.674      0.721      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      7.17G     0.8991     0.5886      1.018         12        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.07it/s]
#                    all       4977      35511      0.777      0.674      0.721      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.21G     0.8921     0.5817      1.016          4        512: 100% 2014/2014 [06:10<00:00,  5.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:51<00:00,  6.11it/s]
#                    all       4977      35511      0.775      0.675      0.721      0.483
#
# 100 epochs completed in 11.750 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 40.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 40.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.175 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,041,597 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 312/312 [00:49<00:00,  6.33it/s]
#                    all       4977      35511      0.776      0.675      0.722      0.483
#                  plane       1039       3810      0.948      0.785      0.869      0.656
#                   ship        796      10438      0.903      0.895      0.936      0.694
#           storage-tank        322       3166      0.918      0.699       0.84      0.557
#       baseball-diamond        199        290      0.808      0.684      0.735      0.428
#           tennis-court        320       1099      0.958      0.892      0.938      0.842
#       basketball-court         97        198      0.701      0.576      0.597       0.46
#     ground-track-field        305        321      0.798      0.579      0.638      0.422
#                 harbor       1062       3308      0.826      0.658      0.743      0.442
#                 bridge        424        597      0.699      0.475       0.53      0.259
#          large-vehicle        638       5264      0.852        0.8      0.864      0.652
#          small-vehicle        625       5878       0.69      0.816      0.789       0.49
#             helicopter         51        101      0.404      0.495       0.46      0.256
#             roundabout        201        223      0.773      0.592      0.663      0.387
#      soccer-ball-field        252        313      0.696      0.562      0.624      0.434
#          swimming-pool        165        505      0.659      0.612      0.597      0.263
# Speed: 0.1ms preprocess, 6.2ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# Saving the result

# %%
import shutil
from google.colab import files

# Caminho da pasta que será compactada
caminho_pasta = "/content/runs/detect/train"

# Caminho do arquivo zip que será criado
arquivo_zip = "/content/train_output_yolov11m_100_epocas-adam-imgsz512_batch8.zip"

# Compacta a pasta
shutil.make_archive(arquivo_zip.replace(".zip", ""), 'zip', caminho_pasta)

# Gera link para download
files.download(arquivo_zip)
