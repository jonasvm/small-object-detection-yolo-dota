# %% [markdown]
# Downloading the first part of the training images zip

# %%
# Instala gdown
# !pip install -U gdown

# Baixa o arquivo usando o ID
import gdown

file_id = "1BlaGYNNEKGmT6OjZjsJ8HoUYrTTmFcO2"
output = "imagens.zip"

gdown.download(f"https://drive.google.com/uc?id={file_id}", output, quiet=False)
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1BlaGYNNEKGmT6OjZjsJ8HoUYrTTmFcO2
# From (redirected): https://drive.google.com/uc?id=1BlaGYNNEKGmT6OjZjsJ8HoUYrTTmFcO2&confirm=t&uuid=24928edd-a97f-433e-be48-b8e4e1876121
# To: /content/imagens.zip
# 100%|██████████| 2.13G/2.13G [00:13<00:00, 162MB/s]
# 'imagens.zip'

# %% [markdown]
# Unzipping the images and placing them into the YOLO dataset folder structure

# %%
# Cria a subpasta desejada e descompacta
import os
import zipfile

destino = "yolo-dataset/images/train"
os.makedirs(destino, exist_ok=True)

with zipfile.ZipFile("imagens.zip", 'r') as zip_ref:
    zip_ref.extractall(destino)

# Mostra os primeiros arquivos extraídos
# !ls -lh "yolo-dataset/images/train" | head
# Out:
# total 20K
# drwxr-xr-x 2 root root 20K Aug 14 18:59 images

# %% [markdown]
# The images ended up in the wrong structure, so moving them to the correct order

# %%
import os
import shutil

# Caminhos
pasta_errada = "yolo-dataset/images/train/images"
pasta_correta = "yolo-dataset/images/train"

# Verifica se a pasta errada existe
if os.path.exists(pasta_errada):
    # Move todos os arquivos da pasta_errada para pasta_correta
    for nome_arquivo in os.listdir(pasta_errada):
        origem = os.path.join(pasta_errada, nome_arquivo)
        destino = os.path.join(pasta_correta, nome_arquivo)
        shutil.move(origem, destino)

    # Remove a pasta_errada após mover os arquivos
    shutil.rmtree(pasta_errada)
    print("Arquivos movidos e pasta 'images' removida com sucesso.")
else:
    print("Pasta 'yolo-dataset/images/train/images' não encontrada.")
# Out:
# Arquivos movidos e pasta 'images' removida com sucesso.

# %% [markdown]
# Doing the same thing for part 2 of the training image

# %%
# ID do arquivo no Google Drive
file_id = "1JBWCHdyZOd9ULX0ng5C9haAt3FMPXa3v"
zip_path = "imagens2.zip"

# Baixa o .zip
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# Caminhos de destino
destino_final = "yolo-dataset/images/train"
tmp_extract = "temp_extracao"

# Cria as pastas
os.makedirs(tmp_extract, exist_ok=True)
os.makedirs(destino_final, exist_ok=True)

# Descompacta na pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(tmp_extract)

# Move arquivos da subpasta "images" para "train"
src_images_dir = os.path.join(tmp_extract, "images")
if os.path.exists(src_images_dir):
    for nome_arquivo in os.listdir(src_images_dir):
        origem = os.path.join(src_images_dir, nome_arquivo)
        destino = os.path.join(destino_final, nome_arquivo)
        shutil.move(origem, destino)
else:
    print(f"A pasta '{src_images_dir}' não foi encontrada.")

# Remove a pasta temporária
shutil.rmtree(tmp_extract)

# Verifica resultado
# !ls -lh "yolo-dataset/images/train" | head
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JBWCHdyZOd9ULX0ng5C9haAt3FMPXa3v
# From (redirected): https://drive.google.com/uc?id=1JBWCHdyZOd9ULX0ng5C9haAt3FMPXa3v&confirm=t&uuid=ecdff876-9026-47bd-bfeb-6cf5e5fdd6b5
# To: /content/imagens2.zip
# 100%|██████████| 4.76G/4.76G [00:32<00:00, 148MB/s]
# total 6.8G
# -rw-r--r-- 1 root root   23M Aug 14 18:59 P0000.png
# -rw-r--r-- 1 root root   12M Aug 14 18:59 P0001.png
# -rw-r--r-- 1 root root  7.8M Aug 14 18:59 P0002.png
# -rw-r--r-- 1 root root  1.4M Aug 14 18:59 P0005.png
# -rw-r--r-- 1 root root  2.1M Aug 14 18:59 P0008.png
# -rw-r--r-- 1 root root  6.0M Aug 14 18:59 P0010.png
# -rw-r--r-- 1 root root  3.6M Aug 14 18:59 P0011.png
# -rw-r--r-- 1 root root  9.2M Aug 14 18:59 P0012.png
# -rw-r--r-- 1 root root  3.9M Aug 14 18:59 P0013.png

# %% [markdown]
# Now the third and final part of the training images zip

# %%
# ID do terceiro arquivo
file_id = "1pEmwJtugIWhiwgBqOtplNUtTG2T454zn"
zip_path = "imagens3.zip"

# Baixa o arquivo .zip do Google Drive
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# Diretórios
tmp_extract = "temp_extracao"
destino_final = "yolo-dataset/images/train"

# Cria diretórios se não existirem
os.makedirs(tmp_extract, exist_ok=True)
os.makedirs(destino_final, exist_ok=True)

# Extrai o conteúdo na pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(tmp_extract)

# Move arquivos de temp_extracao/images para train/
src_images_dir = os.path.join(tmp_extract, "images")
if os.path.exists(src_images_dir):
    for nome_arquivo in os.listdir(src_images_dir):
        origem = os.path.join(src_images_dir, nome_arquivo)
        destino = os.path.join(destino_final, nome_arquivo)
        shutil.move(origem, destino)
else:
    print(f"Pasta '{src_images_dir}' não encontrada.")

# Limpa a pasta temporária
shutil.rmtree(tmp_extract)

# Verifica os primeiros arquivos movidos
# !ls -lh "yolo-dataset/images/train" | head
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1pEmwJtugIWhiwgBqOtplNUtTG2T454zn
# From (redirected): https://drive.google.com/uc?id=1pEmwJtugIWhiwgBqOtplNUtTG2T454zn&confirm=t&uuid=95c4e4d8-8690-4f8f-a2db-f094866deff1
# To: /content/imagens3.zip
# 100%|██████████| 3.32G/3.32G [00:28<00:00, 115MB/s]
# total 10G
# -rw-r--r-- 1 root root   23M Aug 14 18:59 P0000.png
# -rw-r--r-- 1 root root   12M Aug 14 18:59 P0001.png
# -rw-r--r-- 1 root root  7.8M Aug 14 18:59 P0002.png
# -rw-r--r-- 1 root root  1.4M Aug 14 18:59 P0005.png
# -rw-r--r-- 1 root root  2.1M Aug 14 18:59 P0008.png
# -rw-r--r-- 1 root root  6.0M Aug 14 18:59 P0010.png
# -rw-r--r-- 1 root root  3.6M Aug 14 18:59 P0011.png
# -rw-r--r-- 1 root root  9.2M Aug 14 18:59 P0012.png
# -rw-r--r-- 1 root root  3.9M Aug 14 18:59 P0013.png

# %% [markdown]
# Checking the images

# %%
# Caminho da pasta com as imagens
caminho = "yolo-dataset/images/train"

# Extensões consideradas como imagem
extensoes_imagem = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp')

# Conta arquivos com as extensões de imagem
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensoes_imagem)
)

print(f"Total de imagens em '{caminho}': {quantidade}")
# Out:
# Total de imagens em 'yolo-dataset/images/train': 1411

# %% [markdown]
# Now setting up the validation images

# %%
# ID do arquivo .zip no Google Drive
file_id = "1uCCCFhFQOJLfjBpcL5MC0DHJ9lgOaXWP"
zip_path = "imagens_test.zip"

# Baixar o arquivo .zip
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# Caminhos
tmp_extract = "temp_extracao"
destino_final = "yolo-dataset/images/val"

# Cria pastas se necessário
os.makedirs(tmp_extract, exist_ok=True)
os.makedirs(destino_final, exist_ok=True)

# Descompacta na pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(tmp_extract)

# Move arquivos de temp_extracao/images para test/
src_images_dir = os.path.join(tmp_extract, "images")
if os.path.exists(src_images_dir):
    for nome_arquivo in os.listdir(src_images_dir):
        origem = os.path.join(src_images_dir, nome_arquivo)
        destino = os.path.join(destino_final, nome_arquivo)
        shutil.move(origem, destino)
else:
    print(f"Pasta '{src_images_dir}' não encontrada.")

# Remove pasta temporária
shutil.rmtree(tmp_extract)

# Verifica os primeiros arquivos
# !ls -lh "yolo-dataset/images/test" | head
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1uCCCFhFQOJLfjBpcL5MC0DHJ9lgOaXWP
# From (redirected): https://drive.google.com/uc?id=1uCCCFhFQOJLfjBpcL5MC0DHJ9lgOaXWP&confirm=t&uuid=018c2e7f-02b1-4d8f-8f01-1c61ca05b28d
# To: /content/imagens_test.zip
# 100%|██████████| 3.34G/3.34G [00:29<00:00, 112MB/s]
# ls: cannot access 'yolo-dataset/images/test': No such file or directory

# %% [markdown]
# Checking the validation images

# %%
# Caminho da pasta com as imagens
caminho = "yolo-dataset/images/val"

# Extensões consideradas como imagem
extensoes_imagem = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp')

# Conta arquivos com as extensões de imagem
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensoes_imagem)
)

print(f"Total de imagens em '{caminho}': {quantidade}")
# Out:
# Total de imagens em 'yolo-dataset/images/val': 458

# %% [markdown]
# Checking the training images

# %%
# Caminho da pasta com as imagens
caminho = "yolo-dataset/images/train"

# Extensões consideradas como imagem
extensoes_imagem = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp')

# Conta arquivos com as extensões de imagem
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensoes_imagem)
)

print(f"Total de imagens em '{caminho}': {quantidade}")
# Out:
# Total de imagens em 'yolo-dataset/images/train': 1411

# %% [markdown]
# Uploading and organizing the training labels (manual upload)

# %%
# Caminhos
zip_path = "/content/train.zip"
dest_folder = "/content/yolo-dataset/labels/train"
temp_extract_folder = "/content/temp_labels"

# Cria a pasta de destino se não existir
os.makedirs(dest_folder, exist_ok=True)

# Extrai o zip para uma pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(temp_extract_folder)

# Move os arquivos extraídos para a pasta de destino
for root, _, files in os.walk(temp_extract_folder):
    for file in files:
        src = os.path.join(root, file)
        dst = os.path.join(dest_folder, file)
        shutil.move(src, dst)

# Remove a pasta temporária
shutil.rmtree(temp_extract_folder)

print(f"Arquivos extraídos para {dest_folder}")
# Out:
# Arquivos extraídos para /content/yolo-dataset/labels/train

# %% [markdown]
# Uploading and organizing the validation labels (manual upload)

# %%
# Caminhos
zip_path = "/content/val.zip"
dest_folder = "/content/yolo-dataset/labels/val"
temp_extract_folder = "/content/temp_labels"

# Cria a pasta de destino se não existir
os.makedirs(dest_folder, exist_ok=True)

# Extrai o zip para uma pasta temporária
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(temp_extract_folder)

# Move os arquivos extraídos para a pasta de destino
for root, _, files in os.walk(temp_extract_folder):
    for file in files:
        src = os.path.join(root, file)
        dst = os.path.join(dest_folder, file)
        shutil.move(src, dst)

# Remove a pasta temporária
shutil.rmtree(temp_extract_folder)

print(f"Arquivos extraídos para {dest_folder}")
# Out:
# Arquivos extraídos para /content/yolo-dataset/labels/val

# %% [markdown]
# Checking the labels

# %%
# Caminho da pasta com os labels
caminho = "yolo-dataset/labels/train"

# Extensão considerada como label YOLO
extensao_label = ".txt"

# Conta arquivos com a extensão .txt
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensao_label)
)

print(f"Total de labels em '{caminho}': {quantidade}")
# Out:
# Total de labels em 'yolo-dataset/labels/train': 1410

# %%
# Caminho da pasta com os labels
caminho = "yolo-dataset/labels/val"

# Extensão considerada como label YOLO
extensao_label = ".txt"

# Conta arquivos com a extensão .txt
quantidade = sum(
    1 for nome in os.listdir(caminho)
    if nome.lower().endswith(extensao_label)
)

print(f"Total de labels em '{caminho}': {quantidade}")
# Out:
# Total de labels em 'yolo-dataset/labels/val': 458

# %% [markdown]
# Creating the dataset description

# %%
data_yaml = """
train: yolo-dataset/images/train
val: yolo-dataset/images/val

nc: 15

names: [
  'plane',
  'ship',
  'storage-tank',
  'baseball-diamond',
  'tennis-court',
  'basketball-court',
  'ground-track-field',
  'harbor',
  'bridge',
  'large-vehicle',
  'small-vehicle',
  'helicopter',
  'roundabout',
  'soccer-ball-field',
  'swimming-pool'
]
"""

with open("data.yaml", "w") as f:
    f.write(data_yaml)

# %% [markdown]
# Installing the ultralytics

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.179-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.179-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.179 ultralytics-thop-2.0.15

# %% [markdown]
# Checking the GPU availability

# %%
# !nvidia-smi
# Out:
# Thu Aug 14 19:12:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# NOW PROCESSING THE IMAGES FOR TESTING WITH TRAINING AND VALIDATION SLICING

# %%
import os
import cv2
import math
import shutil

# Configurações
BASE_DIR = "/content/yolo-dataset"
IMG_DIR = os.path.join(BASE_DIR, "images")
LABEL_DIR = os.path.join(BASE_DIR, "labels")

OUTPUT_DIR = "/content/yolo-dataset-sliced"
TILE_SIZE = 256

SUBSETS = ["train", "val"]  # Apenas train e val

def read_labels(label_path):
    labels = []
    if not os.path.exists(label_path):
        return labels
    with open(label_path, "r") as f:
        for line in f.readlines():
            parts = line.strip().split()
            cls = int(parts[0])
            x_center = float(parts[1])
            y_center = float(parts[2])
            w = float(parts[3])
            h = float(parts[4])
            labels.append([cls, x_center, y_center, w, h])
    return labels

def save_labels(label_path, labels):
    with open(label_path, "w") as f:
        for label in labels:
            f.write(" ".join(map(str, label)) + "\n")

def yolo_to_box(xc, yc, w, h, img_w, img_h):
    xmin = (xc - w / 2) * img_w
    xmax = (xc + w / 2) * img_w
    ymin = (yc - h / 2) * img_h
    ymax = (yc + h / 2) * img_h
    return xmin, ymin, xmax, ymax

def box_to_yolo(xmin, ymin, xmax, ymax, img_w, img_h):
    xc = (xmin + xmax) / 2 / img_w
    yc = (ymin + ymax) / 2 / img_h
    w = (xmax - xmin) / img_w
    h = (ymax - ymin) / img_h
    return [xc, yc, w, h]

def process_subset(subset):
    img_subset_dir = os.path.join(IMG_DIR, subset)
    label_subset_dir = os.path.join(LABEL_DIR, subset)
    out_img_dir = os.path.join(OUTPUT_DIR, "images", subset)
    out_label_dir = os.path.join(OUTPUT_DIR, "labels", subset)

    os.makedirs(out_img_dir, exist_ok=True)
    os.makedirs(out_label_dir, exist_ok=True)

    img_files = [f for f in os.listdir(img_subset_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

    for img_file in img_files:
        img_path = os.path.join(img_subset_dir, img_file)
        label_path = os.path.join(label_subset_dir, img_file.rsplit('.',1)[0] + ".txt")

        img = cv2.imread(img_path)
        if img is None:
            print(f"Erro ao ler imagem {img_path}")
            continue
        h_img, w_img = img.shape[:2]

        labels = read_labels(label_path)

        # Se a imagem for menor ou igual a TILE_SIZE em largura ou altura, copia direto
        if w_img <= TILE_SIZE or h_img <= TILE_SIZE:
            out_img_path = os.path.join(out_img_dir, img_file)
            out_label_path = os.path.join(out_label_dir, img_file.rsplit('.',1)[0] + ".txt")
            shutil.copy2(img_path, out_img_path)
            save_labels(out_label_path, labels)
            print(f"Copiado {img_file} sem fatiamento")
            continue

        # Quantidade de tiles horizontal e vertical
        tiles_x = math.ceil(w_img / TILE_SIZE)
        tiles_y = math.ceil(h_img / TILE_SIZE)

        for ty in range(tiles_y):
            for tx in range(tiles_x):
                x_start = tx * TILE_SIZE
                y_start = ty * TILE_SIZE
                x_end = min(x_start + TILE_SIZE, w_img)
                y_end = min(y_start + TILE_SIZE, h_img)

                tile_w = x_end - x_start
                tile_h = y_end - y_start

                tile_img = img[y_start:y_end, x_start:x_end]

                tile_labels = []
                for label in labels:
                    cls, xc, yc, bw, bh = label
                    xmin, ymin, xmax, ymax = yolo_to_box(xc, yc, bw, bh, w_img, h_img)

                    inter_xmin = max(xmin, x_start)
                    inter_ymin = max(ymin, y_start)
                    inter_xmax = min(xmax, x_end)
                    inter_ymax = min(ymax, y_end)

                    inter_w = inter_xmax - inter_xmin
                    inter_h = inter_ymax - inter_ymin

                    if inter_w <= 0 or inter_h <= 0:
                        continue

                    new_xmin = inter_xmin - x_start
                    new_ymin = inter_ymin - y_start
                    new_xmax = inter_xmax - x_start
                    new_ymax = inter_ymax - y_start

                    if new_xmax - new_xmin < 2 or new_ymax - new_ymin < 2:
                        continue

                    new_xc, new_yc, new_w, new_h = box_to_yolo(new_xmin, new_ymin, new_xmax, new_ymax, tile_w, tile_h)

                    tile_labels.append([cls, new_xc, new_yc, new_w, new_h])

                if len(tile_labels) > 0:
                    tile_img_name = f"{img_file.rsplit('.',1)[0]}_{ty}_{tx}.png"
                    tile_label_name = f"{img_file.rsplit('.',1)[0]}_{ty}_{tx}.txt"

                    cv2.imwrite(os.path.join(out_img_dir, tile_img_name), tile_img)
                    save_labels(os.path.join(out_label_dir, tile_label_name), tile_labels)

        print(f"Processado {img_file} - {tiles_y}x{tiles_x} tiles")

def main():
    for subset in SUBSETS:
        print(f"Processando {subset}...")
        process_subset(subset)
    print("Corte concluído!")

if __name__ == "__main__":
    main()
# Out:
# Processando train...
# Processado P2346.png - 7x7 tiles
# Processado P1416.png - 9x11 tiles
# Processado P0918.png - 4x3 tiles
# Processado P2538.png - 9x8 tiles
# Processado P0337.png - 6x13 tiles
# Processado P2157.png - 7x5 tiles
# Processado P0169.png - 16x28 tiles
# Processado P1757.png - 16x16 tiles
# Processado P1170.png - 32x17 tiles
# Processado P2016.png - 3x2 tiles
# Processado P2270.png - 4x2 tiles
# Processado P1743.png - 20x17 tiles
# Processado P1364.png - 16x16 tiles
# Processado P0162.png - 6x5 tiles
# Processado P2518.png - 10x8 tiles
# Processado P0282.png - 4x5 tiles
# Processado P1453.png - 7x10 tiles
# Processado P2534.png - 11x11 tiles
# Processado P1783.png - 14x13 tiles
# Processado P2371.png - 9x7 tiles
# Processado P0000.png - 22x16 tiles
# Processado P2584.png - 12x9 tiles
# Processado P1475.png - 4x4 tiles
# Processado P0611.png - 7x4 tiles
# Processado P2207.png - 14x13 tiles
# Processado P0152.png - 4x4 tiles
# Processado P1962.png - 5x4 tiles
# Processado P1554.png - 16x16 tiles
# Processado P0909.png - 11x10 tiles
# Processado P1382.png - 30x19 tiles
# Processado P0256.png - 4x5 tiles
# Processado P0542.png - 4x3 tiles
# Processado P0586.png - 4x6 tiles
# Processado P2702.png - 10x8 tiles
# Processado P0488.png - 4x4 tiles
# Processado P0235.png - 4x10 tiles
# Processado P1148.png - 21x19 tiles
# Processado P1805.png - 7x6 tiles
# Processado P1945.png - 7x8 tiles
# Processado P1969.png - 7x5 tiles
# Processado P1297.png - 15x16 tiles
# Processado P2221.png - 4x4 tiles
# Processado P0232.png - 7x6 tiles
# Processado P0743.png - 3x7 tiles
# Processado P0987.png - 8x5 tiles
# Processado P0744.png - 5x6 tiles
# Processado P0140.png - 5x6 tiles
# Processado P1322.png - 16x21 tiles
# Processado P2107.png - 4x4 tiles
# Processado P0475.png - 4x5 tiles
# Processado P2479.png - 9x7 tiles
# Processado P1939.png - 5x6 tiles
# Processado P0689.png - 4x6 tiles
# Processado P1259.png - 16x16 tiles
# Processado P0346.png - 11x18 tiles
# Processado P0938.png - 5x7 tiles
# Processado P1906.png - 4x4 tiles
# Processado P1778.png - 11x13 tiles
# Processado P2522.png - 8x10 tiles
# Processado P2250.png - 7x12 tiles
# Processado P1915.png - 8x3 tiles
# Processado P0794.png - 6x7 tiles
# Processado P2727.png - 6x7 tiles
# Processado P0288.png - 5x5 tiles
# Processado P0087.png - 21x18 tiles
# Processado P2514.png - 11x8 tiles
# Processado P0711.png - 4x4 tiles
# Processado P2797.png - 8x4 tiles
# Processado P0504.png - 6x8 tiles
# Processado P2627.png - 6x6 tiles
# Processado P1704.png - 16x17 tiles
# Processado P0405.png - 6x3 tiles
# Processado P1238.png - 16x16 tiles
# Processado P1185.png - 5x6 tiles
# Processado P0452.png - 4x5 tiles
# Processado P0391.png - 4x6 tiles
# Processado P0754.png - 5x4 tiles
# Processado P2087.png - 4x6 tiles
# Processado P0860.png - 11x15 tiles
# Processado P2191.png - 4x2 tiles
# Processado P1231.png - 16x16 tiles
# Processado P1776.png - 5x6 tiles
# Processado P1526.png - 16x16 tiles
# Processado P1467.png - 15x16 tiles
# Processado P1392.png - 16x17 tiles
# Processado P0204.png - 5x4 tiles
# Processado P1307.png - 16x16 tiles
# Processado P0010.png - 8x8 tiles
# Processado P1443.png - 14x22 tiles
# Processado P1142.png - 20x16 tiles
# Processado P1155.png - 11x12 tiles
# Processado P1608.png - 16x16 tiles
# Processado P1552.png - 16x16 tiles
# Processado P2125.png - 4x2 tiles
# Processado P2036.png - 7x4 tiles
# Processado P0455.png - 4x5 tiles
# Processado P2266.png - 5x3 tiles
# Processado P0875.png - 7x11 tiles
# Processado P0641.png - 3x2 tiles
# Processado P1660.png - 16x16 tiles
# Processado P2622.png - 6x9 tiles
# Processado P1926.png - 7x3 tiles
# Processado P1165.png - 17x12 tiles
# Processado P1955.png - 7x9 tiles
# Processado P1245.png - 16x16 tiles
# Processado P0946.png - 9x14 tiles
# Processado P0032.png - 7x10 tiles
# Processado P2769.png - 16x11 tiles
# Processado P2359.png - 9x8 tiles
# Processado P2438.png - 9x6 tiles
# Processado P2554.png - 11x12 tiles
# Processado P0223.png - 6x8 tiles
# Processado P0229.png - 6x5 tiles
# Processado P0264.png - 3x4 tiles
# Processado P1607.png - 16x16 tiles
# Processado P1375.png - 13x16 tiles
# Processado P2422.png - 11x10 tiles
# Processado P0995.png - 8x3 tiles
# Processado P2743.png - 17x18 tiles
# Processado P0251.png - 7x8 tiles
# Processado P1114.png - 7x20 tiles
# Processado P1998.png - 3x2 tiles
# Processado P0869.png - 5x4 tiles
# Processado P0792.png - 5x6 tiles
# Processado P2497.png - 10x9 tiles
# Processado P0167.png - 14x16 tiles
# Processado P2566.png - 6x5 tiles
# Processado P1016.png - 5x12 tiles
# Processado P1249.png - 16x16 tiles
# Processado P2529.png - 8x8 tiles
# Processado P2770.png - 9x13 tiles
# Processado P1369.png - 16x21 tiles
# Processado P2572.png - 9x5 tiles
# Processado P2123.png - 4x3 tiles
# Processado P2280.png - 21x17 tiles
# Processado P2729.png - 11x13 tiles
# Processado P0979.png - 3x12 tiles
# Processado P1875.png - 12x24 tiles
# Processado P1691.png - 16x16 tiles
# Processado P0630.png - 4x14 tiles
# Processado P0008.png - 5x5 tiles
# Processado P0058.png - 5x5 tiles
# Processado P1891.png - 6x8 tiles
# Processado P1046.png - 5x11 tiles
# Processado P1130.png - 12x9 tiles
# Processado P1222.png - 15x16 tiles
# Processado P1519.png - 16x16 tiles
# Processado P2732.png - 11x13 tiles
# Processado P1746.png - 16x16 tiles
# Processado P1433.png - 4x4 tiles
# Processado P0562.png - 5x3 tiles
# Processado P2491.png - 11x11 tiles
# Processado P1054.png - 5x2 tiles
# Processado P2160.png - 7x6 tiles
# Processado P2114.png - 4x3 tiles
# Processado P2533.png - 10x10 tiles
# Processado P0334.png - 7x12 tiles
# Processado P0364.png - 4x4 tiles
# Processado P1052.png - 4x5 tiles
# Processado P0430.png - 7x5 tiles
# Processado P2156.png - 4x4 tiles
# Processado P1438.png - 18x12 tiles
# Processado P0159.png - 4x3 tiles
# Processado P0443.png - 5x5 tiles
# Processado P2790.png - 14x19 tiles
# Processado P2141.png - 5x5 tiles
# Processado P0512.png - 3x4 tiles
# Processado P1108.png - 12x14 tiles
# Processado P1765.png - 20x16 tiles
# Processado P1913.png - 7x6 tiles
# Processado P0273.png - 4x6 tiles
# Processado P1965.png - 3x3 tiles
# Processado P1909.png - 3x4 tiles
# Processado P2496.png - 8x8 tiles
# Processado P0415.png - 4x5 tiles
# Processado P2651.png - 8x7 tiles
# Processado P0236.png - 6x6 tiles
# Processado P0872.png - 5x10 tiles
# Processado P2063.png - 4x4 tiles
# Processado P0846.png - 3x7 tiles
# Processado P1703.png - 16x16 tiles
# Processado P0041.png - 10x13 tiles
# Processado P0142.png - 3x4 tiles
# Processado P2132.png - 4x4 tiles
# Processado P0610.png - 8x6 tiles
# Processado P0066.png - 13x13 tiles
# Processado P1077.png - 5x4 tiles
# Processado P1495.png - 22x20 tiles
# Processado P1558.png - 16x16 tiles
# Processado P2642.png - 22x28 tiles
# Processado P2142.png - 5x5 tiles
# Processado P1872.png - 20x16 tiles
# Processado P1466.png - 23x25 tiles
# Processado P1976.png - 4x4 tiles
# Processado P0100.png - 4x4 tiles
# Processado P1580.png - 16x16 tiles
# Processado P1395.png - 14x20 tiles
# Processado P1565.png - 16x17 tiles
# Processado P1758.png - 16x17 tiles
# Processado P1374.png - 25x25 tiles
# Processado P1606.png - 16x17 tiles
# Processado P2409.png - 9x7 tiles
# Processado P0484.png - 4x4 tiles
# Processado P0478.png - 5x4 tiles
# Processado P1387.png - 17x27 tiles
# Processado P1325.png - 16x16 tiles
# Processado P0464.png - 5x5 tiles
# Processado P0461.png - 4x5 tiles
# Processado P2454.png - 8x8 tiles
# Processado P1094.png - 18x5 tiles
# Processado P1351.png - 16x21 tiles
# Processado P1846.png - 5x5 tiles
# Processado P1997.png - 4x4 tiles
# Processado P0310.png - 8x12 tiles
# Processado P1439.png - 17x10 tiles
# Processado P1059.png - 11x14 tiles
# Processado P1725.png - 16x16 tiles
# Processado P1446.png - 15x8 tiles
# Processado P1062.png - 8x13 tiles
# Processado P1462.png - 19x24 tiles
# Processado P0437.png - 4x6 tiles
# Processado P1109.png - 10x8 tiles
# Processado P0723.png - 6x5 tiles
# Processado P0098.png - 5x4 tiles
# Processado P1224.png - 16x16 tiles
# Processado P1839.png - 8x6 tiles
# Processado P2055.png - 6x5 tiles
# Processado P0848.png - 4x4 tiles
# Processado P2095.png - 6x6 tiles
# Processado P1047.png - 4x4 tiles
# Processado P0555.png - 7x4 tiles
# Processado P0991.png - 8x9 tiles
# Processado P1063.png - 8x10 tiles
# Processado P0738.png - 8x4 tiles
# Processado P0618.png - 6x5 tiles
# Processado P2719.png - 10x18 tiles
# Processado P2739.png - 11x16 tiles
# Processado P0441.png - 5x6 tiles
# Processado P2761.png - 17x19 tiles
# Processado P0345.png - 14x6 tiles
# Processado P2565.png - 9x7 tiles
# Processado P0568.png - 9x4 tiles
# Processado P2708.png - 11x12 tiles
# Processado P2397.png - 8x8 tiles
# Processado P1305.png - 16x21 tiles
# Processado P0371.png - 5x4 tiles
# Processado P2247.png - 5x11 tiles
# Processado P2543.png - 10x9 tiles
# Processado P1352.png - 16x16 tiles
# Processado P2145.png - 5x4 tiles
# Processado P0960.png - 8x7 tiles
# Processado P1357.png - 16x16 tiles
# Processado P2690.png - 9x11 tiles
# Processado P0076.png - 3x3 tiles
# Processado P0800.png - 8x7 tiles
# Processado P0324.png - 8x11 tiles
# Processado P0911.png - 8x5 tiles
# Processado P0350.png - 5x4 tiles
# Processado P2536.png - 10x10 tiles
# Processado P1360.png - 16x16 tiles
# Processado P1006.png - 3x21 tiles
# Processado P1850.png - 7x6 tiles
# Processado P2211.png - 12x17 tiles
# Processado P0313.png - 6x6 tiles
# Processado P2235.png - 7x3 tiles
# Processado P0900.png - 9x9 tiles
# Processado P1214.png - 16x16 tiles
# Processado P0388.png - 5x3 tiles
# Processado P0238.png - 6x5 tiles
# Processado P0510.png - 4x5 tiles
# Processado P2613.png - 4x3 tiles
# Processado P0666.png - 4x3 tiles
# Processado P1848.png - 9x7 tiles
# Processado P1470.png - 23x22 tiles
# Processado P0957.png - 5x14 tiles
# Processado P1481.png - 14x12 tiles
# Processado P2019.png - 5x6 tiles
# Processado P1827.png - 6x7 tiles
# Processado P1306.png - 16x16 tiles
# Processado P0676.png - 4x2 tiles
# Processado P1061.png - 6x8 tiles
# Processado P0646.png - 5x4 tiles
# Processado P1816.png - 8x6 tiles
# Processado P1413.png - 16x22 tiles
# Processado P2144.png - 3x3 tiles
# Processado P0446.png - 4x7 tiles
# Processado P2205.png - 9x6 tiles
# Processado P0386.png - 5x3 tiles
# Processado P2517.png - 8x9 tiles
# Processado P1981.png - 7x8 tiles
# Processado P0597.png - 9x4 tiles
# Processado P2368.png - 10x11 tiles
# Processado P1199.png - 4x3 tiles
# Processado P1808.png - 6x4 tiles
# Processado P0975.png - 7x10 tiles
# Processado P0468.png - 5x4 tiles
# Processado P0867.png - 9x12 tiles
# Processado P1659.png - 16x16 tiles
# Processado P2275.png - 10x13 tiles
# Processado P2611.png - 8x13 tiles
# Processado P0299.png - 4x5 tiles
# Processado P2303.png - 3x2 tiles
# Processado P1421.png - 4x3 tiles
# Processado P2632.png - 5x6 tiles
# Processado P0458.png - 5x6 tiles
# Processado P2058.png - 5x4 tiles
# Processado P2210.png - 6x17 tiles
# Processado P0724.png - 5x7 tiles
# Processado P0702.png - 4x5 tiles
# Processado P2764.png - 16x17 tiles
# Processado P0546.png - 5x3 tiles
# Processado P0840.png - 8x14 tiles
# Processado P0857.png - 8x5 tiles
# Processado P2047.png - 5x5 tiles
# Processado P1159.png - 17x14 tiles
# Processado P0614.png - 6x4 tiles
# Processado P0357.png - 5x5 tiles
# Processado P1881.png - 4x3 tiles
# Processado P2513.png - 10x8 tiles
# Processado P2686.png - 15x25 tiles
# Processado P2311.png - 4x3 tiles
# Processado P2609.png - 19x16 tiles
# Processado P1057.png - 16x17 tiles
# Processado P2332.png - 10x12 tiles
# Processado P1597.png - 20x16 tiles
# Processado P1876.png - 7x6 tiles
# Processado P2482.png - 10x9 tiles
# Processado P1521.png - 16x16 tiles
# Processado P0459.png - 3x3 tiles
# Processado P2382.png - 8x10 tiles
# Processado P1019.png - 13x17 tiles
# Processado P0818.png - 3x4 tiles
# Processado P2279.png - 11x14 tiles
# Processado P2352.png - 10x10 tiles
# Processado P2590.png - 5x6 tiles
# Processado P1698.png - 16x16 tiles
# Processado P0218.png - 11x13 tiles
# Processado P1669.png - 16x17 tiles
# Processado P1640.png - 20x16 tiles
# Processado P1662.png - 16x16 tiles
# Processado P0629.png - 5x10 tiles
# Processado P1493.png - 20x18 tiles
# Processado P0829.png - 7x7 tiles
# Processado P1550.png - 16x16 tiles
# Processado P2520.png - 10x9 tiles
# Processado P1791.png - 19x20 tiles
# Processado P1563.png - 16x16 tiles
# Processado P0571.png - 9x5 tiles
# Processado P1954.png - 5x4 tiles
# Processado P1689.png - 20x16 tiles
# Processado P2077.png - 4x3 tiles
# Processado P2705.png - 9x6 tiles
# Processado P1638.png - 16x17 tiles
# Processado P0951.png - 4x26 tiles
# Processado P1893.png - 3x3 tiles
# Processado P1972.png - 11x26 tiles
# Processado P0505.png - 8x4 tiles
# Processado P0469.png - 4x4 tiles
# Processado P1670.png - 16x16 tiles
# Processado P0874.png - 10x6 tiles
# Processado P1680.png - 20x16 tiles
# Processado P0139.png - 4x4 tiles
# Processado P0973.png - 6x13 tiles
# Processado P2006.png - 11x8 tiles
# Processado P1272.png - 16x21 tiles
# Processado P0638.png - 3x3 tiles
# Processado P1927.png - 11x5 tiles
# Processado P2344.png - 8x10 tiles
# Processado P1076.png - 11x5 tiles
# Processado P1073.png - 5x6 tiles
# Processado P0030.png - 10x11 tiles
# Processado P2313.png - 3x3 tiles
# Processado P0609.png - 8x4 tiles
# Processado P2029.png - 3x2 tiles
# Processado P1221.png - 15x16 tiles
# Processado P2348.png - 6x6 tiles
# Processado P2465.png - 9x8 tiles
# Processado P1649.png - 16x16 tiles
# Processado P2401.png - 9x7 tiles
# Processado P1444.png - 16x10 tiles
# Processado P1277.png - 16x16 tiles
# Processado P0149.png - 4x3 tiles
# Processado P2232.png - 7x5 tiles
# Processado P0493.png - 4x3 tiles
# Processado P0440.png - 6x7 tiles
# Processado P2022.png - 7x4 tiles
# Processado P0625.png - 4x6 tiles
# Processado P2681.png - 5x6 tiles
# Processado P1113.png - 4x12 tiles
# Processado P0699.png - 4x4 tiles
# Processado P0438.png - 6x7 tiles
# Processado P0219.png - 5x11 tiles
# Processado P1634.png - 16x17 tiles
# Processado P0270.png - 5x6 tiles
# Processado P2116.png - 6x6 tiles
# Processado P0750.png - 4x8 tiles
# Processado P2418.png - 10x7 tiles
# Processado P0221.png - 9x6 tiles
# Processado P1501.png - 16x7 tiles
# Processado P0276.png - 6x5 tiles
# Processado P0843.png - 4x3 tiles
# Processado P2427.png - 11x11 tiles
# Processado P0520.png - 8x5 tiles
# Processado P0303.png - 4x4 tiles
# Processado P1871.png - 20x47 tiles
# Processado P1705.png - 16x16 tiles
# Processado P2138.png - 9x9 tiles
# Processado P2067.png - 5x8 tiles
# Processado P2134.png - 2x6 tiles
# Processado P1366.png - 16x21 tiles
# Processado P1339.png - 16x16 tiles
# Processado P2453.png - 9x8 tiles
# Processado P1790.png - 7x5 tiles
# Processado P2264.png - 3x9 tiles
# Processado P1861.png - 15x8 tiles
# Processado P1986.png - 5x3 tiles
# Processado P0757.png - 5x7 tiles
# Processado P2162.png - 6x5 tiles
# Processado P0343.png - 5x11 tiles
# Processado P1329.png - 16x16 tiles
# Processado P0212.png - 4x3 tiles
# Processado P0172.png - 7x11 tiles
# Processado P2349.png - 7x7 tiles
# Processado P0360.png - 3x3 tiles
# Processado P0782.png - 5x4 tiles
# Processado P0581.png - 7x8 tiles
# Processado P2503.png - 10x8 tiles
# Processado P0244.png - 4x5 tiles
# Processado P0898.png - 16x11 tiles
# Processado P1799.png - 4x4 tiles
# Processado P0602.png - 5x5 tiles
# Processado P0406.png - 5x4 tiles
# Processado P0713.png - 7x9 tiles
# Processado P0365.png - 4x6 tiles
# Processado P2243.png - 7x8 tiles
# Processado P2604.png - 7x5 tiles
# Processado P2326.png - 3x2 tiles
# Processado P0634.png - 4x4 tiles
# Processado P0933.png - 5x9 tiles
# Processado P1152.png - 16x10 tiles
# Processado P0978.png - 8x8 tiles
# Processado P0293.png - 5x6 tiles
# Processado P0417.png - 5x4 tiles
# Processado P2417.png - 9x6 tiles
# Processado P0012.png - 8x12 tiles
# Processado P2355.png - 8x9 tiles
# Processado P0652.png - 4x3 tiles
# Processado P2100.png - 6x7 tiles
# Processado P1201.png - 16x16 tiles
# Processado P2007.png - 18x10 tiles
# Processado P2787.png - 16x8 tiles
# Processado P1150.png - 13x12 tiles
# Processado P0878.png - 9x20 tiles
# Processado P0225.png - 4x5 tiles
# Processado P0039.png - 15x15 tiles
# Processado P2641.png - 22x30 tiles
# Processado P2693.png - 10x9 tiles
# Processado P1464.png - 19x15 tiles
# Processado P2552.png - 15x12 tiles
# Processado P1295.png - 16x21 tiles
# Processado P1620.png - 16x16 tiles
# Processado P1087.png - 12x10 tiles
# Processado P2045.png - 3x3 tiles
# Processado P0294.png - 5x6 tiles
# Processado P0020.png - 18x20 tiles
# Processado P1427.png - 22x31 tiles
# Processado P1864.png - 5x8 tiles
# Processado P2578.png - 6x5 tiles
# Processado P2673.png - 11x10 tiles
# Processado P0481.png - 4x3 tiles
# Processado P0777.png - 6x7 tiles
# Processado P0332.png - 8x9 tiles
# Processado P0603.png - 7x4 tiles
# Processado P2033.png - 7x7 tiles
# Processado P0664.png - 5x6 tiles
# Processado P0203.png - 3x7 tiles
# Processado P0531.png - 6x9 tiles
# Processado P0527.png - 4x6 tiles
# Processado P0070.png - 5x5 tiles
# Processado P0093.png - 5x4 tiles
# Processado P1533.png - 16x16 tiles
# Processado P2321.png - 3x2 tiles
# Processado P2309.png - 3x3 tiles
# Processado P2742.png - 10x10 tiles
# Processado P1867.png - 10x28 tiles
# Processado P1198.png - 2x2 tiles
# Processado P2302.png - 3x3 tiles
# Processado P2800.png - 13x13 tiles
# Processado P0624.png - 5x4 tiles
# Processado P1460.png - 8x7 tiles
# Processado P2335.png - 9x10 tiles
# Processado P0413.png - 5x4 tiles
# Processado P1426.png - 22x31 tiles
# Processado P1775.png - 8x5 tiles
# Processado P1966.png - 6x4 tiles
# Processado P1211.png - 16x16 tiles
# Processado P1359.png - 16x16 tiles
# Processado P2731.png - 20x20 tiles
# Processado P1361.png - 16x16 tiles
# Processado P2506.png - 8x8 tiles
# Processado P2389.png - 8x9 tiles
# Processado P0038.png - 17x10 tiles
# Processado P1688.png - 16x16 tiles
# Processado P0254.png - 8x10 tiles
# Processado P0335.png - 7x9 tiles
# Processado P0330.png - 4x5 tiles
# Processado P1646.png - 16x17 tiles
# Processado P2154.png - 4x4 tiles
# Processado P2301.png - 4x3 tiles
# Processado P0178.png - 8x8 tiles
# Processado P1507.png - 7x5 tiles
# Processado P1522.png - 12x16 tiles
# Processado P2419.png - 9x7 tiles
# Processado P1078.png - 9x8 tiles
# Processado P1812.png - 7x6 tiles
# Processado P2777.png - 10x17 tiles
# Processado P2663.png - 9x10 tiles
# Processado P2287.png - 9x10 tiles
# Processado P2747.png - 10x12 tiles
# Processado P0373.png - 4x4 tiles
# Processado P2048.png - 7x7 tiles
# Processado P1594.png - 16x16 tiles
# Processado P0895.png - 7x6 tiles
# Processado P2551.png - 17x18 tiles
# Processado P2579.png - 8x7 tiles
# Processado P0703.png - 8x6 tiles
# Processado P0428.png - 5x4 tiles
# Processado P2201.png - 4x5 tiles
# Processado P2685.png - 9x6 tiles
# Processado P0477.png - 5x4 tiles
# Processado P2283.png - 9x10 tiles
# Processado P2512.png - 9x8 tiles
# Processado P2071.png - 3x3 tiles
# Processado P0780.png - 7x5 tiles
# Processado P1631.png - 16x16 tiles
# Processado P2164.png - 11x19 tiles
# Processado P0947.png - 7x21 tiles
# Processado P0190.png - 5x12 tiles
# Processado P1502.png - 17x17 tiles
# Processado P2282.png - 13x13 tiles
# Processado P0896.png - 10x8 tiles
# Processado P0823.png - 10x7 tiles
# Processado P1015.png - 4x16 tiles
# Processado P2110.png - 7x3 tiles
# Processado P1600.png - 16x16 tiles
# Processado P2466.png - 8x7 tiles
# Processado P2471.png - 9x7 tiles
# Processado P2468.png - 8x7 tiles
# Processado P1419.png - 19x14 tiles
# Processado P1079.png - 7x6 tiles
# Processado P2013.png - 4x8 tiles
# Processado P1164.png - 17x12 tiles
# Processado P0649.png - 3x3 tiles
# Processado P1267.png - 15x16 tiles
# Processado P0899.png - 8x9 tiles
# Processado P0210.png - 5x10 tiles
# Processado P0144.png - 4x3 tiles
# Processado P0873.png - 13x7 tiles
# Processado P1804.png - 6x5 tiles
# Processado P0392.png - 3x5 tiles
# Processado P0355.png - 4x4 tiles
# Processado P2730.png - 6x6 tiles
# Processado P2605.png - 9x10 tiles
# Processado P2576.png - 10x4 tiles
# Processado P2076.png - 5x8 tiles
# Processado P1187.png - 4x3 tiles
# Processado P1092.png - 9x8 tiles
# Processado P1171.png - 21x27 tiles
# Processado P1896.png - 3x4 tiles
# Processado P2558.png - 19x21 tiles
# Processado P1780.png - 19x15 tiles
# Processado P2614.png - 6x7 tiles
# Processado P1053.png - 5x6 tiles
# Processado P0944.png - 4x14 tiles
# Processado P1645.png - 16x16 tiles
# Processado P2433.png - 8x8 tiles
# Processado P2650.png - 8x12 tiles
# Processado P0082.png - 20x22 tiles
# Processado P0387.png - 4x7 tiles
# Processado P1736.png - 20x17 tiles
# Processado P1216.png - 16x16 tiles
# Processado P1959.png - 6x4 tiles
# Processado P1509.png - 13x19 tiles
# Processado P0209.png - 8x16 tiles
# Processado P0766.png - 4x4 tiles
# Processado P0103.png - 4x4 tiles
# Processado P2163.png - 6x6 tiles
# Processado P1110.png - 4x2 tiles
# Processado P1923.png - 6x5 tiles
# Processado P0779.png - 4x3 tiles
# Processado P1117.png - 5x7 tiles
# Processado P2070.png - 3x2 tiles
# Processado P2324.png - 4x4 tiles
# Processado P2028.png - 4x6 tiles
# Processado P2005.png - 17x20 tiles
# Processado P1571.png - 20x16 tiles
# Processado P1071.png - 14x10 tiles
# Processado P1161.png - 26x25 tiles
# Processado P2426.png - 9x8 tiles
# Processado P0768.png - 4x9 tiles
# Processado P2775.png - 12x18 tiles
# Processado P0537.png - 9x5 tiles
# Processado P0907.png - 7x7 tiles
# Processado P2676.png - 15x10 tiles
# Processado P1391.png - 16x26 tiles
# Processado P2053.png - 6x6 tiles
# Processado P0340.png - 6x12 tiles
# Processado P0163.png - 3x4 tiles
# Processado P2245.png - 5x5 tiles
# Processado P0631.png - 8x6 tiles
# Processado P2305.png - 3x2 tiles
# Processado P0021.png - 13x12 tiles
# Processado P2421.png - 9x9 tiles
# Processado P0111.png - 7x8 tiles
# Processado P1358.png - 16x16 tiles
# Processado P0963.png - 4x9 tiles
# Processado P1685.png - 12x17 tiles
# Processado P0061.png - 8x8 tiles
# Processado P2109.png - 4x3 tiles
# Processado P0981.png - 6x8 tiles
# Processado P2704.png - 8x15 tiles
# Processado P1739.png - 16x16 tiles
# Processado P1934.png - 4x4 tiles
# Processado P2430.png - 9x8 tiles
# Processado P0054.png - 9x9 tiles
# Processado P1788.png - 6x7 tiles
# Processado P0853.png - 5x5 tiles
# Processado P1107.png - 4x3 tiles
# Processado P2615.png - 4x5 tiles
# Processado P1866.png - 14x11 tiles
# Processado P0999.png - 4x9 tiles
# Processado P1899.png - 4x2 tiles
# Processado P1228.png - 16x16 tiles
# Processado P0769.png - 7x5 tiles
# Processado P1055.png - 18x19 tiles
# Processado P2788.png - 4x6 tiles
# Processado P2553.png - 13x13 tiles
# Processado P2334.png - 8x9 tiles
# Processado P0894.png - 8x14 tiles
# Processado P1431.png - 11x16 tiles
# Processado P0207.png - 6x4 tiles
# Processado P0746.png - 3x7 tiles
# Processado P2490.png - 11x11 tiles
# Processado P0905.png - 6x3 tiles
# Processado P1060.png - 8x10 tiles
# Processado P2089.png - 5x2 tiles
# Processado P0018.png - 7x8 tiles
# Processado P2457.png - 9x7 tiles
# Processado P0691.png - 3x3 tiles
# Processado P0378.png - 5x5 tiles
# Processado P2597.png - 7x6 tiles
# Processado P2494.png - 10x8 tiles
# Processado P0314.png - 6x5 tiles
# Processado P1043.png - 6x5 tiles
# Processado P2653.png - 12x9 tiles
# Processado P0263.png - 4x3 tiles
# Processado P1841.png - 7x8 tiles
# Processado P2131.png - 6x6 tiles
# Processado P1869.png - 19x30 tiles
# Processado P2435.png - 10x7 tiles
# Processado P0483.png - 3x5 tiles
# Processado P1037.png - 14x7 tiles
# Processado P0292.png - 4x5 tiles
# Processado P1451.png - 16x9 tiles
# Processado P1465.png - 10x10 tiles
# Processado P0176.png - 4x3 tiles
# Processado P1730.png - 16x16 tiles
# Processado P0851.png - 4x4 tiles
# Processado P2531.png - 10x10 tiles
# Processado P0445.png - 5x4 tiles
# Processado P0322.png - 8x7 tiles
# Processado P2257.png - 5x3 tiles
# Processado P0941.png - 4x12 tiles
# Processado P2432.png - 7x11 tiles
# Processado P1589.png - 16x16 tiles
# Processado P1200.png - 16x21 tiles
# Processado P2469.png - 8x7 tiles
# Processado P1849.png - 11x11 tiles
# Processado P1833.png - 3x5 tiles
# Processado P1708.png - 16x16 tiles
# Processado P0601.png - 4x4 tiles
# Processado P0753.png - 4x3 tiles
# Processado P1260.png - 16x16 tiles
# Processado P0692.png - 5x4 tiles
# Processado P1661.png - 16x16 tiles
# Processado P0533.png - 5x6 tiles
# Processado P1368.png - 16x16 tiles
# Processado P0593.png - 4x6 tiles
# Processado P0573.png - 5x6 tiles
# Processado P0707.png - 5x6 tiles
# Processado P1336.png - 16x21 tiles
# Processado P0926.png - 10x10 tiles
# Processado P0760.png - 4x6 tiles
# Processado P0029.png - 10x11 tiles
# Processado P1545.png - 16x16 tiles
# Processado P1935.png - 3x6 tiles
# Processado P1744.png - 16x16 tiles
# Processado P1683.png - 16x16 tiles
# Processado P0085.png - 10x11 tiles
# Processado P2362.png - 8x10 tiles
# Processado P2387.png - 7x8 tiles
# Processado P2792.png - 7x10 tiles
# Processado P2148.png - 5x3 tiles
# Processado P2244.png - 5x5 tiles
# Processado P0381.png - 4x5 tiles
# Processado P2664.png - 10x8 tiles
# Processado P2086.png - 6x5 tiles
# Processado P0928.png - 5x3 tiles
# Processado P2179.png - 5x5 tiles
# Processado P2687.png - 22x11 tiles
# Processado P0906.png - 8x8 tiles
# Processado P0362.png - 4x3 tiles
# Processado P1497.png - 17x13 tiles
# Processado P2001.png - 4x4 tiles
# Processado P1144.png - 10x6 tiles
# Processado P0099.png - 6x5 tiles
# Processado P2189.png - 6x3 tiles
# Processado P0632.png - 5x12 tiles
# Processado P2304.png - 3x3 tiles
# Processado P0580.png - 4x4 tiles
# Processado P0572.png - 4x8 tiles
# Processado P2805.png - 13x12 tiles
# Processado P2458.png - 10x8 tiles
# Processado P0479.png - 4x4 tiles
# Processado P1932.png - 4x2 tiles
# Processado P1587.png - 16x16 tiles
# Processado P0870.png - 5x4 tiles
# Processado P2638.png - 8x4 tiles
# Processado P1394.png - 15x27 tiles
# Processado P0522.png - 8x4 tiles
# Processado P0248.png - 5x3 tiles
# Processado P2039.png - 4x3 tiles
# Processado P2560.png - 14x15 tiles
# Processado P0407.png - 4x7 tiles
# Processado P0605.png - 5x3 tiles
# Processado P0442.png - 4x6 tiles
# Processado P2672.png - 11x16 tiles
# Processado P0714.png - 3x3 tiles
# Processado P1337.png - 16x21 tiles
# Processado P2523.png - 11x7 tiles
# Processado P0187.png - 6x10 tiles
# Processado P2262.png - 4x9 tiles
# Processado P0308.png - 6x6 tiles
# Processado P1067.png - 13x9 tiles
# Processado P0920.png - 8x6 tiles
# Processado P0296.png - 5x5 tiles
# Processado P1789.png - 6x7 tiles
# Processado P2228.png - 9x8 tiles
# Processado P1785.png - 6x5 tiles
# Processado P1933.png - 6x7 tiles
# Processado P0553.png - 4x7 tiles
# Processado P2248.png - 4x3 tiles
# Processado P1080.png - 13x7 tiles
# Processado P0042.png - 9x8 tiles
# Processado P0078.png - 3x2 tiles
# Processado P2492.png - 10x8 tiles
# Processado P2475.png - 9x8 tiles
# Processado P0393.png - 3x4 tiles
# Processado P2569.png - 7x4 tiles
# Processado P2746.png - 10x12 tiles
# Processado P2411.png - 7x8 tiles
# Processado P1070.png - 15x17 tiles
# Processado P1096.png - 6x18 tiles
# Processado P2227.png - 4x3 tiles
# Processado P1984.png - 3x3 tiles
# Processado P2079.png - 4x3 tiles
# Processado P0389.png - 5x4 tiles
# Processado P0425.png - 5x3 tiles
# Processado P1837.png - 8x5 tiles
# Processado P2505.png - 10x9 tiles
# Processado P0281.png - 5x4 tiles
# Processado P1818.png - 5x10 tiles
# Processado P2594.png - 11x7 tiles
# Processado P1753.png - 16x16 tiles
# Processado P2319.png - 3x2 tiles
# Processado P0419.png - 4x5 tiles
# Processado P0637.png - 4x4 tiles
# Processado P0719.png - 5x7 tiles
# Processado P2507.png - 9x10 tiles
# Processado P0439.png - 4x4 tiles
# Processado P0888.png - 6x25 tiles
# Processado P2670.png - 11x10 tiles
# Processado P0049.png - 8x7 tiles
# Processado P0301.png - 4x4 tiles
# Processado P0940.png - 6x6 tiles
# Processado P2668.png - 11x7 tiles
# Processado P1641.png - 20x16 tiles
# Processado P1912.png - 6x4 tiles
# Processado P2253.png - 5x13 tiles
# Processado P2783.png - 5x5 tiles
# Processado P2190.png - 6x4 tiles
# Processado P0914.png - 8x7 tiles
# Processado P1010.png - 5x9 tiles
# Processado P1618.png - 16x17 tiles
# Processado P1484.png - 9x8 tiles
# Processado P1674.png - 16x16 tiles
# Processado P1887.png - 4x4 tiles
# Processado P2327.png - 4x3 tiles
# Processado P1602.png - 16x17 tiles
# Processado P1300.png - 16x21 tiles
# Processado P2548.png - 9x9 tiles
# Processado P0344.png - 8x7 tiles
# Processado P2278.png - 5x7 tiles
# Processado P1287.png - 16x21 tiles
# Processado P1166.png - 19x14 tiles
# Processado P2018.png - 6x5 tiles
# Processado P2004.png - 7x5 tiles
# Processado P1874.png - 14x14 tiles
# Processado P2159.png - 5x7 tiles
# Processado P2061.png - 3x3 tiles
# Processado P2103.png - 3x2 tiles
# Processado P1609.png - 16x17 tiles
# Processado P1863.png - 13x12 tiles
# Processado P2222.png - 5x4 tiles
# Processado P0587.png - 4x6 tiles
# Processado P1989.png - 5x3 tiles
# Processado P1948.png - 4x5 tiles
# Processado P2456.png - 11x8 tiles
# Processado P1868.png - 15x41 tiles
# Processado P0892.png - 9x10 tiles
# Processado P1842.png - 3x4 tiles
# Processado P0487.png - 5x5 tiles
# Processado P2618.png - 6x4 tiles
# Processado P0321.png - 8x7 tiles
# Processado P2674.png - 12x11 tiles
# Processado P1414.png - 20x24 tiles
# Processado P1274.png - 16x16 tiles
# Processado P0116.png - 4x3 tiles
# Processado P1892.png - 4x3 tiles
# Processado P1990.png - 5x6 tiles
# Processado P0731.png - 6x7 tiles
# Processado P1697.png - 16x16 tiles
# Processado P2184.png - 3x2 tiles
# Processado P0627.png - 5x14 tiles
# Processado P2180.png - 4x2 tiles
# Processado P1717.png - 16x16 tiles
# Processado P1340.png - 16x16 tiles
# Processado P0730.png - 5x7 tiles
# Processado P1719.png - 16x17 tiles
# Processado P2192.png - 7x11 tiles
# Processado P1489.png - 19x20 tiles
# Processado P0418.png - 4x6 tiles
# Processado P1702.png - 16x17 tiles
# Processado P0642.png - 5x3 tiles
# Processado P2735.png - 11x13 tiles
# Processado P2196.png - 5x5 tiles
# Processado P1311.png - 15x16 tiles
# Processado P2801.png - 16x12 tiles
# Processado P0435.png - 5x4 tiles
# Processado P1851.png - 9x7 tiles
# Processado P2395.png - 10x12 tiles
# Processado P0617.png - 7x7 tiles
# Processado P0687.png - 7x7 tiles
# Processado P2149.png - 3x3 tiles
# Processado P0548.png - 5x3 tiles
# Processado P0036.png - 22x13 tiles
# Processado P1333.png - 16x16 tiles
# Processado P0422.png - 4x4 tiles
# Processado P2528.png - 8x10 tiles
# Processado P0317.png - 4x8 tiles
# Processado P1399.png - 24x26 tiles
# Processado P0126.png - 2x2 tiles
# Processado P2483.png - 8x7 tiles
# Processado P1794.png - 18x13 tiles
# Processado P2646.png - 11x6 tiles
# Processado P0893.png - 20x7 tiles
# Processado P1292.png - 16x16 tiles
# Processado P0220.png - 5x8 tiles
# Processado P2173.png - 9x22 tiles
# Processado P0370.png - 4x4 tiles
# Processado P0133.png - 6x5 tiles
# Processado P1900.png - 4x3 tiles
# Processado P1779.png - 4x4 tiles
# Processado P1168.png - 29x12 tiles
# Processado P0567.png - 4x4 tiles
# Processado P1479.png - 9x10 tiles
# Processado P2793.png - 7x8 tiles
# Processado P1658.png - 20x17 tiles
# Processado P1795.png - 6x4 tiles
# Processado P2467.png - 8x10 tiles
# Processado P1158.png - 21x26 tiles
# Processado P2755.png - 19x8 tiles
# Processado P0448.png - 5x4 tiles
# Processado P2002.png - 7x6 tiles
# Processado P1003.png - 3x32 tiles
# Processado P1105.png - 4x3 tiles
# Processado P1639.png - 20x16 tiles
# Processado P1247.png - 16x16 tiles
# Processado P0578.png - 5x9 tiles
# Processado P2066.png - 5x5 tiles
# Processado P2561.png - 5x6 tiles
# Processado P2017.png - 4x5 tiles
# Processado P1540.png - 16x16 tiles
# Processado P1614.png - 16x16 tiles
# Processado P2460.png - 8x8 tiles
# Processado P0831.png - 3x5 tiles
# Processado P0052.png - 9x8 tiles
# Processado P1908.png - 5x4 tiles
# Processado P0275.png - 5x5 tiles
# Processado P0762.png - 3x7 tiles
# Processado P0174.png - 6x8 tiles
# Processado P2728.png - 9x12 tiles
# Processado P2115.png - 6x4 tiles
# Processado P2030.png - 20x29 tiles
# Processado P1121.png - 5x9 tiles
# Processado P1167.png - 18x11 tiles
# Processado P1344.png - 16x21 tiles
# Processado P1291.png - 16x16 tiles
# Processado P0817.png - 5x5 tiles
# Processado P1714.png - 16x17 tiles
# Processado P0934.png - 5x11 tiles
# Processado P0653.png - 5x5 tiles
# Processado P1843.png - 4x3 tiles
# Processado P0728.png - 6x9 tiles
# Processado P2621.png - 6x7 tiles
# Processado P1928.png - 3x3 tiles
# Processado P0778.png - 6x7 tiles
# Processado P0285.png - 4x3 tiles
# Processado P2143.png - 3x4 tiles
# Processado P1258.png - 16x21 tiles
# Processado P1131.png - 24x17 tiles
# Processado P0074.png - 4x3 tiles
# Processado P1845.png - 14x16 tiles
# Processado P1250.png - 16x16 tiles
# Processado P0083.png - 18x21 tiles
# Processado P0554.png - 4x6 tiles
# Processado P0255.png - 8x6 tiles
# Processado P0952.png - 7x24 tiles
# Processado P0734.png - 7x9 tiles
# Processado P0827.png - 8x5 tiles
# Processado P1633.png - 16x16 tiles
# Processado P0013.png - 7x6 tiles
# Processado P2065.png - 5x4 tiles
# Processado P0289.png - 5x5 tiles
# Processado P0158.png - 11x13 tiles
# Processado P1894.png - 3x5 tiles
# Processado P2644.png - 14x18 tiles
# Processado P1673.png - 20x16 tiles
# Processado P1469.png - 8x9 tiles
# Processado P1193.png - 4x5 tiles
# Processado P1498.png - 13x10 tiles
# Processado P2217.png - 8x3 tiles
# Processado P0849.png - 5x7 tiles
# Processado P2182.png - 7x5 tiles
# Processado P0538.png - 5x9 tiles
# Processado P0908.png - 10x10 tiles
# Processado P1756.png - 16x16 tiles
# Processado P1942.png - 6x6 tiles
# Processado P2339.png - 9x10 tiles
# Processado P0315.png - 5x5 tiles
# Processado P2616.png - 5x8 tiles
# Processado P0260.png - 6x8 tiles
# Processado P0002.png - 9x10 tiles
# Processado P0202.png - 5x5 tiles
# Processado P0733.png - 4x13 tiles
# Processado P0828.png - 9x6 tiles
# Processado P2634.png - 6x7 tiles
# Processado P1132.png - 19x21 tiles
# Processado P1365.png - 16x16 tiles
# Processado P0521.png - 8x5 tiles
# Processado P1251.png - 16x21 tiles
# Processado P2740.png - 10x16 tiles
# Processado P0803.png - 4x6 tiles
# Processado P0367.png - 6x7 tiles
# Processado P0582.png - 6x6 tiles
# Processado P2464.png - 9x8 tiles
# Processado P1907.png - 4x4 tiles
# Processado P1707.png - 16x16 tiles
# Processado P2249.png - 25x10 tiles
# Processado P1298.png - 15x16 tiles
# Processado P2062.png - 4x3 tiles
# Processado P1918.png - 4x3 tiles
# Processado P0171.png - 6x11 tiles
# Processado P1832.png - 10x6 tiles
# Processado P0363.png - 5x4 tiles
# Processado P1741.png - 16x17 tiles
# Processado P2370.png - 7x7 tiles
# Processado P0416.png - 5x3 tiles
# Processado P1977.png - 7x7 tiles
# Processado P0005.png - 4x4 tiles
# Processado P2527.png - 11x10 tiles
# Processado P1539.png - 16x16 tiles
# Processado P2665.png - 9x11 tiles
# Processado P0549.png - 4x4 tiles
# Processado P0434.png - 4x6 tiles
# Processado P2655.png - 12x20 tiles
# Processado P0804.png - 4x6 tiles
# Processado P0327.png - 8x7 tiles
# Processado P2423.png - 8x8 tiles
# Processado P2682.png - 17x11 tiles
# Processado P0884.png - 6x5 tiles
# Processado P0096.png - 5x4 tiles
# Processado P1784.png - 7x5 tiles
# Processado P1445.png - 13x22 tiles
# Processado P0781.png - 5x4 tiles
# Processado P1910.png - 3x3 tiles
# Processado P2700.png - 11x13 tiles
# Processado P1308.png - 16x21 tiles
# Processado P2545.png - 10x11 tiles
# Processado P1724.png - 20x16 tiles
# Processado P2379.png - 9x9 tiles
# Processado P2240.png - 7x4 tiles
# Processado P0668.png - 4x4 tiles
# Processado P0380.png - 4x4 tiles
# Processado P1328.png - 16x16 tiles
# Processado P0109.png - 5x5 tiles
# Processado P0376.png - 4x3 tiles
# Processado P0832.png - 5x4 tiles
# Processado P1243.png - 16x16 tiles
# Processado P1537.png - 20x16 tiles
# Processado P0563.png - 5x6 tiles
# Processado P0727.png - 5x7 tiles
# Processado P1174.png - 24x24 tiles
# Processado P1319.png - 16x21 tiles
# Processado P0786.png - 8x14 tiles
# Processado P1555.png - 16x16 tiles
# Processado P2056.png - 4x3 tiles
# Processado P0272.png - 4x4 tiles
# Processado P2751.png - 14x15 tiles
# Processado P1049.png - 22x7 tiles
# Processado P0855.png - 4x5 tiles
# Processado P0025.png - 17x18 tiles
# Processado P2306.png - 3x3 tiles
# Processado P0431.png - 5x5 tiles
# Processado P0921.png - 11x15 tiles
# Processado P2388.png - 8x9 tiles
# Processado P1487.png - 6x7 tiles
# Processado P1747.png - 16x16 tiles
# Processado P2759.png - 20x35 tiles
# Processado P2219.png - 4x5 tiles
# Processado P2532.png - 11x11 tiles
# Processado P1856.png - 10x11 tiles
# Processado P1616.png - 16x16 tiles
# Processado P1223.png - 15x21 tiles
# Processado P0850.png - 4x5 tiles
# Processado P2185.png - 5x2 tiles
# Processado P1084.png - 5x5 tiles
# Processado P1951.png - 5x7 tiles
# Processado P2734.png - 11x17 tiles
# Processado P0517.png - 5x5 tiles
# Processado P1964.png - 7x6 tiles
# Processado P2392.png - 8x7 tiles
# Processado P1119.png - 4x14 tiles
# Processado P2073.png - 5x3 tiles
# Processado P1208.png - 16x16 tiles
# Processado P1418.png - 13x10 tiles
# Processado P0482.png - 4x4 tiles
# Processado P2706.png - 6x7 tiles
# Processado P2380.png - 7x9 tiles
# Processado P1748.png - 16x16 tiles
# Processado P0094.png - 5x5 tiles
# Processado P1938.png - 6x8 tiles
# Processado P1458.png - 19x16 tiles
# Processado P2213.png - 6x7 tiles
# Processado P1207.png - 16x21 tiles
# Processado P1139.png - 26x36 tiles
# Processado P0806.png - 5x6 tiles
# Processado P1389.png - 22x24 tiles
# Processado P2127.png - 4x4 tiles
# Processado P0424.png - 5x5 tiles
# Processado P0972.png - 6x9 tiles
# Processado P2403.png - 8x9 tiles
# Processado P1929.png - 9x6 tiles
# Processado P2175.png - 3x2 tiles
# Processado P1524.png - 16x16 tiles
# Processado P1740.png - 16x16 tiles
# Processado P0280.png - 4x3 tiles
# Processado P1480.png - 11x9 tiles
# Processado P0950.png - 5x19 tiles
# Processado P1205.png - 16x16 tiles
# Processado P2710.png - 10x8 tiles
# Processado P1412.png - 11x26 tiles
# Processado P0716.png - 7x4 tiles
# Processado P0881.png - 4x4 tiles
# Processado P0361.png - 3x3 tiles
# Processado P2177.png - 5x3 tiles
# Processado P1499.png - 12x11 tiles
# Processado P0986.png - 10x6 tiles
# Processado P0151.png - 4x3 tiles
# Processado P1140.png - 19x23 tiles
# Processado P1996.png - 5x7 tiles
# Processado P1632.png - 16x16 tiles
# Processado P0124.png - 10x8 tiles
# Processado P1020.png - 4x10 tiles
# Processado P1822.png - 4x3 tiles
# Processado P0183.png - 8x25 tiles
# Processado P1773.png - 5x3 tiles
# Processado P0286.png - 4x4 tiles
# Processado P2696.png - 10x12 tiles
# Processado P0591.png - 6x5 tiles
# Processado P0401.png - 4x3 tiles
# Processado P0471.png - 4x4 tiles
# Processado P0821.png - 3x4 tiles
# Processado P1455.png - 22x23 tiles
# Processado P1428.png - 11x13 tiles
# Processado P1823.png - 11x8 tiles
# Processado P0626.png - 8x4 tiles
# Processado P1636.png - 16x16 tiles
# Processado P2716.png - 10x16 tiles
# Processado P0922.png - 8x7 tiles
# Processado P0136.png - 11x12 tiles
# Processado P2328.png - 4x3 tiles
# Processado P1343.png - 16x16 tiles
# Processado P2748.png - 12x13 tiles
# Processado P2026.png - 12x4 tiles
# Processado P1217.png - 16x16 tiles
# Processado P2226.png - 5x17 tiles
# Processado P1676.png - 16x17 tiles
# Processado P0685.png - 8x8 tiles
# Processado P0775.png - 8x7 tiles
# Processado P1309.png - 15x16 tiles
# Processado P0868.png - 10x13 tiles
# Processado P0925.png - 8x5 tiles
# Processado P1265.png - 16x21 tiles
# Processado P1288.png - 16x16 tiles
# Processado P2606.png - 11x7 tiles
# Processado P2680.png - 8x8 tiles
# Processado P2251.png - 5x5 tiles
# Processado P1209.png - 16x16 tiles
# Processado P1768.png - 16x16 tiles
# Processado P1321.png - 16x16 tiles
# Processado P1895.png - 3x3 tiles
# Processado P2390.png - 8x11 tiles
# Processado P2203.png - 8x6 tiles
# Processado P0022.png - 26x16 tiles
# Processado P2373.png - 10x9 tiles
# Processado P2224.png - 5x19 tiles
# Processado P1517.png - 16x17 tiles
# Processado P2014.png - 12x12 tiles
# Processado P1535.png - 20x16 tiles
# Processado P0516.png - 5x6 tiles
# Processado P0783.png - 6x10 tiles
# Processado P2038.png - 3x4 tiles
# Processado P2204.png - 7x3 tiles
# Processado P2639.png - 4x5 tiles
# Processado P0541.png - 5x6 tiles
# Processado P2436.png - 8x6 tiles
# Processado P1186.png - 4x3 tiles
# Processado P2234.png - 7x6 tiles
# Processado P2485.png - 10x7 tiles
# Processado P2090.png - 5x3 tiles
# Processado P0697.png - 5x6 tiles
# Processado P1653.png - 16x16 tiles
# Processado P2626.png - 4x5 tiles
# Processado P2354.png - 8x8 tiles
# Processado P2130.png - 5x5 tiles
# Processado P1515.png - 16x16 tiles
# Processado P2750.png - 15x13 tiles
# Processado P0695.png - 5x6 tiles
# Processado P0160.png - 11x14 tiles
# Processado P0596.png - 8x4 tiles
# Processado P2472.png - 10x7 tiles
# Processado P2054.png - 3x4 tiles
# Processado P1118.png - 2x8 tiles
# Processado P2199.png - 6x5 tiles
# Processado P0726.png - 5x7 tiles
# Processado P0064.png - 9x12 tiles
# Processado P1591.png - 16x17 tiles
# Processado P0825.png - 4x4 tiles
# Processado P1256.png - 16x16 tiles
# Processado P0068.png - 4x3 tiles
# Processado P1947.png - 4x3 tiles
# Processado P0845.png - 5x4 tiles
# Processado P0460.png - 5x3 tiles
# Processado P0809.png - 5x6 tiles
# Processado P0785.png - 14x9 tiles
# Processado P1276.png - 16x16 tiles
# Processado P0258.png - 5x4 tiles
# Processado P2269.png - 6x5 tiles
# Processado P2495.png - 11x7 tiles
# Processado P1556.png - 16x17 tiles
# Processado P0556.png - 8x3 tiles
# Processado P0091.png - 5x4 tiles
# Processado P2049.png - 5x8 tiles
# Processado P2452.png - 9x7 tiles
# Processado P0241.png - 5x5 tiles
# Processado P0095.png - 5x4 tiles
# Processado P0201.png - 6x5 tiles
# Processado P2637.png - 10x8 tiles
# Processado P1338.png - 16x16 tiles
# Processado P0188.png - 9x8 tiles
# Processado P0122.png - 6x7 tiles
# Processado P0222.png - 6x7 tiles
# Processado P2725.png - 11x18 tiles
# Processado P1116.png - 7x26 tiles
# Processado P0503.png - 5x5 tiles
# Processado P0489.png - 4x4 tiles
# Processado P1686.png - 16x17 tiles
# Processado P2669.png - 6x8 tiles
# Processado P0395.png - 4x5 tiles
# Processado P2060.png - 3x3 tiles
# Processado P2656.png - 8x7 tiles
# Processado P2720.png - 10x17 tiles
# Processado P0233.png - 5x5 tiles
# Processado P0011.png - 6x6 tiles
# Processado P0400.png - 4x5 tiles
# Processado P0252.png - 6x8 tiles
# Processado P0338.png - 6x11 tiles
# Processado P0835.png - 6x12 tiles
# Processado P2585.png - 7x7 tiles
# Processado P2612.png - 17x27 tiles
# Processado P2753.png - 9x14 tiles
# Processado P0915.png - 7x6 tiles
# Processado P1617.png - 16x16 tiles
# Processado P2281.png - 15x15 tiles
# Processado P1574.png - 16x16 tiles
# Processado P2756.png - 17x19 tiles
# Processado P2074.png - 8x5 tiles
# Processado P1482.png - 10x10 tiles
# Processado P1994.png - 4x4 tiles
# Processado P0693.png - 4x6 tiles
# Processado P0113.png - 17x15 tiles
# Processado P1930.png - 10x6 tiles
# Processado P2260.png - 3x6 tiles
# Processado P2080.png - 4x2 tiles
# Processado P2133.png - 3x2 tiles
# Processado P0226.png - 4x4 tiles
# Processado P1682.png - 16x16 tiles
# Processado P2557.png - 15x20 tiles
# Processado P0966.png - 6x13 tiles
# Processado P0861.png - 11x9 tiles
# Processado P0879.png - 11x13 tiles
# Processado P1141.png - 18x22 tiles
# Processado P2258.png - 4x10 tiles
# Processado P2237.png - 5x4 tiles
# Processado P0384.png - 3x3 tiles
# Processado P1098.png - 9x10 tiles
# Processado P0656.png - 3x5 tiles
# Processado P0358.png - 4x5 tiles
# Processado P1353.png - 16x16 tiles
# Processado P2052.png - 3x4 tiles
# Processado P1232.png - 16x16 tiles
# Processado P0759.png - 5x5 tiles
# Processado P0283.png - 3x5 tiles
# Processado P0129.png - 8x6 tiles
# Processado P1191.png - 3x3 tiles
# Processado P2659.png - 8x11 tiles
# Processado P1279.png - 16x16 tiles
# Processado P1299.png - 16x16 tiles
# Processado P2476.png - 9x8 tiles
# Processado P1514.png - 16x16 tiles
# Processado P1807.png - 5x6 tiles
# Processado P1615.png - 16x16 tiles
# Processado P0948.png - 6x12 tiles
# Processado P0826.png - 5x3 tiles
# Processado P0595.png - 7x6 tiles
# Processado P0071.png - 4x4 tiles
# Processado P2032.png - 4x4 tiles
# Processado P2415.png - 10x8 tiles
# Processado P0141.png - 7x17 tiles
# Processado P1403.png - 14x17 tiles
# Processado P1027.png - 6x9 tiles
# Processado P1675.png - 16x16 tiles
# Processado P2091.png - 4x3 tiles
# Processado P2657.png - 10x8 tiles
# Processado P0404.png - 5x5 tiles
# Processado P2377.png - 8x10 tiles
# Processado P0227.png - 5x9 tiles
# Processado P0495.png - 5x3 tiles
# Processado P1459.png - 18x22 tiles
# Processado P2416.png - 9x8 tiles
# Processado P0339.png - 6x13 tiles
# Processado P2629.png - 7x5 tiles
# Processado P0224.png - 6x8 tiles
# Processado P2437.png - 8x8 tiles
# Processado P1585.png - 16x16 tiles
# Processado P0465.png - 5x6 tiles
# Processado P0569.png - 4x4 tiles
# Processado P0885.png - 9x4 tiles
# Processado P0805.png - 5x6 tiles
# Processado P2396.png - 8x10 tiles
# Processado P0366.png - 5x4 tiles
# Processado P0565.png - 5x6 tiles
# Processado P1709.png - 16x16 tiles
# Processado P1354.png - 16x16 tiles
# Processado P2057.png - 3x2 tiles
# Processado P0349.png - 14x13 tiles
# Processado P1531.png - 16x17 tiles
# Processado P2600.png - 10x8 tiles
# Processado P1350.png - 16x16 tiles
# Processado P1727.png - 16x16 tiles
# Processado P2118.png - 4x3 tiles
# Processado P2010.png - 4x4 tiles
# Processado P0050.png - 13x10 tiles
# Processado P1917.png - 3x2 tiles
# Processado P0871.png - 12x10 tiles
# Processado P0200.png - 4x5 tiles
# Processado P2206.png - 7x5 tiles
# Processado P1182.png - 14x12 tiles
# Processado P1255.png - 16x16 tiles
# Processado P0745.png - 4x7 tiles
# Processado P1450.png - 16x11 tiles
# Processado P1486.png - 5x6 tiles
# Processado P1281.png - 16x16 tiles
# Processado P1317.png - 16x16 tiles
# Processado P0147.png - 5x7 tiles
# Processado P2470.png - 8x6 tiles
# Processado P2259.png - 2x5 tiles
# Processado P0001.png - 23x5 tiles
# Processado P2712.png - 6x8 tiles
# Processado P2020.png - 4x3 tiles
# Processado P0164.png - 5x6 tiles
# Processado P2356.png - 8x10 tiles
# Processado P2662.png - 12x10 tiles
# Processado P1401.png - 14x18 tiles
# Processado P2343.png - 8x9 tiles
# Processado P0993.png - 5x10 tiles
# Processado P0436.png - 4x7 tiles
# Processado P1505.png - 10x11 tiles
# Processado P1026.png - 8x8 tiles
# Processado P2509.png - 9x9 tiles
# Processado P1793.png - 13x14 tiles
# Processado P2151.png - 3x2 tiles
# Processado P1551.png - 16x16 tiles
# Processado P1652.png - 16x16 tiles
# Processado P0755.png - 6x7 tiles
# Processado P1745.png - 16x16 tiles
# Processado P0067.png - 6x5 tiles
# Processado P0980.png - 3x3 tiles
# Processado P0612.png - 4x5 tiles
# Processado P0494.png - 8x11 tiles
# Processado P2628.png - 7x5 tiles
# Processado P2671.png - 12x11 tiles
# Processado P1879.png - 4x3 tiles
# Processado P1726.png - 16x16 tiles
# Processado P1656.png - 20x16 tiles
# Processado P1534.png - 16x17 tiles
# Processado P0700.png - 7x8 tiles
# Processado P0732.png - 5x7 tiles
# Processado P2550.png - 17x19 tiles
# Processado P0215.png - 6x13 tiles
# Processado P1449.png - 14x9 tiles
# Processado P0426.png - 4x4 tiles
# Processado P2099.png - 5x5 tiles
# Processado P0688.png - 5x6 tiles
# Processado P2364.png - 9x9 tiles
# Processado P1980.png - 8x5 tiles
# Processado P2741.png - 11x11 tiles
# Processado P2288.png - 20x12 tiles
# Processado P0063.png - 12x12 tiles
# Processado P0044.png - 7x7 tiles
# Processado P0819.png - 5x4 tiles
# Processado P1801.png - 8x8 tiles
# Processado P2804.png - 9x15 tiles
# Processado P0890.png - 14x7 tiles
# Processado P1012.png - 2x25 tiles
# Processado P1437.png - 28x11 tiles
# Processado P1393.png - 26x24 tiles
# Processado P1241.png - 16x16 tiles
# Processado P0544.png - 5x7 tiles
# Processado P1181.png - 17x15 tiles
# Processado P1089.png - 3x9 tiles
# Processado P2158.png - 7x6 tiles
# Processado P0023.png - 20x10 tiles
# Processado P0421.png - 5x6 tiles
# Processado P0883.png - 6x6 tiles
# Processado P1239.png - 16x16 tiles
# Processado P1457.png - 19x21 tiles
# Processado P1420.png - 5x8 tiles
# Processado P0967.png - 6x15 tiles
# Processado P0453.png - 3x5 tiles
# Processado P0607.png - 8x4 tiles
# Processado P0737.png - 6x9 tiles
# Processado P0648.png - 4x3 tiles
# Processado P1987.png - 4x2 tiles
# Processado P2501.png - 10x7 tiles
# Processado P1408.png - 21x29 tiles
# Processado P0658.png - 5x4 tiles
# Processado P0119.png - 12x11 tiles
# Processado P2601.png - 14x12 tiles
# Processado P1599.png - 20x17 tiles
# Processado P0379.png - 4x3 tiles
# Processado P0619.png - 5x5 tiles
# Processado P2106.png - 4x3 tiles
# Processado P2442.png - 8x6 tiles
# Processado P2631.png - 9x6 tiles
# Processado P1902.png - 4x4 tiles
# Processado P2225.png - 8x6 tiles
# Processado P0620.png - 8x3 tiles
# Processado P1931.png - 7x5 tiles
# Processado P0677.png - 4x4 tiles
# Processado P1341.png - 16x16 tiles
# Processado P2034.png - 6x6 tiles
# Processado P0722.png - 6x4 tiles
# Processado P1859.png - 8x5 tiles
# Processado P2691.png - 25x23 tiles
# Processado P0450.png - 3x4 tiles
# Processado P1562.png - 16x16 tiles
# Processado P0810.png - 3x4 tiles
# Processado P2692.png - 9x11 tiles
# Processado P2519.png - 9x8 tiles
# Processado P1173.png - 15x14 tiles
# Processado P0856.png - 6x8 tiles
# Processado P1388.png - 21x17 tiles
# Processado P0790.png - 7x10 tiles
# Processado P2289.png - 3x4 tiles
# Processado P2591.png - 8x8 tiles
# Processado P0065.png - 14x10 tiles
# Processado P2381.png - 9x9 tiles
# Processado P2428.png - 11x11 tiles
# Processado P2444.png - 8x8 tiles
# Processado P2122.png - 4x4 tiles
# Processado P0383.png - 4x5 tiles
# Processado P1069.png - 14x17 tiles
# Processado P1582.png - 20x16 tiles
# Processado P2516.png - 10x10 tiles
# Processado P0535.png - 5x4 tiles
# Processado P0913.png - 9x13 tiles
# Processado P0250.png - 8x5 tiles
# Processado P1991.png - 3x7 tiles
# Processado P1696.png - 16x16 tiles
# Processando val...
# Processado P1732.png - 16x17 tiles
# Processado P0904.png - 4x5 tiles
# Processado P1398.png - 26x16 tiles
# Processado P2771.png - 8x10 tiles
# Processado P2093.png - 7x6 tiles
# Processado P0432.png - 4x4 tiles
# Processado P0763.png - 5x7 tiles
# Processado P2571.png - 6x5 tiles
# Processado P2477.png - 9x7 tiles
# Processado P0749.png - 4x6 tiles
# Processado P1029.png - 7x11 tiles
# Processado P1786.png - 15x14 tiles
# Processado P2758.png - 17x29 tiles
# Processado P1508.png - 15x7 tiles
# Processado P2541.png - 11x11 tiles
# Processado P0936.png - 5x13 tiles
# Processado P0882.png - 10x4 tiles
# Processado P0352.png - 5x6 tiles
# Processado P0259.png - 9x9 tiles
# Processado P2714.png - 10x18 tiles
# Processado P1809.png - 27x29 tiles
# Processado P1370.png - 16x16 tiles
# Processado P0977.png - 9x9 tiles
# Processado P1888.png - 3x3 tiles
# Processado P2168.png - 5x8 tiles
# Processado P1210.png - 16x16 tiles
# Processado P0342.png - 4x4 tiles
# Processado P1022.png - 5x11 tiles
# Processado P1973.png - 7x8 tiles
# Processado P1610.png - 16x16 tiles
# Processado P2645.png - 14x18 tiles
# Processado P0375.png - 4x4 tiles
# Processado P2478.png - 7x7 tiles
# Processado P0385.png - 4x4 tiles
# Processado P0347.png - 14x7 tiles
# Processado P1679.png - 20x16 tiles
# Processado P1821.png - 5x3 tiles
# Processado P2701.png - 11x16 tiles
# Processado P0974.png - 5x10 tiles
# Processado P0143.png - 3x3 tiles
# Processado P2779.png - 6x7 tiles
# Processado P2167.png - 5x5 tiles
# Processado P0814.png - 3x6 tiles
# Processado P2198.png - 4x2 tiles
# Processado P0170.png - 5x8 tiles
# Processado P2255.png - 4x3 tiles
# Processado P1314.png - 16x16 tiles
# Processado P0117.png - 5x6 tiles
# Processado P1672.png - 20x16 tiles
# Processado P2124.png - 5x5 tiles
# Processado P2481.png - 10x10 tiles
# Processado P0589.png - 9x4 tiles
# Processado P1476.png - 8x10 tiles
# Processado P0402.png - 4x3 tiles
# Processado P0374.png - 5x6 tiles
# Processado P1754.png - 20x16 tiles
# Processado P0104.png - 5x4 tiles
# Processado P1579.png - 16x16 tiles
# Processado P1983.png - 5x5 tiles
# Processado P0715.png - 7x6 tiles
# Processado P2502.png - 10x14 tiles
# Processado P1278.png - 16x21 tiles
# Processado P1566.png - 16x16 tiles
# Processado P2768.png - 10x6 tiles
# Processado P2630.png - 6x8 tiles
# Processado P2231.png - 9x7 tiles
# Processado P1693.png - 16x16 tiles
# Processado P0706.png - 5x5 tiles
# Processado P1007.png - 5x33 tiles
# Processado P0499.png - 5x5 tiles
# Processado P2214.png - 4x5 tiles
# Processado P2587.png - 9x12 tiles
# Processado P1315.png - 16x16 tiles
# Processado P2408.png - 11x8 tiles
# Processado P1586.png - 16x16 tiles
# Processado P0491.png - 7x11 tiles
# Processado P0110.png - 9x11 tiles
# Processado P2678.png - 11x17 tiles
# Processado P2446.png - 10x8 tiles
# Processado P1738.png - 16x16 tiles
# Processado P1570.png - 20x16 tiles
# Processado P0838.png - 7x6 tiles
# Processado P0910.png - 8x9 tiles
# Processado P1009.png - 6x16 tiles
# Processado P1483.png - 8x7 tiles
# Processado P0613.png - 4x5 tiles
# Processado P0929.png - 26x3 tiles
# Processado P0547.png - 5x4 tiles
# Processado P1643.png - 16x16 tiles
# Processado P2322.png - 3x3 tiles
# Processado P1541.png - 16x16 tiles
# Processado P0075.png - 4x2 tiles
# Processado P2539.png - 9x8 tiles
# Processado P2689.png - 14x25 tiles
# Processado P2230.png - 5x10 tiles
# Processado P2504.png - 9x7 tiles
# Processado P0123.png - 5x4 tiles
# Processado P1234.png - 16x16 tiles
# Processado P1030.png - 6x16 tiles
# Processado P0990.png - 9x10 tiles
# Processado P0060.png - 9x14 tiles
# Processado P1471.png - 20x19 tiles
# Processado P2271.png - 13x25 tiles
# Processado P2330.png - 16x33 tiles
# Processado P1806.png - 5x3 tiles
# Processado P1156.png - 12x14 tiles
# Processado P2068.png - 4x4 tiles
# Processado P1958.png - 5x4 tiles
# Processado P1860.png - 7x8 tiles
# Processado P2285.png - 16x15 tiles
# Processado P0382.png - 5x5 tiles
# Processado P0056.png - 4x4 tiles
# Processado P2582.png - 7x7 tiles
# Processado P0962.png - 4x10 tiles
# Processado P2593.png - 7x5 tiles
# Processado P1376.png - 21x19 tiles
# Processado P0604.png - 4x6 tiles
# Processado P0525.png - 6x3 tiles
# Processado P2709.png - 10x12 tiles
# Processado P2393.png - 7x9 tiles
# Processado P1623.png - 20x16 tiles
# Processado P0841.png - 12x10 tiles
# Processado P0932.png - 5x5 tiles
# Processado P1088.png - 8x7 tiles
# Processado P0199.png - 7x5 tiles
# Processado P1103.png - 7x5 tiles
# Processado P0411.png - 5x4 tiles
# Processado P2135.png - 2x2 tiles
# Processado P0615.png - 6x6 tiles
# Processado P1386.png - 14x19 tiles
# Processado P0650.png - 3x4 tiles
# Processado P2331.png - 8x13 tiles
# Processado P1699.png - 20x17 tiles
# Processado P0725.png - 5x7 tiles
# Processado P0761.png - 6x7 tiles
# Processado P2097.png - 4x5 tiles
# Processado P0486.png - 4x6 tiles
# Processado P1619.png - 16x16 tiles
# Processado P0787.png - 5x5 tiles
# Processado P0729.png - 6x3 tiles
# Processado P0953.png - 5x12 tiles
# Processado P1432.png - 17x14 tiles
# Processado P0543.png - 4x5 tiles
# Processado P0130.png - 4x3 tiles
# Processado P1720.png - 16x16 tiles
# Processado P2404.png - 17x22 tiles
# Processado P2294.png - 3x2 tiles
# Processado P1283.png - 16x16 tiles
# Processado P1700.png - 16x16 tiles
# Processado P0194.png - 4x4 tiles
# Processado P0557.png - 5x9 tiles
# Processado P0564.png - 5x4 tiles
# Processado P0998.png - 6x23 tiles
# Processado P1246.png - 16x16 tiles
# Processado P1390.png - 13x25 tiles
# Processado P2450.png - 7x7 tiles
# Processado P2592.png - 6x9 tiles
# Processado P1101.png - 4x4 tiles
# Processado P2726.png - 11x12 tiles
# Processado P1854.png - 17x53 tiles
# Processado P0175.png - 5x4 tiles
# Processado P2220.png - 4x5 tiles
# Processado P2129.png - 5x4 tiles
# Processado P1090.png - 6x9 tiles
# Processado P2059.png - 9x4 tiles
# Processado P0791.png - 5x5 tiles
# Processado P0242.png - 6x3 tiles
# Processado P2197.png - 7x9 tiles
# Processado P2098.png - 4x3 tiles
# Processado P0081.png - 4x3 tiles
# Processado P2241.png - 5x3 tiles
# Processado P1577.png - 16x17 tiles
# Processado P1751.png - 16x16 tiles
# Processado P0146.png - 8x11 tiles
# Processado P0551.png - 6x6 tiles
# Processado P2194.png - 9x7 tiles
# Processado P0712.png - 5x4 tiles
# Processado P1429.png - 11x13 tiles
# Processado P0559.png - 4x4 tiles
# Processado P2337.png - 10x10 tiles
# Processado P1596.png - 20x16 tiles
# Processado P0309.png - 8x4 tiles
# Processado P0558.png - 7x3 tiles
# Processado P1128.png - 5x7 tiles
# Processado P1005.png - 6x23 tiles
# Processado P0454.png - 4x6 tiles
# Processado P1134.png - 9x9 tiles
# Processado P1269.png - 15x16 tiles
# Processado P2310.png - 3x2 tiles
# Processado P0518.png - 5x4 tiles
# Processado P1763.png - 16x16 tiles
# Processado P1066.png - 13x7 tiles
# Processado P1091.png - 4x4 tiles
# Processado P2236.png - 4x5 tiles
# Processado P2044.png - 3x2 tiles
# Processado P2126.png - 5x4 tiles
# Processado P1178.png - 18x17 tiles
# Processado P1583.png - 20x16 tiles
# Processado P0007.png - 9x6 tiles
# Processado P0198.png - 6x5 tiles
# Processado P1666.png - 16x16 tiles
# Processado P1143.png - 21x23 tiles
# Processado P2695.png - 10x16 tiles
# Processado P0799.png - 8x6 tiles
# Processado P1752.png - 16x16 tiles
# Processado P2766.png - 22x22 tiles
# Processado P0246.png - 4x3 tiles
# Processado P2778.png - 14x11 tiles
# Processado P2595.png - 7x4 tiles
# Processado P1960.png - 7x6 tiles
# Processado P1513.png - 17x11 tiles
# Processado P1560.png - 16x16 tiles
# Processado P0704.png - 6x9 tiles
# Processado P2754.png - 15x14 tiles
# Processado P2012.png - 3x2 tiles
# Processado P1581.png - 16x17 tiles
# Processado P0053.png - 6x6 tiles
# Processado P0864.png - 8x12 tiles
# Processado P1075.png - 14x9 tiles
# Processado P1014.png - 8x9 tiles
# Processado P1529.png - 16x16 tiles
# Processado P0237.png - 4x4 tiles
# Processado P1518.png - 16x16 tiles
# Processado P0764.png - 5x7 tiles
# Processado P0789.png - 5x7 tiles
# Processado P0004.png - 6x4 tiles
# Processado P0179.png - 18x19 tiles
# Processado P1995.png - 5x9 tiles
# Processado P1759.png - 16x16 tiles
# Processado P1065.png - 10x17 tiles
# Processado P1213.png - 16x21 tiles
# Processado P2181.png - 10x12 tiles
# Processado P1434.png - 8x8 tiles
# Processado P1825.png - 4x2 tiles
# Processado P1189.png - 4x4 tiles
# Processado P1147.png - 26x19 tiles
# Processado P1184.png - 25x11 tiles
# Processado P2791.png - 24x20 tiles
# Processado P0590.png - 5x6 tiles
# Processado P1179.png - 26x26 tiles
# Processado P1950.png - 3x3 tiles
# Processado P0659.png - 5x3 tiles
# Processado P1023.png - 5x15 tiles
# Processado P1474.png - 25x12 tiles
# Processado P0128.png - 8x7 tiles
# Processado P0257.png - 7x5 tiles
# Processado P1095.png - 9x22 tiles
# Processado P1650.png - 16x17 tiles
# Processado P0189.png - 4x3 tiles
# Processado P0348.png - 8x4 tiles
# Processado P2542.png - 10x9 tiles
# Processado P0949.png - 4x12 tiles
# Processado P2011.png - 5x4 tiles
# Processado P0476.png - 5x5 tiles
# Processado P2374.png - 7x8 tiles
# Processado P1749.png - 16x16 tiles
# Processado P2242.png - 5x11 tiles
# Processado P1905.png - 3x3 tiles
# Processado P0647.png - 4x3 tiles
# Processado P2617.png - 4x5 tiles
# Processado P2488.png - 10x10 tiles
# Processado P1122.png - 12x27 tiles
# Processado P1478.png - 8x8 tiles
# Processado P2570.png - 6x8 tiles
# Processado P1547.png - 16x16 tiles
# Processado P2256.png - 6x18 tiles
# Processado P0414.png - 5x4 tiles
# Processado P1380.png - 19x18 tiles
# Processado P0526.png - 7x9 tiles
# Processado P1911.png - 4x3 tiles
# Processado P0654.png - 5x5 tiles
# Processado P2003.png - 7x5 tiles
# Processado P1225.png - 16x16 tiles
# Processado P0583.png - 3x9 tiles
# Processado P1021.png - 4x7 tiles
# Processado P0837.png - 11x7 tiles
# Processado P2625.png - 10x17 tiles
# Processado P2152.png - 3x5 tiles
# Processado P1463.png - 12x15 tiles
# Processado P1086.png - 5x4 tiles
# Processado P1275.png - 16x16 tiles
# Processado P2547.png - 10x15 tiles
# Processado P0131.png - 5x6 tiles
# Processado P1268.png - 15x16 tiles
# Processado P0964.png - 5x14 tiles
# Processado P2794.png - 18x18 tiles
# Processado P1342.png - 16x16 tiles
# Processado P0377.png - 4x4 tiles
# Processado P1904.png - 3x3 tiles
# Processado P0623.png - 5x5 tiles
# Processado P1601.png - 16x16 tiles
# Processado P2722.png - 10x16 tiles
# Processado P1880.png - 5x2 tiles
# Processado P0262.png - 10x9 tiles
# Processado P2449.png - 9x7 tiles
# Processado P2155.png - 4x4 tiles
# Processado P0989.png - 7x5 tiles
# Processado P1878.png - 5x3 tiles
# Processado P0206.png - 6x5 tiles
# Processado P2724.png - 10x18 tiles
# Processado P0150.png - 3x3 tiles
# Processado P0261.png - 5x6 tiles
# Processado P2718.png - 10x18 tiles
# Processado P0331.png - 9x10 tiles
# Processado P0833.png - 5x7 tiles
# Processado P1713.png - 16x17 tiles
# Processado P0887.png - 11x9 tiles
# Processado P1257.png - 16x16 tiles
# Processado P1877.png - 5x4 tiles
# Processado P2050.png - 4x3 tiles
# Processado P0683.png - 10x8 tiles
# Processado P0969.png - 3x3 tiles
# Processado P0961.png - 5x24 tiles
# Processado P0968.png - 4x9 tiles
# Processado P0079.png - 3x3 tiles
# Processado P0795.png - 10x7 tiles
# Processado P1099.png - 5x4 tiles
# Processado P0228.png - 4x6 tiles
# Processado P1138.png - 5x10 tiles
# Processado P0816.png - 4x5 tiles
# Processado P2363.png - 8x9 tiles
# Processado P1154.png - 15x15 tiles
# Processado P0305.png - 4x3 tiles
# Processado P0249.png - 7x4 tiles
# Processado P2745.png - 10x15 tiles
# Processado P1137.png - 4x3 tiles
# Processado P0466.png - 6x6 tiles
# Processado P0622.png - 7x5 tiles
# Processado P1542.png - 16x16 tiles
# Processado P1770.png - 20x16 tiles
# Processado P2789.png - 18x19 tiles
# Processado P0665.png - 7x6 tiles
# Processado P2781.png - 9x14 tiles
# Processado P2721.png - 10x18 tiles
# Processado P1219.png - 15x16 tiles
# Processado P2802.png - 21x24 tiles
# Processado P2455.png - 9x8 tiles
# Processado P2027.png - 9x5 tiles
# Processado P0368.png - 6x4 tiles
# Processado P1557.png - 20x16 tiles
# Processado P0822.png - 3x5 tiles
# Processado P1512.png - 7x7 tiles
# Processado P0550.png - 4x6 tiles
# Processado P2351.png - 7x8 tiles
# Processado P2082.png - 6x4 tiles
# Processado P2429.png - 12x9 tiles
# Processado P2150.png - 5x3 tiles
# Processado P1473.png - 4x5 tiles
# Processado P1647.png - 16x16 tiles
# Processado P2598.png - 9x10 tiles
# Processado P1742.png - 16x17 tiles
# Processado P1397.png - 14x33 tiles
# Processado P2420.png - 9x8 tiles
# Processado P2365.png - 10x12 tiles
# Processado P1506.png - 11x14 tiles
# Processado P2042.png - 3x2 tiles
# Processado P1212.png - 16x16 tiles
# Processado P0329.png - 4x3 tiles
# Processado P0524.png - 5x5 tiles
# Processado P2580.png - 8x4 tiles
# Processado P0858.png - 6x10 tiles
# Processado P2733.png - 11x12 tiles
# Processado P1750.png - 16x17 tiles
# Processado P0186.png - 3x5 tiles
# Processado P1384.png - 23x23 tiles
# Processado P0217.png - 6x7 tiles
# Processado P1584.png - 20x17 tiles
# Processado P2563.png - 5x8 tiles
# Processado P1919.png - 4x3 tiles
# Processado P2375.png - 9x7 tiles
# Processado P0801.png - 7x14 tiles
# Processado P2462.png - 9x8 tiles
# Processado P1377.png - 16x15 tiles
# Processado P1323.png - 16x16 tiles
# Processado P0027.png - 7x10 tiles
# Processado P1982.png - 8x8 tiles
# Processado P0086.png - 6x5 tiles
# Processado P1940.png - 4x6 tiles
# Processado P0579.png - 5x9 tiles
# Processado P1332.png - 16x16 tiles
# Processado P0300.png - 4x6 tiles
# Processado P0651.png - 5x4 tiles
# Processado P0673.png - 5x5 tiles
# Processado P1829.png - 6x7 tiles
# Processado P0696.png - 9x7 tiles
# Processado P1787.png - 5x3 tiles
# Processado P0660.png - 4x5 tiles
# Processado P1569.png - 16x17 tiles
# Processado P0796.png - 10x3 tiles
# Processado P2218.png - 4x4 tiles
# Processado P1651.png - 16x16 tiles
# Processado P0359.png - 4x3 tiles
# Processado P1371.png - 16x16 tiles
# Processado P0003.png - 4x5 tiles
# Processado P0353.png - 5x5 tiles
# Processado P0168.png - 7x9 tiles
# Processado P2215.png - 4x3 tiles
# Processado P2239.png - 3x4 tiles
# Processado P1410.png - 24x21 tiles
# Processado P1903.png - 6x8 tiles
# Processado P0815.png - 4x5 tiles
# Processado P1492.png - 11x7 tiles
# Processado P2342.png - 10x8 tiles
# Processado P0213.png - 7x8 tiles
# Processado P2166.png - 4x5 tiles
# Processado P0336.png - 6x12 tiles
# Processado P2378.png - 10x11 tiles
# Processado P1838.png - 6x4 tiles
# Processado P2413.png - 8x9 tiles
# Processado P1452.png - 4x4 tiles
# Processado P2121.png - 5x4 tiles
# Processado P1440.png - 7x8 tiles
# Processado P1242.png - 16x16 tiles
# Processado P1273.png - 15x21 tiles
# Processado P1051.png - 4x6 tiles
# Processado P0161.png - 11x11 tiles
# Processado P2610.png - 10x8 tiles
# Processado P0770.png - 6x7 tiles
# Processado P0897.png - 20x10 tiles
# Processado P0577.png - 6x4 tiles
# Processado P1373.png - 16x16 tiles
# Processado P0396.png - 5x5 tiles
# Processado P0945.png - 6x6 tiles
# Processado P0019.png - 15x26 tiles
# Processado P1573.png - 20x17 tiles
# Processado P2599.png - 5x5 tiles
# Processado P0970.png - 5x17 tiles
# Processado P1230.png - 16x21 tiles
# Processado P0844.png - 5x4 tiles
# Processado P2286.png - 9x11 tiles
# Processado P1240.png - 16x16 tiles
# Processado P0173.png - 4x4 tiles
# Processado P0420.png - 5x7 tiles
# Processado P1456.png - 10x14 tiles
# Processado P2085.png - 3x5 tiles
# Processado P1924.png - 4x3 tiles
# Processado P1992.png - 8x5 tiles
# Processado P1978.png - 5x6 tiles
# Processado P2111.png - 4x3 tiles
# Processado P1266.png - 15x16 tiles
# Processado P2088.png - 6x3 tiles
# Processado P1604.png - 16x16 tiles
# Processado P2394.png - 8x8 tiles
# Processado P1598.png - 20x16 tiles
# Processado P1356.png - 16x16 tiles
# Processado P0684.png - 4x3 tiles
# Processado P1561.png - 16x17 tiles
# Processado P1149.png - 17x13 tiles
# Processado P2385.png - 8x9 tiles
# Processado P0839.png - 10x4 tiles
# Processado P2577.png - 5x6 tiles
# Processado P0457.png - 4x6 tiles
# Processado P1133.png - 5x5 tiles
# Processado P1957.png - 7x7 tiles
# Processado P2608.png - 10x9 tiles
# Processado P0047.png - 9x5 tiles
# Processado P0643.png - 4x3 tiles
# Processado P2169.png - 4x4 tiles
# Corte concluído!

# %% [markdown]
# Creating the sliced dataset description

# %%
data_sliced_yaml = """
train: yolo-dataset-sliced/images/train
val: yolo-dataset-sliced/images/val

nc: 15

names: [
  'plane',
  'ship',
  'storage-tank',
  'baseball-diamond',
  'tennis-court',
  'basketball-court',
  'ground-track-field',
  'harbor',
  'bridge',
  'large-vehicle',
  'small-vehicle',
  'helicopter',
  'roundabout',
  'soccer-ball-field',
  'swimming-pool'
]
"""

with open("data_sliced.yaml", "w") as f:
    f.write(data_sliced_yaml)

# %% [markdown]
# Training the yolov11m with the sliced dataset

# %%
# !yolo train model=yolo11m.pt data=/content/data_sliced.yaml epochs=100 imgsz=256 batch=8 optimizer=AdamW lr0=0.001
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt': 100% 38.8M/38.8M [00:00<00:00, 65.2MB/s]
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data_sliced.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=256, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% 755k/755k [00:00<00:00, 36.6MB/s]
# Overriding model.yaml nc=80 with nc=15
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1422589  ultralytics.nn.modules.head.Detect           [15, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,064,573 parameters, 20,064,557 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% 5.35M/5.35M [00:00<00:00, 101MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2536.4±584.5 MB/s, size: 112.2 KB)
# train: Scanning /content/yolo-dataset-sliced/labels/train... 37099 images, 0 backgrounds, 3 corrupt: 100% 37102/37102 [00:43<00:00, 849.80it/s]
# train: /content/yolo-dataset-sliced/images/train/P0840_5_13.png: ignoring corrupt image/label: image size (256, 8) <10 pixels
# train: /content/yolo-dataset-sliced/images/train/P0867_8_4.png: ignoring corrupt image/label: image size (3, 256) <10 pixels
# train: /content/yolo-dataset-sliced/images/train/P0867_8_7.png: ignoring corrupt image/label: image size (3, 256) <10 pixels
# train: /content/yolo-dataset-sliced/images/train/P1055_7_11.png: 1 duplicate labels removed
# train: /content/yolo-dataset-sliced/images/train/P1794_13_8.png: 1 duplicate labels removed
# train: /content/yolo-dataset-sliced/images/train/P1929_3_3.png: 1 duplicate labels removed
# train: New cache created: /content/yolo-dataset-sliced/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1403.0±531.8 MB/s, size: 105.5 KB)
# val: Scanning /content/yolo-dataset-sliced/labels/val... 11461 images, 0 backgrounds, 4 corrupt: 100% 11465/11465 [00:13<00:00, 854.81it/s]
# val: /content/yolo-dataset-sliced/images/val/P0696_4_2.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P0897_15_1.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P0897_15_2.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P0897_15_3.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P1983_4_4.png: ignoring corrupt image/label: image size (238, 8) <10 pixels
# val: /content/yolo-dataset-sliced/images/val/P2592_1_8.png: ignoring corrupt image/label: image size (256, 7) <10 pixels
# val: /content/yolo-dataset-sliced/images/val/P2592_2_8.png: ignoring corrupt image/label: image size (256, 7) <10 pixels
# val: /content/yolo-dataset-sliced/images/val/P2592_3_8.png: ignoring corrupt image/label: image size (256, 7) <10 pixels
# val: /content/yolo-dataset-sliced/images/val/P2789_7_10.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P2789_7_11.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P2789_7_12.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P2789_7_13.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P2789_7_14.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P2789_7_15.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P2789_7_8.png: 1 duplicate labels removed
# val: /content/yolo-dataset-sliced/images/val/P2789_7_9.png: 1 duplicate labels removed
# val: New cache created: /content/yolo-dataset-sliced/labels/val.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 256 train, 256 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      1.11G      1.674      2.099      1.452         14        256: 100% 4638/4638 [08:38<00:00,  8.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:03<00:00, 11.27it/s]
#                    all      11461      44680       0.45      0.291      0.272      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      1.49G      1.568      1.859      1.407         15        256: 100% 4638/4638 [08:01<00:00,  9.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:01<00:00, 11.61it/s]
#                    all      11461      44680      0.523      0.345      0.337      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      1.56G      1.492      1.722      1.367         14        256: 100% 4638/4638 [07:52<00:00,  9.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:01<00:00, 11.74it/s]
#                    all      11461      44680      0.573      0.382      0.403      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      1.63G      1.429      1.605      1.334         18        256: 100% 4638/4638 [07:49<00:00,  9.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:01<00:00, 11.75it/s]
#                    all      11461      44680      0.541      0.433      0.437      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      1.69G       1.38       1.52      1.304         12        256: 100% 4638/4638 [07:46<00:00,  9.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:00<00:00, 11.78it/s]
#                    all      11461      44680      0.587      0.449       0.46      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      1.76G      1.352      1.455      1.287         21        256: 100% 4638/4638 [07:50<00:00,  9.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:01<00:00, 11.71it/s]
#                    all      11461      44680      0.617      0.456      0.476      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      1.83G      1.319      1.415       1.27         25        256: 100% 4638/4638 [07:52<00:00,  9.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:02<00:00, 11.54it/s]
#                    all      11461      44680      0.455      0.466      0.393      0.236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      1.91G      2.342      8.783      1.972         16        256: 100% 4638/4638 [07:48<00:00,  9.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [11:30<00:00,  1.04it/s]
#                    all      11461      44680     0.0667    0.00135   1.69e-05   2.38e-06
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.09G      3.754      15.07      4.012         14        256: 100% 4638/4638 [07:48<00:00,  9.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [09:29<00:00,  1.26it/s]
#                    all      11461      44680   0.000393     0.0517   0.000223   5.72e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.16G      3.798      17.43      3.848         30        256: 100% 4638/4638 [07:47<00:00,  9.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [09:36<00:00,  1.24it/s]
#                    all      11461      44680   0.000451     0.0256   0.000283   6.47e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.26G      3.816      18.06      4.605         18        256: 100% 4638/4638 [07:48<00:00,  9.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [09:38<00:00,  1.24it/s]
#                    all      11461      44680    0.00043     0.0305   0.000305   6.99e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.38G      3.767      12.02      4.443         11        256: 100% 4638/4638 [07:44<00:00,  9.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [09:14<00:00,  1.29it/s]
#                    all      11461      44680   0.000374     0.0198   0.000261   5.52e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.51G      3.722      12.05      3.993         27        256: 100% 4638/4638 [07:48<00:00,  9.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [10:01<00:00,  1.19it/s]
#                    all      11461      44680   0.000362     0.0365   0.000286   6.57e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.65G      3.666      12.32      4.018         10        256: 100% 4638/4638 [07:45<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [10:13<00:00,  1.17it/s]
#                    all      11461      44680   6.94e-05    0.00344   3.55e-05   5.76e-06
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.72G      3.513      10.05      5.639         38        256: 100% 4638/4638 [07:40<00:00, 10.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [09:14<00:00,  1.29it/s]
#                    all      11461      44680   0.000312     0.0162   0.000183   4.21e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.83G      3.455      8.976      5.278         23        256: 100% 4638/4638 [07:45<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [09:47<00:00,  1.22it/s]
#                    all      11461      44680   0.000224      0.023    0.00015   3.94e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.93G       3.49        9.5      3.914         27        256: 100% 4638/4638 [07:45<00:00,  9.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [10:38<00:00,  1.12it/s]
#                    all      11461      44680    0.00024       0.02   0.000138   3.35e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      3.05G      3.528      9.467      3.205         25        256: 100% 4638/4638 [07:45<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [11:08<00:00,  1.07it/s]
#                    all      11461      44680   0.000335     0.0238   0.000195   4.73e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      3.25G      3.765      6.895      2.917         38        256: 100% 4638/4638 [07:45<00:00,  9.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [10:19<00:00,  1.16it/s]
#                    all      11461      44680   0.000255     0.0209   0.000477   6.98e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      3.32G      3.795      7.042      3.208         12        256: 100% 4638/4638 [07:41<00:00, 10.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [11:21<00:00,  1.05it/s]
#                    all      11461      44680   0.000195     0.0202   0.000152   3.62e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100       3.4G      3.817      7.115      3.301         24        256: 100% 4638/4638 [07:45<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [11:35<00:00,  1.03it/s]
#                    all      11461      44680    0.00017     0.0181   0.000117   2.72e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      3.52G      3.801      5.834      3.284         14        256: 100% 4638/4638 [07:45<00:00,  9.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [11:39<00:00,  1.03it/s]
#                    all      11461      44680   0.000133     0.0181   9.21e-05   2.34e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      3.65G      3.791      5.383      3.173         14        256: 100% 4638/4638 [07:46<00:00,  9.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [11:39<00:00,  1.03it/s]
#                    all      11461      44680   0.000193     0.0212   0.000128   3.68e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      3.75G      3.783      5.335      3.112         13        256: 100% 4638/4638 [07:45<00:00,  9.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [11:20<00:00,  1.05it/s]
#                    all      11461      44680   0.000233     0.0288   0.000175    4.5e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      3.87G      3.774      5.154      3.001         19        256: 100% 4638/4638 [07:41<00:00, 10.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [09:13<00:00,  1.30it/s]
#                    all      11461      44680   0.000249     0.0315   0.000188   4.75e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100         4G      3.758      4.634      2.893         12        256: 100% 4638/4638 [07:45<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [08:02<00:00,  1.49it/s]
#                    all      11461      44680   0.000169     0.0217    0.00016   3.85e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.14G      3.733       4.64      2.825         10        256: 100% 4638/4638 [07:46<00:00,  9.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [04:48<00:00,  2.49it/s]
#                    all      11461      44680   0.000193      0.022   0.000124   3.55e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4.21G      3.707       4.64      2.843         11        256: 100% 4638/4638 [07:46<00:00,  9.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [04:18<00:00,  2.78it/s]
#                    all      11461      44680   0.000204     0.0224   0.000138   3.81e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      4.31G      3.701      4.361      2.728          7        256: 100% 4638/4638 [07:41<00:00, 10.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [04:13<00:00,  2.83it/s]
#                    all      11461      44680    0.00013     0.0197   9.11e-05   2.43e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      4.46G      3.686      4.318      2.708         31        256: 100% 4638/4638 [07:43<00:00, 10.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [03:15<00:00,  3.66it/s]
#                    all      11461      44680   0.000183      0.022   0.000126   3.53e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      4.55G      3.667      4.321      2.682         23        256: 100% 4638/4638 [07:43<00:00, 10.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [02:44<00:00,  4.36it/s]
#                    all      11461      44680   0.000163      0.022   0.000117   3.31e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.65G      3.666      4.255      2.646         12        256: 100% 4638/4638 [07:40<00:00, 10.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [02:42<00:00,  4.41it/s]
#                    all      11461      44680   9.36e-05     0.0186   8.57e-05   2.14e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      4.79G      3.656      4.167       2.59         15        256: 100% 4638/4638 [07:43<00:00, 10.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [02:23<00:00,  4.99it/s]
#                    all      11461      44680   0.000198      0.032   0.000153   4.14e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.93G      3.645       4.18       2.56         12        256: 100% 4638/4638 [07:40<00:00, 10.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:59<00:00,  6.01it/s]
#                    all      11461      44680   0.000286     0.0578   0.000203   5.79e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100         5G      3.638      4.195      2.524          7        256: 100% 4638/4638 [07:37<00:00, 10.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:32<00:00,  7.77it/s]
#                    all      11461      44680   0.000252     0.0553   0.000182   5.09e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      5.12G      3.637      4.119      2.525          6        256: 100% 4638/4638 [07:40<00:00, 10.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:26<00:00,  8.27it/s]
#                    all      11461      44680   0.000282     0.0562    0.00021   5.71e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      5.24G        nan        nan        nan         48        256: 100% 4638/4638 [07:37<00:00, 10.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:17<00:00,  9.30it/s]
#                    all      11461      44680   0.000296     0.0541   0.000218   5.84e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      5.34G        nan        nan        nan         22        256: 100% 4638/4638 [07:36<00:00, 10.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:18<00:00,  9.16it/s]
#                    all      11461      44680   0.000204     0.0537   0.000182   9.84e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      5.46G        nan        nan        nan          7        256: 100% 4638/4638 [07:38<00:00, 10.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:30<00:00,  7.88it/s]
#                    all      11461      44680   0.000178     0.0352   0.000126   3.47e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      5.56G        nan        nan        nan         20        256: 100% 4638/4638 [07:40<00:00, 10.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:30<00:00,  7.91it/s]
#                    all      11461      44680   0.000207     0.0344   0.000141   4.34e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100       5.7G        nan        nan        nan         20        256: 100% 4638/4638 [07:43<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:44<00:00,  6.86it/s]
#                    all      11461      44680   0.000167      0.034   0.000118   3.43e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      5.82G        nan        nan        nan         10        256: 100% 4638/4638 [07:41<00:00, 10.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:57<00:00,  6.11it/s]
#                    all      11461      44680   0.000167     0.0344   0.000119    3.5e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      5.96G        nan        nan        nan         15        256: 100% 4638/4638 [07:42<00:00, 10.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [02:04<00:00,  5.74it/s]
#                    all      11461      44680   0.000166     0.0345    0.00012   3.53e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      6.02G        nan        nan        nan         10        256: 100% 4638/4638 [07:44<00:00,  9.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [02:24<00:00,  4.95it/s]
#                    all      11461      44680   0.000168     0.0348   0.000184   5.07e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      6.15G        nan        nan        nan          9        256: 100% 4638/4638 [07:43<00:00, 10.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [02:47<00:00,  4.29it/s]
#                    all      11461      44680   0.000167     0.0347    0.00012   3.58e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      6.27G        nan        nan        nan         11        256: 100% 4638/4638 [07:41<00:00, 10.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [03:10<00:00,  3.76it/s]
#                    all      11461      44680   0.000169     0.0346   0.000121   3.59e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      6.39G        nan        nan        nan         29        256: 100% 4638/4638 [07:40<00:00, 10.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [03:15<00:00,  3.67it/s]
#                    all      11461      44680   0.000169     0.0347   0.000139   3.82e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      6.49G        nan        nan        nan         12        256: 100% 4638/4638 [07:44<00:00,  9.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [03:31<00:00,  3.39it/s]
#                    all      11461      44680   0.000175     0.0347   0.000153   4.87e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      6.62G        nan        nan        nan         11        256: 100% 4638/4638 [07:46<00:00,  9.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [03:57<00:00,  3.02it/s]
#                    all      11461      44680   0.000188     0.0349   0.000165   5.09e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      6.74G        nan        nan        nan         36        256: 100% 4638/4638 [07:48<00:00,  9.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [07:51<00:00,  1.52it/s]
#                    all      11461      44680   0.000188     0.0349   0.000175   4.91e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      6.88G        nan        nan        nan         19        256: 100% 4638/4638 [07:43<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [09:01<00:00,  1.32it/s]
#                    all      11461      44680   0.000189     0.0349   0.000134   3.96e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      6.95G        nan        nan        nan         11        256: 100% 4638/4638 [07:43<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [06:19<00:00,  1.89it/s]
#                    all      11461      44680   0.000186      0.035   0.000126   3.84e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      7.05G        nan        nan        nan         17        256: 100% 4638/4638 [07:42<00:00, 10.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [06:17<00:00,  1.90it/s]
#                    all      11461      44680   0.000185      0.035    0.00014   4.34e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      7.18G        nan        nan        nan          5        256: 100% 4638/4638 [07:43<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [06:17<00:00,  1.90it/s]
#                    all      11461      44680   0.000183     0.0349   0.000134   3.88e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      7.33G        nan        nan        nan         26        256: 100% 4638/4638 [07:39<00:00, 10.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:41<00:00, 17.08it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100       7.4G        nan        nan        nan         17        256: 100% 4638/4638 [07:41<00:00, 10.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.89it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      2.28G        nan        nan        nan         52        256: 100% 4638/4638 [07:43<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.85it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      2.28G        nan        nan        nan         18        256: 100% 4638/4638 [07:45<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:41<00:00, 17.08it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      2.28G        nan        nan        nan         12        256: 100% 4638/4638 [07:41<00:00, 10.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.98it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      2.28G        nan        nan        nan         16        256: 100% 4638/4638 [07:44<00:00,  9.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.75it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      2.28G        nan        nan        nan         36        256: 100% 4638/4638 [07:42<00:00, 10.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.84it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      2.28G        nan        nan        nan          7        256: 100% 4638/4638 [07:46<00:00,  9.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.82it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      2.28G        nan        nan        nan          9        256: 100% 4638/4638 [07:41<00:00, 10.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.81it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.28G        nan        nan        nan         18        256: 100% 4638/4638 [07:44<00:00,  9.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.94it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.28G        nan        nan        nan         32        256: 100% 4638/4638 [07:41<00:00, 10.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.95it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.31G        nan        nan        nan         38        256: 100% 4638/4638 [07:38<00:00, 10.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:41<00:00, 17.09it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.38G        nan        nan        nan         19        256: 100% 4638/4638 [07:39<00:00, 10.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:41<00:00, 17.11it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.46G        nan        nan        nan          7        256: 100% 4638/4638 [07:35<00:00, 10.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 17.01it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.58G        nan        nan        nan          8        256: 100% 4638/4638 [07:37<00:00, 10.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.99it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.71G        nan        nan        nan          9        256: 100% 4638/4638 [07:38<00:00, 10.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 17.03it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.85G        nan        nan        nan          7        256: 100% 4638/4638 [07:37<00:00, 10.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:41<00:00, 17.15it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.93G        nan        nan        nan         41        256: 100% 4638/4638 [07:36<00:00, 10.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:41<00:00, 17.09it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.06G        nan        nan        nan          6        256: 100% 4638/4638 [07:43<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.76it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      3.16G        nan        nan        nan         29        256: 100% 4638/4638 [07:44<00:00,  9.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.87it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100       3.3G        nan        nan        nan          7        256: 100% 4638/4638 [07:38<00:00, 10.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.78it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100       3.4G        nan        nan        nan          4        256: 100% 4638/4638 [07:44<00:00,  9.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.87it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.54G        nan        nan        nan         10        256: 100% 4638/4638 [07:45<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.73it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.62G        nan        nan        nan         11        256: 100% 4638/4638 [07:44<00:00,  9.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.84it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      3.75G        nan        nan        nan         19        256: 100% 4638/4638 [07:44<00:00,  9.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.94it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      3.85G        nan        nan        nan          8        256: 100% 4638/4638 [07:42<00:00, 10.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.84it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      3.98G        nan        nan        nan         13        256: 100% 4638/4638 [07:42<00:00, 10.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.88it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      4.11G        nan        nan        nan         39        256: 100% 4638/4638 [07:43<00:00, 10.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.90it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      4.19G        nan        nan        nan         30        256: 100% 4638/4638 [07:41<00:00, 10.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.79it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100       4.3G        nan        nan        nan         24        256: 100% 4638/4638 [07:41<00:00, 10.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.95it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      4.43G        nan        nan        nan         18        256: 100% 4638/4638 [07:43<00:00, 10.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.92it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      4.55G        nan        nan        nan         29        256: 100% 4638/4638 [07:43<00:00, 10.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.89it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.75G        nan        nan        nan         17        256: 100% 4638/4638 [07:44<00:00,  9.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.87it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.81G        nan        nan        nan          7        256: 100% 4638/4638 [07:41<00:00, 10.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.85it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.88G        nan        nan        nan         12        256: 100% 4638/4638 [07:39<00:00, 10.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 17.04it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.98G        nan        nan        nan         10        256: 100% 4638/4638 [07:39<00:00, 10.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.87it/s]
#                    all      11461      44680          0          0          0          0
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      5.18G        nan        nan        nan          8        256: 100% 4638/4638 [07:52<00:00,  9.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.81it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      5.25G        nan        nan        nan          2        256: 100% 4638/4638 [07:53<00:00,  9.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.70it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      5.35G        nan        nan        nan          2        256: 100% 4638/4638 [07:58<00:00,  9.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:43<00:00, 16.66it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      5.45G        nan        nan        nan         17        256: 100% 4638/4638 [07:54<00:00,  9.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.68it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      5.58G        nan        nan        nan          2        256: 100% 4638/4638 [07:56<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:43<00:00, 16.57it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.68G        nan        nan        nan          3        256: 100% 4638/4638 [07:54<00:00,  9.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.72it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      5.82G        nan        nan        nan          9        256: 100% 4638/4638 [07:56<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:43<00:00, 16.58it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.91G        nan        nan        nan         12        256: 100% 4638/4638 [07:59<00:00,  9.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.72it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      6.05G        nan        nan        nan         15        256: 100% 4638/4638 [07:56<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.79it/s]
#                    all      11461      44680          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      6.14G        nan        nan        nan          7        256: 100% 4638/4638 [07:55<00:00,  9.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [00:42<00:00, 16.83it/s]
#                    all      11461      44680          0          0          0          0
#
# 100 epochs completed in 18.512 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 40.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 40.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,041,597 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 717/717 [01:00<00:00, 11.93it/s]
#                    all      11461      44680      0.614      0.457      0.476      0.285
#                  plane       2535       5666      0.811      0.537      0.629      0.401
#                   ship       1710      12142      0.773      0.805      0.831      0.549
#           storage-tank        636       3487       0.87      0.531      0.663        0.4
#       baseball-diamond        343        426      0.639       0.27      0.335      0.151
#           tennis-court        674       1573      0.835      0.777      0.815      0.628
#       basketball-court        170        303      0.496      0.271      0.289      0.173
#     ground-track-field        623        633      0.458      0.216      0.236       0.13
#                 harbor       2594       5086      0.616      0.404      0.458      0.222
#                 bridge        655        807      0.445      0.226      0.205     0.0832
#          large-vehicle       1312       6437      0.691      0.725       0.74      0.488
#          small-vehicle       1210       6521        0.5      0.825      0.712      0.413
#             helicopter         90        140      0.373       0.15      0.132     0.0764
#             roundabout        281        289      0.468      0.291      0.281       0.15
#      soccer-ball-field        529        600      0.664      0.285      0.356      0.224
#          swimming-pool        318        570      0.566       0.54      0.465      0.185
# Speed: 0.0ms preprocess, 1.7ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# Saving the reuslt

# %%
import shutil
from google.colab import files

# Caminho da pasta que será compactada
caminho_pasta = "/content/runs/detect/train"

# Caminho do arquivo zip que será criado
arquivo_zip = "/content/train_output_yolov11m_100_epocas-adam-imgsz256_batch8.zip"

# Compacta a pasta
shutil.make_archive(arquivo_zip.replace(".zip", ""), 'zip', caminho_pasta)

# Gera link para download
files.download(arquivo_zip)
